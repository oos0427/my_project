# %%
import pandas as pd
import numpy as np
import my_def

# %% [markdown]
# <h1>데이터확인 및 가공</h1>
# 업종명 분류 -> 9개의 중분류로 구분

# %%
df = pd.read_csv('Merged_Sales_data_v2.6(shift3).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62298 entries, 0 to 62297
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년분기         62298 non-null  int64
#  1   행정동         62298 non-null  object
#  2   업종별카테고리     62298 non-null  object
#  3   월매출(점포)     62298 non-null  int64
#  4   인구수         62298 non-null  float64
#  5   지역생활인구      62298 non-null  float64
#  6   장기외국인       62298 non-null  float64
#  7   단기외국인       62298 non-null  float64
#  8   주차장면적(면)    62298 non-null  float64
#  9   주차장개수(개소)   62298 non-null  float64
#  10  학교수         62298 non-null  float64
#  11  학생수         62298 non-null  float64
#  12  버스정류장수      62298 non-null  float64
#  13  년분기_미룸      62298 non-null  float64
#  14  월매출_shift1  62298 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 7.1+ MB

# %%
df = my_def.reduce_memory_usage(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62298 entries, 0 to 62297
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년분기         62298 non-null  int16
#  1   행정동         62298 non-null  object
#  2   업종별카테고리     62298 non-null  object
#  3   월매출(점포)     62298 non-null  int64
#  4   인구수         62298 non-null  float16
#  5   지역생활인구      62298 non-null  float32
#  6   장기외국인       62298 non-null  float32
#  7   단기외국인       62298 non-null  float32
#  8   주차장면적(면)    62298 non-null  float32
#  9   주차장개수(개소)   62298 non-null  float16
#  10  학교수         62298 non-null  float16
#  11  학생수         62298 non-null  float16
#  12  버스정류장수      62298 non-null  float16
#  13  년분기_미룸      62298 non-null  float16
#  14  월매출_shift1  62298 non-null  float32
# dtypes: float16(6), float32(5), int16(1), int64(1), object(2)
# memory usage: 3.4+ MB
# None

# %%
df[df["업종별카테고리"] == "기타"]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# Empty DataFrame
# Columns: [년분기, 행정동, 업종별카테고리, 월매출(점포), 인구수, 지역생활인구, 장기외국인, 단기외국인, 주차장면적(면), 주차장개수(개소), 학교수, 학생수, 버스정류장수, 년분기_미룸, 월매출_shift1]
# Index: []

# %% [markdown]
# <h1>전체업종 선형회귀 분석</h1>

# %%
shift = 3

# %%
result_lr_00 = my_def.linear_regression_model(df, scaler_option= 0, shift_value=shift)
result_lr_00
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'None',
#  'train_mse': np.float64(4.506265616372923e+16),
#  'test_mse': np.float64(4.967637445850049e+16),
#  'train_rmse': np.float64(212279664.98),
#  'test_rmse': np.float64(222881974.28),
#  'train_r2': 0.44,
#  'test_r2': 0.42,
#  'train_mae': np.float64(112306425.85),
#  'test_mae': np.float64(113486923.2),
#  'train_mae_ratio': np.float64(53.28),
#  'test_mae_ratio': np.float64(53.56),
#  'Shift': 3}

# %%
result_lr_01 = my_def.linear_regression_model(df, scaler_option= 1, shift_value=shift)
result_lr_01
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'StandardScaler',
#  'train_mse': np.float64(4.348441270819262e+16),
#  'test_mse': np.float64(4.682330300177595e+16),
#  'train_rmse': np.float64(208529165.13),
#  'test_rmse': np.float64(216386928.91),
#  'train_r2': 0.46,
#  'test_r2': 0.45,
#  'train_mae': np.float64(112498286.25),
#  'test_mae': np.float64(113562153.45),
#  'train_mae_ratio': np.float64(53.38),
#  'test_mae_ratio': np.float64(53.6),
#  'Shift': 3}

# %%
result_lr_02 = my_def.linear_regression_model(df, scaler_option= 2, shift_value=shift)
result_lr_02
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'MinMaxScaler',
#  'train_mse': np.float64(4.3484413200873736e+16),
#  'test_mse': np.float64(4.6823326237518664e+16),
#  'train_rmse': np.float64(208529166.31),
#  'test_rmse': np.float64(216386982.6),
#  'train_r2': 0.46,
#  'test_r2': 0.45,
#  'train_mae': np.float64(112497292.17),
#  'test_mae': np.float64(113561162.93),
#  'train_mae_ratio': np.float64(53.37),
#  'test_mae_ratio': np.float64(53.6),
#  'Shift': 3}

# %%
#raise KeyboardInterrupt("실행을 중단합니다.")

# %%
result_rf_00 = my_def.random_forest_model(df, scaler_option= 0, shift_value=shift)
result_rf_00
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'None',
#  'train_mse': np.float64(696705833348933.6),
#  'test_mse': np.float64(5458950001914771.0),
#  'train_rmse': np.float64(26395185.8),
#  'test_rmse': np.float64(73884707.5),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11421346.5),
#  'test_mae': np.float64(31829629.96),
#  'train_mae_ratio': np.float64(5.42),
#  'test_mae_ratio': np.float64(15.02),
#  'Shift': 3}

# %%
result_rf_01 = my_def.random_forest_model(df, scaler_option= 1, shift_value=shift)
result_rf_01
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'StandardScaler',
#  'train_mse': np.float64(696891574943822.9),
#  'test_mse': np.float64(5449624040710011.0),
#  'train_rmse': np.float64(26398704.04),
#  'test_rmse': np.float64(73821568.94),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11424338.28),
#  'test_mae': np.float64(31829603.59),
#  'train_mae_ratio': np.float64(5.42),
#  'test_mae_ratio': np.float64(15.02),
#  'Shift': 3}

# %%
result_rf_02 = my_def.random_forest_model(df, scaler_option= 2, shift_value=shift)
result_rf_02
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'MinMaxScaler',
#  'train_mse': np.float64(696902644867744.6),
#  'test_mse': np.float64(5471243276353664.0),
#  'train_rmse': np.float64(26398913.71),
#  'test_rmse': np.float64(73967852.99),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11423207.28),
#  'test_mae': np.float64(31849248.53),
#  'train_mae_ratio': np.float64(5.42),
#  'test_mae_ratio': np.float64(15.03),
#  'Shift': 3}

# %%
# 결과 딕셔너리들을 리스트에 모읍니다.
results = [result_lr_00, result_lr_01, result_lr_02, result_rf_00, result_rf_01, result_rf_02]

# 리스트를 데이터프레임으로 변환합니다.
df_results = pd.DataFrame(results)

# %%
col = ['Shift', 'Model', 'Scaler', 'train_mse', 'test_mse', 'train_rmse', 'test_rmse',
       'train_r2', 'test_r2', 'train_mae', 'test_mae', 'train_mae_ratio',
       'test_mae_ratio']
df_results = df_results[col]

# %%
df_results
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      3       LinearRegression            None  4.506266e+16  4.967637e+16
# 1      3       LinearRegression  StandardScaler  4.348441e+16  4.682330e+16
# 2      3       LinearRegression    MinMaxScaler  4.348441e+16  4.682333e+16
# 3      3  RandomForestRegressor            None  6.967058e+14  5.458950e+15
# 4      3  RandomForestRegressor  StandardScaler  6.968916e+14  5.449624e+15
# 5      3  RandomForestRegressor    MinMaxScaler  6.969026e+14  5.471243e+15
#
#      train_rmse     test_rmse  train_r2  test_r2     train_mae      test_mae  \
# 0  2.122797e+08  2.228820e+08      0.44     0.42  1.123064e+08  1.134869e+08
# 1  2.085292e+08  2.163869e+08      0.46     0.45  1.124983e+08  1.135622e+08
# 2  2.085292e+08  2.163870e+08      0.46     0.45  1.124973e+08  1.135612e+08
# 3  2.639519e+07  7.388471e+07      0.99     0.94  1.142135e+07  3.182963e+07
# 4  2.639870e+07  7.382157e+07      0.99     0.94  1.142434e+07  3.182960e+07
# 5  2.639891e+07  7.396785e+07      0.99     0.94  1.142321e+07  3.184925e+07
#
#    train_mae_ratio  test_mae_ratio
# 0            53.28           53.56
# 1            53.38           53.60
# 2            53.37           53.60
# 3             5.42           15.02
# 4             5.42           15.02
# 5             5.42           15.03

# %%
df_results.to_csv("all_category_shift3.csv", index= False)

# %%
#raise KeyboardInterrupt("실행을 중단합니다.")

# %% [markdown]
# <h1>업종별카테고리 선형회귀 모델</h1>
# Polynomial Features & Standard Scaler 사용 안함<br>
# 9개 카테고리를 개별로해서 데이터프레임 형태로 저장

# %%
shift = 3

# %%
LRN_result = my_def.category_model_evaluation(df, model_index=0, shift_value=shift)
LRN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   107370670.36 107370637.63      0.89     0.89 61393356.22 59432740.12
# 식음료      51374683.26  52238531.61      0.88     0.89 34428702.12 35224463.91
# 소매_편의   117106625.88 128362576.46      0.92     0.88 64891641.90 67037693.22
# 생활서비스    65071925.98  54254145.78      0.82     0.89 32546091.04 29781849.14
# 미용_패션    50096625.16  45344040.38      0.89     0.88 19930385.75 18186737.48
# 교육_학원    18413527.16  20990430.69      0.80     0.82 10315107.01 10907534.29
# 취미_레저   116554704.29 112011820.99      0.81     0.85 39226850.79 38551788.24
# 가구_전자기기  83216664.23 100670067.27      0.82     0.75 39100642.43 43780937.76
# 부동산_숙박    9127604.78  11007558.75      0.89     0.86  4776199.91  5806602.23
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              12.47           12.13      3               47.71
# 식음료                14.59           14.89      3               47.71
# 소매_편의              14.61           14.95      3               47.71
# 생활서비스              22.17           20.30      3               47.71
# 미용_패션              22.66           21.86      3               47.71
# 교육_학원              27.28           27.35      3               47.71
# 취미_레저              32.52           30.27      3               47.71
# 가구_전자기기            36.51           40.18      3               47.71
# 부동산_숙박             41.85           47.71      3               47.71
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 12.13                25.52
# 식음료                   12.13                25.52
# 소매_편의                 12.13                25.52
# 생활서비스                 12.13                25.52
# 미용_패션                 12.13                25.52
# 교육_학원                 12.13                25.52
# 취미_레저                 12.13                25.52
# 가구_전자기기               12.13                25.52
# 부동산_숙박                12.13                25.52

# %% [markdown]
# <h1>선형회귀 - Standard Scaler 적용</h1>

# %%
LRS_result = my_def.category_model_evaluation(df, model_index=0, scaler_type="standard", shift_value=shift)
LRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   88085637.72  91095443.03      0.93     0.92 51111704.13 53521442.17
# 소매_편의   96495829.41 112907945.24      0.94     0.91 54584738.93 60289108.10
# 식음료     41349393.55  46505294.86      0.93     0.91 29171422.65 31901353.78
# 생활서비스   49667477.23  47316685.54      0.89     0.91 25428423.08 25822073.57
# 미용_패션   40125764.14  42080172.15      0.93     0.90 15838704.62 15948135.54
# 교육_학원   15333864.28  18111738.70      0.86     0.86  8740843.93  9921698.38
# 취미_레저   78281590.99  78440774.10      0.91     0.93 32401070.89 35029099.44
# 가구_전자기기 66511038.43 109496192.30      0.89     0.71 31236364.48 38437116.07
# 부동산_숙박   7245159.91  24821216.39      0.93     0.31  3601376.76  6316823.51
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              10.39           10.92      3               51.90
# 소매_편의              12.29           13.45      3               51.90
# 식음료                12.37           13.48      3               51.90
# 생활서비스              17.32           17.60      3               51.90
# 미용_패션              18.01           19.17      3               51.90
# 교육_학원              23.12           24.87      3               51.90
# 취미_레저              26.86           27.50      3               51.90
# 가구_전자기기            29.17           35.27      3               51.90
# 부동산_숙박             31.56           51.90      3               51.90
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.92                23.80
# 소매_편의                 10.92                23.80
# 식음료                   10.92                23.80
# 생활서비스                 10.92                23.80
# 미용_패션                 10.92                23.80
# 교육_학원                 10.92                23.80
# 취미_레저                 10.92                23.80
# 가구_전자기기               10.92                23.80
# 부동산_숙박                10.92                23.80

# %% [markdown]
# <h1>선형회귀 - Min-Max Scaler 적용</h1>

# %%
LRM_result = my_def.category_model_evaluation(df, model_index=0, scaler_type="minmax", shift_value=shift)
LRM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   88085654.51  91095430.67      0.93     0.92 51111740.94 53521381.91
# 소매_편의   96495862.49 112907998.87      0.94     0.91 54584344.17 60288748.20
# 식음료     41349346.87  46505284.32      0.93     0.91 29171416.08 31901378.69
# 생활서비스   49667471.24  47316803.80      0.89     0.91 25428541.76 25822223.80
# 미용_패션   40125757.87  42080167.05      0.93     0.90 15838725.50 15948161.22
# 교육_학원   15333857.70  18111720.59      0.86     0.86  8740850.31  9921692.13
# 취미_레저   78281591.62  78440750.72      0.91     0.93 32401089.28 35029129.62
# 가구_전자기기 66511030.83  79859772.17      0.89     0.84 31236443.21 36453842.21
# 부동산_숙박   7245155.86  11092113.99      0.93     0.86  3601385.42  4827205.97
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              10.39           10.92      3               39.66
# 소매_편의              12.29           13.45      3               39.66
# 식음료                12.37           13.48      3               39.66
# 생활서비스              17.32           17.60      3               39.66
# 미용_패션              18.01           19.17      3               39.66
# 교육_학원              23.12           24.87      3               39.66
# 취미_레저              26.86           27.50      3               39.66
# 가구_전자기기            29.17           33.45      3               39.66
# 부동산_숙박             31.56           39.66      3               39.66
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.92                22.23
# 소매_편의                 10.92                22.23
# 식음료                   10.92                22.23
# 생활서비스                 10.92                22.23
# 미용_패션                 10.92                22.23
# 교육_학원                 10.92                22.23
# 취미_레저                 10.92                22.23
# 가구_전자기기               10.92                22.23
# 부동산_숙박                10.92                22.23

# %% [markdown]
# <h1>업종별카테고리 랜덤포레스트 모델</h1>
# Polynomial Features & Standard Scaler 사용 안함<br>
# 9개 카테고리를 개별로해서 데이터프레임 형태로 저장

# %%
RFN_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift)
RFN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     13344020.36  36479155.26      0.99     0.95  8628980.46 23681444.09
# 의료_건강   36477309.60 100910952.44      0.99     0.90 20190335.28 52575880.59
# 소매_편의   35958456.17 105165881.97      0.99     0.92 20200824.22 55838704.30
# 미용_패션   14354477.82  32386569.53      0.99     0.94  5667748.90 13485942.71
# 생활서비스   22237195.86  46774651.12      0.98     0.92 10662581.65 25896823.54
# 교육_학원    5873027.01  17700999.31      0.98     0.87  3134387.57  8897411.86
# 부동산_숙박   2766529.01   6203200.65      0.99     0.96  1300720.62  2979703.86
# 취미_레저   33077506.95  93264587.04      0.98     0.90 12085655.04 33969260.85
# 가구_전자기기 28428270.21  91742899.08      0.98     0.79 12666090.08 38888171.19
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.66           10.01      3               35.69
# 의료_건강               4.10           10.73      3               35.69
# 소매_편의               4.55           12.45      3               35.69
# 미용_패션               6.44           16.21      3               35.69
# 생활서비스               7.26           17.66      3               35.69
# 교육_학원               8.29           22.31      3               35.69
# 부동산_숙박             11.40           24.48      3               35.69
# 취미_레저              10.02           26.67      3               35.69
# 가구_전자기기            11.83           35.69      3               35.69
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   10.01                19.58
# 의료_건강                 10.01                19.58
# 소매_편의                 10.01                19.58
# 미용_패션                 10.01                19.58
# 생활서비스                 10.01                19.58
# 교육_학원                 10.01                19.58
# 부동산_숙박                10.01                19.58
# 취미_레저                 10.01                19.58
# 가구_전자기기               10.01                19.58

# %% [markdown]
# <h1>랜덤포레스트 모델 - Standard scaler</h1>

# %%
RFS_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift, scaler_type="standard")
RFS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     13332117.04  35785069.95      0.99     0.95  8651554.61 23381522.31
# 의료_건강   36937166.25 100965022.39      0.99     0.90 20167753.54 52431145.11
# 소매_편의   35274849.06 104257426.71      0.99     0.92 20072113.17 55494357.70
# 미용_패션   14482778.10  32303801.54      0.99     0.94  5712056.09 13396406.21
# 생활서비스   22171937.90  47043819.37      0.98     0.92 10760153.13 25993197.27
# 교육_학원    5885621.55  17741651.89      0.98     0.87  3106720.05  8943190.90
# 부동산_숙박   2966105.34   6059985.01      0.99     0.96  1324086.23  2874049.03
# 취미_레저   33515217.39  92499082.35      0.98     0.90 12109015.25 33858050.88
# 가구_전자기기 28343487.43  90740385.53      0.98     0.80 12691207.09 38519465.95
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.67            9.88      3               35.35
# 의료_건강               4.10           10.70      3               35.35
# 소매_편의               4.52           12.38      3               35.35
# 미용_패션               6.49           16.10      3               35.35
# 생활서비스               7.33           17.72      3               35.35
# 교육_학원               8.22           22.42      3               35.35
# 부동산_숙박             11.60           23.61      3               35.35
# 취미_레저              10.04           26.58      3               35.35
# 가구_전자기기            11.85           35.35      3               35.35
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    9.88                19.42
# 의료_건강                  9.88                19.42
# 소매_편의                  9.88                19.42
# 미용_패션                  9.88                19.42
# 생활서비스                  9.88                19.42
# 교육_학원                  9.88                19.42
# 부동산_숙박                 9.88                19.42
# 취미_레저                  9.88                19.42
# 가구_전자기기                9.88                19.42

# %% [markdown]
# <h1>랜덤포레스트 모델 - Min-Max scaler</h1>

# %%
RFM_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift, scaler_type="minmax")
RFM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     13247020.53  36323936.24      0.99     0.95  8644816.65 23770718.57
# 의료_건강   36921353.95 100540410.37      0.99     0.90 20215333.52 52493279.71
# 소매_편의   35546038.05 104334357.45      0.99     0.92 20197349.73 55990123.00
# 미용_패션   14646094.38  31994129.72      0.99     0.94  5761938.97 13413861.81
# 생활서비스   22021472.92  47592018.31      0.98     0.91 10710360.97 26053047.46
# 교육_학원    5881319.65  18072143.29      0.98     0.86  3103701.52  8942589.42
# 부동산_숙박   2819271.31   6093168.35      0.99     0.96  1323958.68  2935236.70
# 취미_레저   32972748.63  92859633.24      0.98     0.90 11964646.01 33829527.78
# 가구_전자기기 28106891.08  91559910.23      0.98     0.80 12783246.65 38872994.76
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.66           10.05      3               35.67
# 의료_건강               4.11           10.71      3               35.67
# 소매_편의               4.55           12.49      3               35.67
# 미용_패션               6.55           16.13      3               35.67
# 생활서비스               7.30           17.76      3               35.67
# 교육_학원               8.21           22.42      3               35.67
# 부동산_숙박             11.60           24.12      3               35.67
# 취미_레저               9.92           26.56      3               35.67
# 가구_전자기기            11.94           35.67      3               35.67
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   10.05                19.55
# 의료_건강                 10.05                19.55
# 소매_편의                 10.05                19.55
# 미용_패션                 10.05                19.55
# 생활서비스                 10.05                19.55
# 교육_학원                 10.05                19.55
# 부동산_숙박                10.05                19.55
# 취미_레저                 10.05                19.55
# 가구_전자기기               10.05                19.55

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : None <h1>

# %%
GBN_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift)
GBN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     34087104.84  39540367.19      0.95     0.94 23889109.01 26774725.65
# 의료_건강   82660346.74  99842472.49      0.93     0.90 53057447.61 56033511.54
# 소매_편의   85466150.19 112821083.22      0.95     0.91 54829866.67 62518830.57
# 미용_패션   30602889.09  35679445.54      0.96     0.93 15450948.12 15751501.52
# 생활서비스   47348925.96  48833029.11      0.90     0.91 27810692.16 28159942.96
# 교육_학원   13492065.85  17916318.84      0.89     0.87  8430383.37  9691421.95
# 부동산_숙박   2632355.45   6959566.19      0.99     0.95  1713703.19  3388820.80
# 취미_레저   56122521.56 103151694.21      0.96     0.88 29670247.10 37081713.80
# 가구_전자기기 59564420.42  93132652.04      0.91     0.79 33235813.03 41850103.04
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                10.13           11.32      3               38.40
# 의료_건강              10.78           11.43      3               38.40
# 소매_편의              12.34           13.94      3               38.40
# 미용_패션              17.56           18.94      3               38.40
# 생활서비스              18.94           19.20      3               38.40
# 교육_학원              22.30           24.30      3               38.40
# 부동산_숙박             15.02           27.84      3               38.40
# 취미_레저              24.60           29.12      3               38.40
# 가구_전자기기            31.03           38.40      3               38.40
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   11.32                21.61
# 의료_건강                 11.32                21.61
# 소매_편의                 11.32                21.61
# 미용_패션                 11.32                21.61
# 생활서비스                 11.32                21.61
# 교육_학원                 11.32                21.61
# 부동산_숙박                11.32                21.61
# 취미_레저                 11.32                21.61
# 가구_전자기기               11.32                21.61

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : Standard <h1>

# %%
GBS_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift, scaler_type="standard")
GBS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     34087104.84  39587001.67      0.95     0.94 23889109.01 26782298.90
# 의료_건강   82660346.74 101470579.76      0.93     0.90 53057447.61 56090972.96
# 소매_편의   85466150.19 112867501.64      0.95     0.91 54829866.67 62556525.13
# 미용_패션   30602889.09  35426040.20      0.96     0.93 15450948.12 15660233.47
# 생활서비스   47348925.96  49086651.86      0.90     0.91 27810692.16 28233413.67
# 교육_학원   13492065.85  18206343.82      0.89     0.86  8430383.37  9732628.29
# 부동산_숙박   2632355.45   6923712.89      0.99     0.95  1713703.19  3450729.39
# 취미_레저   56122521.56 105275684.10      0.96     0.87 29670247.10 37338434.20
# 가구_전자기기 59564420.42  93223787.03      0.91     0.79 33235813.03 41866050.79
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                10.13           11.32      3               38.42
# 의료_건강              10.78           11.44      3               38.42
# 소매_편의              12.34           13.95      3               38.42
# 미용_패션              17.56           18.83      3               38.42
# 생활서비스              18.94           19.25      3               38.42
# 교육_학원              22.30           24.40      3               38.42
# 부동산_숙박             15.02           28.35      3               38.42
# 취미_레저              24.60           29.32      3               38.42
# 가구_전자기기            31.03           38.42      3               38.42
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   11.32                21.70
# 의료_건강                 11.32                21.70
# 소매_편의                 11.32                21.70
# 미용_패션                 11.32                21.70
# 생활서비스                 11.32                21.70
# 교육_학원                 11.32                21.70
# 부동산_숙박                11.32                21.70
# 취미_레저                 11.32                21.70
# 가구_전자기기               11.32                21.70

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : MinMax <h1>

# %%
GBM_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift, scaler_type="minmax")
GBM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     34087104.84  39660399.26      0.95     0.94 23889109.01 26816536.31
# 의료_건강   82660346.74 100985067.15      0.93     0.90 53057447.61 56070446.83
# 소매_편의   85472655.36 112800805.53      0.95     0.91 54838820.75 62542086.22
# 미용_패션   30602889.09  35427066.86      0.96     0.93 15450948.12 15664211.13
# 생활서비스   47348925.96  48963047.29      0.90     0.91 27810692.16 28253402.72
# 교육_학원   13293954.04  17813023.01      0.90     0.87  8400156.70  9655806.37
# 부동산_숙박   2632355.45   6850177.46      0.99     0.95  1713703.19  3413803.63
# 취미_레저   56122560.50 104612931.12      0.96     0.87 29670460.35 37276518.21
# 가구_전자기기 59564420.42  94452197.11      0.91     0.78 33235813.03 42023039.13
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                10.13           11.34      3               38.56
# 의료_건강              10.78           11.44      3               38.56
# 소매_편의              12.34           13.95      3               38.56
# 미용_패션              17.56           18.83      3               38.56
# 생활서비스              18.94           19.26      3               38.56
# 교육_학원              22.22           24.21      3               38.56
# 부동산_숙박             15.02           28.05      3               38.56
# 취미_레저              24.60           29.27      3               38.56
# 가구_전자기기            31.03           38.56      3               38.56
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   11.34                21.66
# 의료_건강                 11.34                21.66
# 소매_편의                 11.34                21.66
# 미용_패션                 11.34                21.66
# 생활서비스                 11.34                21.66
# 교육_학원                 11.34                21.66
# 부동산_숙박                11.34                21.66
# 취미_레저                 11.34                21.66
# 가구_전자기기               11.34                21.66

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : None <h1>

# %%
LGN_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift)
LGN_result.iloc[:,4:]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000282 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2163
# [LightGBM] [Info] Number of data points in the train set: 6323, number of used features: 12
# [LightGBM] [Info] Start training from score 146800825.020085
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 6410, number of used features: 12
# [LightGBM] [Info] Start training from score 444264470.047426
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 6429, number of used features: 12
# [LightGBM] [Info] Start training from score 235911555.159589
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2163
# [LightGBM] [Info] Number of data points in the train set: 6314, number of used features: 12
# [LightGBM] [Info] Start training from score 492134915.605638
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2162
# [LightGBM] [Info] Number of data points in the train set: 5460, number of used features: 12
# [LightGBM] [Info] Start training from score 107092026.168315
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000280 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2163
# [LightGBM] [Info] Number of data points in the train set: 6044, number of used features: 12
# [LightGBM] [Info] Start training from score 37811349.447551
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 6400, number of used features: 12
# [LightGBM] [Info] Start training from score 87966102.132656
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000284 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 5996, number of used features: 12
# [LightGBM] [Info] Start training from score 120618917.140427
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000160 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1205
# [LightGBM] [Info] Number of data points in the train set: 459, number of used features: 12
# [LightGBM] [Info] Start training from score 11412908.936819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     25592671.81  36107484.99      0.97     0.95 17714028.77 23566885.02
# 의료_건강   71881581.97 105574949.70      0.95     0.89 43035294.88 55418250.63
# 소매_편의   79898000.59 101321782.57      0.96     0.93 45299844.65 57186671.30
# 생활서비스   38800885.60  46539610.22      0.93     0.92 21748918.13 26366740.53
# 미용_패션   28877484.92  39762670.07      0.96     0.91 12001309.72 15340062.76
# 교육_학원   10208682.04  16577941.05      0.94     0.89  6424865.25  8852628.76
# 취미_레저   68402246.47  88876571.07      0.93     0.91 28381471.84 37311436.97
# 부동산_숙박   6849346.92   8300154.63      0.94     0.92  2723215.60  4492148.72
# 가구_전자기기 45806348.80  93372647.55      0.95     0.79 24827627.36 40710938.87
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.51            9.96      3               37.36
# 의료_건강               8.74           11.31      3               37.36
# 소매_편의              10.20           12.75      3               37.36
# 생활서비스              14.82           17.98      3               37.36
# 미용_패션              13.64           18.44      3               37.36
# 교육_학원              16.99           22.19      3               37.36
# 취미_레저              23.53           29.30      3               37.36
# 부동산_숙박             23.86           36.91      3               37.36
# 가구_전자기기            23.18           37.36      3               37.36
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    9.96                21.80
# 의료_건강                  9.96                21.80
# 소매_편의                  9.96                21.80
# 생활서비스                  9.96                21.80
# 미용_패션                  9.96                21.80
# 교육_학원                  9.96                21.80
# 취미_레저                  9.96                21.80
# 부동산_숙박                 9.96                21.80
# 가구_전자기기                9.96                21.80

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : Standard <h1>

# %%
LGS_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift, scaler_type="standard")
LGS_result.iloc[:,4:]
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000369 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 6323, number of used features: 12
# [LightGBM] [Info] Start training from score 146800825.020085
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000376 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 6410, number of used features: 12
# [LightGBM] [Info] Start training from score 444264470.047426
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000326 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 6429, number of used features: 12
# [LightGBM] [Info] Start training from score 235911555.159589
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 6314, number of used features: 12
# [LightGBM] [Info] Start training from score 492134915.605638
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000358 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2163
# [LightGBM] [Info] Number of data points in the train set: 5460, number of used features: 12
# [LightGBM] [Info] Start training from score 107092026.168315
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000354 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 6044, number of used features: 12
# [LightGBM] [Info] Start training from score 37811349.447551
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2166
# [LightGBM] [Info] Number of data points in the train set: 6400, number of used features: 12
# [LightGBM] [Info] Start training from score 87966102.132656
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000384 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 5996, number of used features: 12
# [LightGBM] [Info] Start training from score 120618917.140427
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1183
# [LightGBM] [Info] Number of data points in the train set: 459, number of used features: 12
# [LightGBM] [Info] Start training from score 11412908.936819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     25320766.99  36263853.70      0.97     0.95 17525416.76 23681247.84
# 의료_건강   71682496.97 106949286.25      0.95     0.89 43039103.59 55166671.24
# 소매_편의   80477376.59  99968742.01      0.96     0.93 45134295.92 57229759.59
# 생활서비스   38807859.38  46817445.93      0.93     0.92 21763164.15 26396488.22
# 미용_패션   28712907.29  39003873.95      0.96     0.91 12049141.36 15290931.56
# 교육_학원   10106919.31  16515572.55      0.94     0.89  6404876.43  8869717.81
# 취미_레저   68615543.04  88761047.53      0.93     0.91 28405060.71 37519422.79
# 가구_전자기기 45450582.15  92680040.40      0.95     0.79 24794517.55 40722233.85
# 부동산_숙박   6698480.25   8417979.02      0.94     0.92  2637553.26  4557402.05
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.43           10.01      3               37.45
# 의료_건강               8.75           11.25      3               37.45
# 소매_편의              10.16           12.76      3               37.45
# 생활서비스              14.82           18.00      3               37.45
# 미용_패션              13.70           18.38      3               37.45
# 교육_학원              16.94           22.24      3               37.45
# 취미_레저              23.55           29.46      3               37.45
# 가구_전자기기            23.15           37.37      3               37.45
# 부동산_숙박             23.11           37.45      3               37.45
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   10.01                21.88
# 의료_건강                 10.01                21.88
# 소매_편의                 10.01                21.88
# 생활서비스                 10.01                21.88
# 미용_패션                 10.01                21.88
# 교육_학원                 10.01                21.88
# 취미_레저                 10.01                21.88
# 가구_전자기기               10.01                21.88
# 부동산_숙박                10.01                21.88

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : MinMax <h1>

# %%
LGM_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift, scaler_type="minmax")
LGM_result.iloc[:,4:]
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000253 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2160
# [LightGBM] [Info] Number of data points in the train set: 6323, number of used features: 12
# [LightGBM] [Info] Start training from score 146800825.020085
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000267 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2161
# [LightGBM] [Info] Number of data points in the train set: 6410, number of used features: 12
# [LightGBM] [Info] Start training from score 444264470.047426
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000262 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2161
# [LightGBM] [Info] Number of data points in the train set: 6429, number of used features: 12
# [LightGBM] [Info] Start training from score 235911555.159589
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000280 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2160
# [LightGBM] [Info] Number of data points in the train set: 6314, number of used features: 12
# [LightGBM] [Info] Start training from score 492134915.605638
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000242 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2159
# [LightGBM] [Info] Number of data points in the train set: 5460, number of used features: 12
# [LightGBM] [Info] Start training from score 107092026.168315
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000257 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2160
# [LightGBM] [Info] Number of data points in the train set: 6044, number of used features: 12
# [LightGBM] [Info] Start training from score 37811349.447551
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000289 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2162
# [LightGBM] [Info] Number of data points in the train set: 6400, number of used features: 12
# [LightGBM] [Info] Start training from score 87966102.132656
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000268 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2161
# [LightGBM] [Info] Number of data points in the train set: 5996, number of used features: 12
# [LightGBM] [Info] Start training from score 120618917.140427
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000105 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1196
# [LightGBM] [Info] Number of data points in the train set: 459, number of used features: 12
# [LightGBM] [Info] Start training from score 11412908.936819
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     25819963.10  36522291.24      0.97     0.94 17763548.14 23877361.15
# 의료_건강   72104981.42 105797993.38      0.95     0.89 43173156.56 55077710.54
# 소매_편의   80250827.32 100713882.19      0.96     0.93 45220900.08 57050043.77
# 미용_패션   29174918.23  39529001.30      0.96     0.91 12040707.17 15128927.83
# 생활서비스   38664532.31  47578862.76      0.94     0.91 21725935.78 26842805.88
# 교육_학원   10080966.25  16681691.79      0.94     0.88  6400087.02  8917574.03
# 취미_레저   68349700.88  88471213.89      0.93     0.91 28421766.54 37174515.69
# 부동산_숙박   6849346.92   8300154.63      0.94     0.92  2723215.60  4492148.72
# 가구_전자기기 46239419.48  94265432.85      0.94     0.78 25061517.79 41076807.54
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.53           10.09      3               37.70
# 의료_건강               8.77           11.24      3               37.70
# 소매_편의              10.18           12.72      3               37.70
# 미용_패션              13.69           18.19      3               37.70
# 생활서비스              14.80           18.30      3               37.70
# 교육_학원              16.93           22.36      3               37.70
# 취미_레저              23.56           29.19      3               37.70
# 부동산_숙박             23.86           36.91      3               37.70
# 가구_전자기기            23.40           37.70      3               37.70
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                   10.09                21.86
# 의료_건강                 10.09                21.86
# 소매_편의                 10.09                21.86
# 미용_패션                 10.09                21.86
# 생활서비스                 10.09                21.86
# 교육_학원                 10.09                21.86
# 취미_레저                 10.09                21.86
# 부동산_숙박                10.09                21.86
# 가구_전자기기               10.09                21.86

# %% [markdown]
# <h1>SVR - Scaler : None <h1>

# %%
SVRN_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift)
SVRN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   327729071.38 325070425.73     -0.03    -0.02 204047731.23
# 식음료     154742787.92 159277058.39     -0.05    -0.05 106715120.94
# 소매_편의   409573986.11 385911411.43     -0.03    -0.04 219555155.13
# 생활서비스   155573808.34 165221094.85     -0.05    -0.04  90765457.28
# 교육_학원    43592071.18  51509549.71     -0.10    -0.10  26211708.90
# 미용_패션   155035270.51 138645144.48     -0.09    -0.09  65970769.64
# 취미_레저   274460046.35 300399101.65     -0.05    -0.05  93268159.66
# 가구_전자기기 208806430.55 215341342.06     -0.13    -0.13  93786327.39
# 부동산_숙박   29210968.84  31543591.97     -0.11    -0.11  10737774.99
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   202794530.66            41.46           41.37      3
# 식음료     106738101.15            45.24           45.12      3
# 소매_편의   219364345.91            49.42           48.92      3
# 생활서비스    94085418.75            61.83           64.14      3
# 교육_학원    28093452.91            69.32           70.43      3
# 미용_패션    61047182.19            75.00           73.39      3
# 취미_레저    99879856.98            77.32           78.42      3
# 가구_전자기기  96034821.12            87.58           88.13      3
# 부동산_숙박   11581414.11            94.08           95.16      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 95.16               41.37                67.23
# 식음료                   95.16               41.37                67.23
# 소매_편의                 95.16               41.37                67.23
# 생활서비스                 95.16               41.37                67.23
# 교육_학원                 95.16               41.37                67.23
# 미용_패션                 95.16               41.37                67.23
# 취미_레저                 95.16               41.37                67.23
# 가구_전자기기               95.16               41.37                67.23
# 부동산_숙박                95.16               41.37                67.23

# %% [markdown]
# <h1>SVR - Scaler : Standard <h1>

# %%
SVRS_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift, scaler_type="standard")
SVRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   327729509.11 325070871.75     -0.03    -0.02 204048312.59
# 식음료     154743447.19 159277676.59     -0.05    -0.05 106715843.59
# 소매_편의   409574435.68 385911896.99     -0.03    -0.04 219555734.92
# 생활서비스   155574333.31 165221609.36     -0.05    -0.04  90766137.90
# 교육_학원    43592809.90  51510199.41     -0.10    -0.10  26212359.60
# 미용_패션   155035615.89 138645504.20     -0.09    -0.09  65971148.70
# 취미_레저   274460242.24 300399303.30     -0.05    -0.05  93268481.69
# 가구_전자기기 208806723.75 215341613.10     -0.13    -0.13  93786657.97
# 부동산_숙박   29210986.04  31543608.54     -0.11    -0.11  10737787.73
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   202795105.17            41.46           41.37      3
# 식음료     106738803.92            45.24           45.12      3
# 소매_편의   219364934.41            49.42           48.92      3
# 생활서비스    94086124.13            61.83           64.14      3
# 교육_학원    28094109.14            69.32           70.43      3
# 미용_패션    61047564.86            75.00           73.39      3
# 취미_레저    99880188.19            77.32           78.42      3
# 가구_전자기기  96035131.21            87.58           88.13      3
# 부동산_숙박   11581429.26            94.08           95.16      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 95.16               41.37                67.23
# 식음료                   95.16               41.37                67.23
# 소매_편의                 95.16               41.37                67.23
# 생활서비스                 95.16               41.37                67.23
# 교육_학원                 95.16               41.37                67.23
# 미용_패션                 95.16               41.37                67.23
# 취미_레저                 95.16               41.37                67.23
# 가구_전자기기               95.16               41.37                67.23
# 부동산_숙박                95.16               41.37                67.23

# %% [markdown]
# <h1>SVR - Scaler : MinMax <h1>

# %%
SVRM_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift, scaler_type="minmax")
SVRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   327729509.11 325070871.75     -0.03    -0.02 204048312.59
# 식음료     154743447.19 159277676.59     -0.05    -0.05 106715843.59
# 소매_편의   409574435.68 385911896.99     -0.03    -0.04 219555734.92
# 생활서비스   155574333.31 165221609.36     -0.05    -0.04  90766137.90
# 교육_학원    43592809.90  51510199.41     -0.10    -0.10  26212359.60
# 미용_패션   155035615.89 138645504.20     -0.09    -0.09  65971148.70
# 취미_레저   274460242.24 300399303.30     -0.05    -0.05  93268481.69
# 가구_전자기기 208806723.75 215341613.10     -0.13    -0.13  93786657.97
# 부동산_숙박   29210986.04  31543608.54     -0.11    -0.11  10737787.73
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   202795105.17            41.46           41.37      3
# 식음료     106738803.92            45.24           45.12      3
# 소매_편의   219364934.41            49.42           48.92      3
# 생활서비스    94086124.13            61.83           64.14      3
# 교육_학원    28094109.14            69.32           70.43      3
# 미용_패션    61047564.86            75.00           73.39      3
# 취미_레저    99880188.19            77.32           78.42      3
# 가구_전자기기  96035131.21            87.58           88.13      3
# 부동산_숙박   11581429.26            94.08           95.16      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 95.16               41.37                67.23
# 식음료                   95.16               41.37                67.23
# 소매_편의                 95.16               41.37                67.23
# 생활서비스                 95.16               41.37                67.23
# 교육_학원                 95.16               41.37                67.23
# 미용_패션                 95.16               41.37                67.23
# 취미_레저                 95.16               41.37                67.23
# 가구_전자기기               95.16               41.37                67.23
# 부동산_숙박                95.16               41.37                67.23

# %% [markdown]
# <h1>MLPR - Scaler : None <h1>

# %%
MLPN_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift)
MLPN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   108729932.32 109442738.12      0.89     0.88 61638983.22 59994559.77
# 소매_편의   117428532.67 128905768.37      0.91     0.88 65324805.56 67273183.69
# 식음료      52414660.83  53149573.39      0.88     0.88 34992939.02 35944186.85
# 생활서비스    65311984.85  54670370.06      0.81     0.89 31561961.81 28826378.77
# 미용_패션    50513059.67  44818562.19      0.88     0.89 19079363.29 17275521.29
# 교육_학원    18498558.69  20984817.67      0.80     0.82 10267451.42 10840945.89
# 취미_레저   116862237.16 112065587.64      0.81     0.85 38117528.05 37769692.40
# 가구_전자기기  83330065.92 100603103.46      0.82     0.75 38600263.52 43309938.75
# 부동산_숙박    9339517.40  11182386.63      0.89     0.86  4386143.38  5132092.38
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              12.52           12.24      3               42.17
# 소매_편의              14.70           15.00      3               42.17
# 식음료                14.83           15.19      3               42.17
# 생활서비스              21.50           19.65      3               42.17
# 미용_패션              21.69           20.77      3               42.17
# 교육_학원              27.15           27.18      3               42.17
# 취미_레저              31.60           29.66      3               42.17
# 가구_전자기기            36.04           39.74      3               42.17
# 부동산_숙박             38.43           42.17      3               42.17
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 12.24                24.62
# 소매_편의                 12.24                24.62
# 식음료                   12.24                24.62
# 생활서비스                 12.24                24.62
# 미용_패션                 12.24                24.62
# 교육_학원                 12.24                24.62
# 취미_레저                 12.24                24.62
# 가구_전자기기               12.24                24.62
# 부동산_숙박                12.24                24.62

# %% [markdown]
# <h1>MLPR - Scaler : Standard <h1>

# %%
MLPS_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift, scaler_type="standard")
MLPS_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 교육_학원    56126409.75  63283996.36     -0.83    -0.66  37774177.22
# 미용_패션   172616827.96 156739060.77     -0.35    -0.39  87930106.93
# 생활서비스   211135530.46 218280370.11     -0.93    -0.82 146763057.32
# 식음료     280151873.46 283159178.65     -2.43    -2.31 235874012.94
# 가구_전자기기 223614746.90 230024844.63     -0.30    -0.29 107066725.73
# 취미_레저   293576224.86 319227141.60     -0.20    -0.19 120595035.23
# 의료_건강   588977651.10 586018199.43     -2.31    -2.33 492101694.00
# 소매_편의   599620128.89 586313073.77     -1.22    -1.41 444225784.42
# 부동산_숙박   29974378.99  32303242.05     -0.17    -0.17  11412695.09
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 교육_학원    39851808.43            99.90           99.91      3
# 미용_패션    83149732.18            99.96           99.96      3
# 생활서비스   146646109.60            99.97           99.98      3
# 식음료     236539623.55            99.98           99.98      3
# 가구_전자기기 108948526.04            99.98           99.98      3
# 취미_레저   127335686.52            99.98           99.98      3
# 의료_건강   490123919.92            99.99           99.99      3
# 소매_편의   448337753.12            99.99           99.99      3
# 부동산_숙박   12170389.71           100.00          100.00      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 교육_학원                100.00               99.91                99.97
# 미용_패션                100.00               99.91                99.97
# 생활서비스                100.00               99.91                99.97
# 식음료                  100.00               99.91                99.97
# 가구_전자기기              100.00               99.91                99.97
# 취미_레저                100.00               99.91                99.97
# 의료_건강                100.00               99.91                99.97
# 소매_편의                100.00               99.91                99.97
# 부동산_숙박               100.00               99.91                99.97

# %% [markdown]
# <h1>MLPR - Scaler : MinMax <h1>

# %%
MLPM_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift, scaler_type="minmax")
MLPM_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 교육_학원    56156433.86  63312868.43     -0.83    -0.66  37795788.59
# 미용_패션   172648610.63 156769334.53     -0.35    -0.39  87948475.97
# 생활서비스   211163560.42 218307117.28     -0.93    -0.82 146784738.58
# 식음료     280174925.01 283180613.28     -2.43    -2.31 235890373.41
# 가구_전자기기 223638746.23 230046639.44     -0.30    -0.29 107077628.97
# 취미_레저   293590723.35 319241348.22     -0.20    -0.19 120603571.21
# 의료_건강   588996675.17 586035708.34     -2.31    -2.33 492117150.62
# 소매_편의   599642681.21 586334977.28     -1.22    -1.41 444245598.36
# 부동산_숙박   29974538.59  32303395.37     -0.17    -0.17  11412628.24
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 교육_학원    39872765.29            99.96           99.96      3
# 미용_패션    83165038.41            99.98           99.98      3
# 생활서비스   146665700.31            99.99           99.99      3
# 식음료     236554446.19            99.99           99.99      3
# 가구_전자기기 108957137.29            99.99           99.99      3
# 취미_레저   127342867.07            99.99           99.99      3
# 의료_건강   490137683.02           100.00          100.00      3
# 소매_편의   448355994.45           100.00          100.00      3
# 부동산_숙박   12170310.33           100.00          100.00      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 교육_학원                100.00               99.96                99.99
# 미용_패션                100.00               99.96                99.99
# 생활서비스                100.00               99.96                99.99
# 식음료                  100.00               99.96                99.99
# 가구_전자기기              100.00               99.96                99.99
# 취미_레저                100.00               99.96                99.99
# 의료_건강                100.00               99.96                99.99
# 소매_편의                100.00               99.96                99.99
# 부동산_숙박               100.00               99.96                99.99

# %% [markdown]
# <h1>ESM - Scaler : None <h1>

# %%
ESN_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift)
ESN_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.326e+19, tolerance: 1.457e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.285e+19, tolerance: 1.040e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.098e+18, tolerance: 1.469e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.589e+19, tolerance: 6.613e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.887e+19, tolerance: 2.105e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.991e+17, tolerance: 1.043e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.914e+18, tolerance: 1.413e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.061e+19, tolerance: 4.296e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.900e+16, tolerance: 3.526e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   106587821.51 106966364.75      0.89     0.89 60866854.26 59250538.22
# 소매_편의   115599858.89 127410846.31      0.92     0.89 63164812.82 65870241.70
# 식음료      50142697.21  51460725.10      0.89     0.89 33674869.74 34946976.26
# 생활서비스    64725813.71  54011395.15      0.82     0.89 32377484.81 29533469.96
# 미용_패션    49702837.50  45182956.55      0.89     0.88 19853383.93 18106404.95
# 교육_학원    18169467.65  20701829.31      0.81     0.82 10075517.76 10624902.21
# 취미_레저   116337084.65 112000333.61      0.81     0.85 39634766.37 39134175.96
# 가구_전자기기  83114641.13 100661165.40      0.82     0.75 39081254.99 43782454.80
# 부동산_숙박    9074677.06  10906087.18      0.89     0.87  4752218.37  5800921.73
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              12.37           12.09      3               47.66
# 소매_편의              14.22           14.69      3               47.66
# 식음료                14.27           14.77      3               47.66
# 생활서비스              22.06           20.13      3               47.66
# 미용_패션              22.57           21.77      3               47.66
# 교육_학원              26.65           26.64      3               47.66
# 취미_레저              32.86           30.73      3               47.66
# 가구_전자기기            36.49           40.18      3               47.66
# 부동산_숙박             41.64           47.66      3               47.66
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 12.09                25.41
# 소매_편의                 12.09                25.41
# 식음료                   12.09                25.41
# 생활서비스                 12.09                25.41
# 미용_패션                 12.09                25.41
# 교육_학원                 12.09                25.41
# 취미_레저                 12.09                25.41
# 가구_전자기기               12.09                25.41
# 부동산_숙박                12.09                25.41

# %% [markdown]
# <h1>ESM - Scaler : standard <h1>

# %%
ESS_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift, scaler_type="standard")
ESS_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.922e+19, tolerance: 1.457e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.666e+20, tolerance: 1.040e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.419e+19, tolerance: 1.469e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.059e+19, tolerance: 6.613e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.811e+19, tolerance: 2.105e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.221e+18, tolerance: 1.043e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.528e+19, tolerance: 1.413e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.956e+19, tolerance: 4.296e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.868e+16, tolerance: 3.526e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   109272207.00 110281758.52      0.89     0.88 66683763.04 68264464.74
# 소매_편의   165164145.96 150714145.97      0.83     0.84 69057438.84 71409236.52
# 식음료      50922791.97  55464927.34      0.89     0.87 35442723.16 38359078.62
# 생활서비스    59431538.72  57767134.32      0.85     0.87 32959476.18 33084827.42
# 미용_패션    49016599.92  50026741.62      0.89     0.86 21806827.36 21298591.36
# 교육_학원    17599766.61  21340218.20      0.82     0.81 10547378.87 11530018.23
# 취미_레저   102317286.62 104952739.28      0.85     0.87 39564235.59 42020919.01
# 가구_전자기기  77307801.73  89610651.08      0.84     0.80 40432438.85 45649797.35
# 부동산_숙박    9140900.84  10822973.26      0.89     0.87  4531465.84  5645589.29
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              13.55           13.93      3               46.39
# 소매_편의              15.54           15.93      3               46.39
# 식음료                15.02           16.21      3               46.39
# 생활서비스              22.45           22.56      3               46.39
# 미용_패션              24.79           25.60      3               46.39
# 교육_학원              27.89           28.91      3               46.39
# 취미_레저              32.80           32.99      3               46.39
# 가구_전자기기            37.75           41.89      3               46.39
# 부동산_숙박             39.70           46.39      3               46.39
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 13.93                27.16
# 소매_편의                 13.93                27.16
# 식음료                   13.93                27.16
# 생활서비스                 13.93                27.16
# 미용_패션                 13.93                27.16
# 교육_학원                 13.93                27.16
# 취미_레저                 13.93                27.16
# 가구_전자기기               13.93                27.16
# 부동산_숙박                13.93                27.16

# %% [markdown]
# <h1>ESM - Scaler : MinMax <h1>

# %%
ESM_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift, scaler_type="minmax")
ESM_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.952e+18, tolerance: 1.457e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.014e+20, tolerance: 1.040e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.555e+19, tolerance: 1.469e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.034e+20, tolerance: 6.613e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.256e+19, tolerance: 2.105e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.036e+17, tolerance: 1.043e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.597e+19, tolerance: 1.413e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.885e+19, tolerance: 4.296e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.254e+15, tolerance: 3.526e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   317493900.56 315456324.00      0.04     0.04 204268800.31
# 식음료     145127184.10 149738713.40      0.08     0.07 105522851.31
# 소매_편의   397383357.56 372896751.08      0.03     0.03 224477644.17
# 생활서비스   149190501.02 159005408.86      0.03     0.03  93128306.15
# 교육_학원    40626614.53  48230651.59      0.04     0.04  27666667.74
# 미용_패션   146318599.72 130979042.68      0.03     0.03  76873981.68
# 취미_레저   264403300.95 289369093.60      0.02     0.02 106693008.88
# 가구_전자기기 192932022.93 199261161.65      0.03     0.03 111713195.56
# 부동산_숙박   25208193.24  27438979.57      0.17     0.16  12952064.28
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   203255764.24            41.51           41.47      3
# 식음료     105686582.22            44.73           44.67      3
# 소매_편의   222876120.28            50.53           49.71      3
# 생활서비스    97375535.54            63.44           66.39      3
# 교육_학원    29116502.07            73.17           73.00      3
# 미용_패션    71910489.02            87.39           86.45      3
# 취미_레저   112250208.72            88.45           88.14      3
# 가구_전자기기 114547721.44           104.32          105.12      3
# 부동산_숙박   13393944.47           113.49          110.05      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                110.05               41.47                73.89
# 식음료                  110.05               41.47                73.89
# 소매_편의                110.05               41.47                73.89
# 생활서비스                110.05               41.47                73.89
# 교육_학원                110.05               41.47                73.89
# 미용_패션                110.05               41.47                73.89
# 취미_레저                110.05               41.47                73.89
# 가구_전자기기              110.05               41.47                73.89
# 부동산_숙박               110.05               41.47                73.89

# %%
ESM_result.iloc[:,:]
# Out:
#               Model Scaler             train_mse              test_mse  \
# 의료_건강    ElasticNet   None 100802376892062848.00  99512692350182208.00
# 식음료      ElasticNet   None  21061899566213564.00  22421682291134080.00
# 소매_편의    ElasticNet   None 157913532869202400.00 139051986962682688.00
# 생활서비스    ElasticNet   None  22257805594022120.00  25282720045494004.00
# 교육_학원    ElasticNet   None   1650521808298684.75   2326195752334794.50
# 미용_패션    ElasticNet   None  21409132624919684.00  17155509622665470.00
# 취미_레저    ElasticNet   None  69909105552832144.00  83734472328266912.00
# 가구_전자기기  ElasticNet   None  37222765471769048.00  39705010542392640.00
# 부동산_숙박   ElasticNet   None    635453006396752.88    752897599638724.50
#
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   317493900.56 315456324.00      0.04     0.04 204268800.31
# 식음료     145127184.10 149738713.40      0.08     0.07 105522851.31
# 소매_편의   397383357.56 372896751.08      0.03     0.03 224477644.17
# 생활서비스   149190501.02 159005408.86      0.03     0.03  93128306.15
# 교육_학원    40626614.53  48230651.59      0.04     0.04  27666667.74
# 미용_패션   146318599.72 130979042.68      0.03     0.03  76873981.68
# 취미_레저   264403300.95 289369093.60      0.02     0.02 106693008.88
# 가구_전자기기 192932022.93 199261161.65      0.03     0.03 111713195.56
# 부동산_숙박   25208193.24  27438979.57      0.17     0.16  12952064.28
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   203255764.24            41.51           41.47      3
# 식음료     105686582.22            44.73           44.67      3
# 소매_편의   222876120.28            50.53           49.71      3
# 생활서비스    97375535.54            63.44           66.39      3
# 교육_학원    29116502.07            73.17           73.00      3
# 미용_패션    71910489.02            87.39           86.45      3
# 취미_레저   112250208.72            88.45           88.14      3
# 가구_전자기기 114547721.44           104.32          105.12      3
# 부동산_숙박   13393944.47           113.49          110.05      3
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                110.05               41.47                73.89
# 식음료                  110.05               41.47                73.89
# 소매_편의                110.05               41.47                73.89
# 생활서비스                110.05               41.47                73.89
# 교육_학원                110.05               41.47                73.89
# 미용_패션                110.05               41.47                73.89
# 취미_레저                110.05               41.47                73.89
# 가구_전자기기              110.05               41.47                73.89
# 부동산_숙박               110.05               41.47                73.89

# %%
# 각 데이터프레임의 인덱스를 리셋한 후 새로운 변수로 저장합니다.
ESM_result2 = ESM_result.reset_index()
ESS_result2 = ESS_result.reset_index()
ESN_result2 = ESN_result.reset_index()
MLPM_result2 = MLPM_result.reset_index()
MLPS_result2 = MLPS_result.reset_index()
MLPN_result2 = MLPN_result.reset_index()
SVRS_result2 = SVRS_result.reset_index()
SVRM_result2 = SVRM_result.reset_index()
SVRN_result2 = SVRN_result.reset_index()
LGM_result2 = LGM_result.reset_index()
LGS_result2 = LGS_result.reset_index()
LGN_result2 = LGN_result.reset_index()
GBM_result2 = GBM_result.reset_index()
GBS_result2 = GBS_result.reset_index()
GBN_result2 = GBN_result.reset_index()
RFM_result2 = RFM_result.reset_index()
RFS_result2 = RFS_result.reset_index()
RFN_result2 = RFN_result.reset_index()
LRM_result2 = LRM_result.reset_index()
LRS_result2 = LRS_result.reset_index()
LRN_result2 = LRN_result.reset_index()

# %%
import pandas as pd

# 데이터프레임 목록 생성
df_list = [
    ESM_result2, ESS_result2, ESN_result2,
    MLPM_result2, MLPS_result2, MLPN_result2,
    SVRS_result2, SVRM_result2, SVRN_result2,
    LGM_result2, LGS_result2, LGN_result2,
    GBM_result2, GBS_result2, GBN_result2,
    RFM_result2, RFS_result2, RFN_result2,
    LRM_result2, LRS_result2, LRN_result2
]

# 데이터프레임 이름 목록 생성
df_names = [
    'ESM', 'ESS', 'ESN',
    'MLPM', 'MLPS', 'MLPN',
    'SVRS', 'SVRM', 'SVRN',
    'LGM', 'LGS', 'LGN',
    'GBM', 'GBS', 'GBN',
    'RFM', 'RFS', 'RFN',
    'LRM', 'LRS', 'LRN'
]

# 각 데이터프레임에 대해 Scaler 값을 업데이트
for df, name in zip(df_list, df_names):
    suffix = name[-1]  # 이름에서 마지막 문자를 추출
    if suffix == 'S':
        scaler_value = 'Standard'
    elif suffix == 'M':
        scaler_value = 'MinMax'
    elif suffix == 'N':
        scaler_value = 'Default'
    else:
        continue  # 해당하지 않으면 건너뜀
    
    # Scaler 컬럼 값을 업데이트
    if 'Scaler' in df.columns:
        df['Scaler'] = scaler_value
    else:
        print(f"DataFrame {name} does not have a 'Scaler' column.")

# %%
all_results = [
    ESM_result2, ESS_result2, ESN_result2,
    MLPM_result2, MLPS_result2, MLPN_result2,
    SVRS_result2, SVRM_result2, SVRN_result2,
    LGM_result2, LGS_result2, LGN_result2,
    GBM_result2, GBS_result2, GBN_result2,
    RFM_result2, RFS_result2, RFN_result2,
    LRM_result2, LRS_result2, LRN_result2
]

# 모든 데이터프레임을 행 방향으로 병합
df_combined = pd.concat(all_results, ignore_index=True)

# %%
col = ['Shift', 'Model', 'Scaler', 'index', 'train_r2', 'test_r2', 'train_mse', 'test_mse','train_mae_ratio', 'test_mae_ratio', 'test_mae_ratio_max','test_mae_ratio_min', 'test_mae_ratio_mean', 'train_mae', 'test_mae', 'train_rmse', 'test_rmse']
df_combined = df_combined[col]

# %%
df_combined.to_csv("single_category_shift3.csv", index=False)

# %%
data = pd.read_csv("single_category_shift3.csv")
data.groupby(["Model", "Scaler"])["index"].count()
# Out:
# Model                      Scaler
# ElasticNet                 Default     9
#                            MinMax      9
#                            Standard    9
# GradientBoostingRegressor  Default     9
#                            MinMax      9
#                            Standard    9
# LGBMRegressor              Default     9
#                            MinMax      9
#                            Standard    9
# LinearRegression           Default     9
#                            MinMax      9
#                            Standard    9
# MLPRegressor               Default     9
#                            MinMax      9
#                            Standard    9
# RandomForestRegressor      Default     9
#                            MinMax      9
#                            Standard    9
# SVR                        Default     9
#                            MinMax      9
#                            Standard    9
# Name: index, dtype: int64
