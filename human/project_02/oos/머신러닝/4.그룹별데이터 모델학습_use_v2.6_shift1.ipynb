# %%
import pandas as pd
import numpy as np
import my_def

# %% [markdown]
# <h1>데이터확인 및 가공</h1>
# 업종명 분류 -> 9개의 중분류로 구분

# %%
df = pd.read_csv('Merged_Sales_data_v2.6(shift1).csv')
shift = 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69001 entries, 0 to 69000
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년분기         69001 non-null  int64
#  1   행정동         69001 non-null  object
#  2   업종별카테고리     69001 non-null  object
#  3   월매출(점포)     69001 non-null  int64
#  4   인구수         69001 non-null  float64
#  5   지역생활인구      69001 non-null  float64
#  6   장기외국인       69001 non-null  float64
#  7   단기외국인       69001 non-null  float64
#  8   주차장면적(면)    69001 non-null  float64
#  9   주차장개수(개소)   69001 non-null  float64
#  10  학교수         69001 non-null  float64
#  11  학생수         69001 non-null  float64
#  12  버스정류장수      69001 non-null  float64
#  13  년분기_미룸      69001 non-null  float64
#  14  월매출_shift1  69001 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 7.9+ MB

# %%
df = my_def.reduce_memory_usage(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69001 entries, 0 to 69000
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년분기         69001 non-null  int16
#  1   행정동         69001 non-null  object
#  2   업종별카테고리     69001 non-null  object
#  3   월매출(점포)     69001 non-null  int64
#  4   인구수         69001 non-null  float16
#  5   지역생활인구      69001 non-null  float32
#  6   장기외국인       69001 non-null  float32
#  7   단기외국인       69001 non-null  float32
#  8   주차장면적(면)    69001 non-null  float32
#  9   주차장개수(개소)   69001 non-null  float16
#  10  학교수         69001 non-null  float16
#  11  학생수         69001 non-null  float16
#  12  버스정류장수      69001 non-null  float16
#  13  년분기_미룸      69001 non-null  float16
#  14  월매출_shift1  69001 non-null  float32
# dtypes: float16(6), float32(5), int16(1), int64(1), object(2)
# memory usage: 3.8+ MB
# None

# %%
df[df["업종별카테고리"] == "기타"]
# Out:
# Empty DataFrame
# Columns: [년분기, 행정동, 업종별카테고리, 월매출(점포), 인구수, 지역생활인구, 장기외국인, 단기외국인, 주차장면적(면), 주차장개수(개소), 학교수, 학생수, 버스정류장수, 년분기_미룸, 월매출_shift1]
# Index: []

# %% [markdown]
# <h1>전체업종 선형회귀 분석</h1>

# %%
result_lr_00 = my_def.linear_regression_model(df, scaler_option= 0, shift_value=shift)
result_lr_00
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'None',
#  'train_mse': np.float64(4.5614627319947624e+16),
#  'test_mse': np.float64(5.116062869903287e+16),
#  'train_rmse': np.float64(213575811.65),
#  'test_rmse': np.float64(226187154.14),
#  'train_r2': 0.44,
#  'test_r2': 0.42,
#  'train_mae': np.float64(113861396.08),
#  'test_mae': np.float64(116022886.92),
#  'train_mae_ratio': np.float64(53.61),
#  'test_mae_ratio': np.float64(53.94),
#  'Shift': 1}

# %%
result_lr_01 = my_def.linear_regression_model(df, scaler_option= 1, shift_value=shift)
result_lr_01
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'StandardScaler',
#  'train_mse': np.float64(4.428341185474847e+16),
#  'test_mse': np.float64(4.8082457330073416e+16),
#  'train_rmse': np.float64(210436241.78),
#  'test_rmse': np.float64(219277124.5),
#  'train_r2': 0.46,
#  'test_r2': 0.45,
#  'train_mae': np.float64(113785064.6),
#  'test_mae': np.float64(115847323.0),
#  'train_mae_ratio': np.float64(53.58),
#  'test_mae_ratio': np.float64(53.86),
#  'Shift': 1}

# %%
result_lr_02 = my_def.linear_regression_model(df, scaler_option= 2, shift_value=shift)
result_lr_02
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'MinMaxScaler',
#  'train_mse': np.float64(4.428341035197752e+16),
#  'test_mse': np.float64(4.808245075010895e+16),
#  'train_rmse': np.float64(210436238.21),
#  'test_rmse': np.float64(219277109.5),
#  'train_r2': 0.46,
#  'test_r2': 0.45,
#  'train_mae': np.float64(113785123.35),
#  'test_mae': np.float64(115847374.75),
#  'train_mae_ratio': np.float64(53.58),
#  'test_mae_ratio': np.float64(53.86),
#  'Shift': 1}

# %%
#raise KeyboardInterrupt("실행을 중단합니다.")

# %%
result_rf_00 = my_def.random_forest_model(df, scaler_option= 0, shift_value=shift)
result_rf_00
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'None',
#  'train_mse': np.float64(654131458971698.2),
#  'test_mse': np.float64(5229041647559962.0),
#  'train_rmse': np.float64(25575993.8),
#  'test_rmse': np.float64(72312112.73),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11363633.23),
#  'test_mae': np.float64(30549311.02),
#  'train_mae_ratio': np.float64(5.35),
#  'test_mae_ratio': np.float64(14.2),
#  'Shift': 1}

# %%
result_rf_01 = my_def.random_forest_model(df, scaler_option= 1, shift_value=shift)
result_rf_01
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'StandardScaler',
#  'train_mse': np.float64(650533806520890.4),
#  'test_mse': np.float64(5208305591550180.0),
#  'train_rmse': np.float64(25505564.23),
#  'test_rmse': np.float64(72168591.45),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11362050.95),
#  'test_mae': np.float64(30550991.16),
#  'train_mae_ratio': np.float64(5.35),
#  'test_mae_ratio': np.float64(14.2),
#  'Shift': 1}

# %%
result_rf_02 = my_def.random_forest_model(df, scaler_option= 2, shift_value=shift)
result_rf_02
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'MinMaxScaler',
#  'train_mse': np.float64(654897239906213.6),
#  'test_mse': np.float64(5238950723507328.0),
#  'train_rmse': np.float64(25590960.12),
#  'test_rmse': np.float64(72380596.32),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11366011.53),
#  'test_mae': np.float64(30564714.04),
#  'train_mae_ratio': np.float64(5.35),
#  'test_mae_ratio': np.float64(14.21),
#  'Shift': 1}

# %%
# 결과 딕셔너리들을 리스트에 모읍니다.
results = [result_lr_00, result_lr_01, result_lr_02, result_rf_00, result_rf_01, result_rf_02]

# 리스트를 데이터프레임으로 변환합니다.
df_results = pd.DataFrame(results)

# %%
col = ['Shift', 'Model', 'Scaler', 'train_mse', 'test_mse', 'train_rmse', 'test_rmse',
       'train_r2', 'test_r2', 'train_mae', 'test_mae', 'train_mae_ratio',
       'test_mae_ratio']
df_results = df_results[col]

# %%
df_results
# Out:
#    Shift                  Model          Scaler            train_mse  \
# 0      1       LinearRegression            None 45614627319947624.00
# 1      1       LinearRegression  StandardScaler 44283411854748472.00
# 2      1       LinearRegression    MinMaxScaler 44283410351977520.00
# 3      1  RandomForestRegressor            None   654131458971698.25
# 4      1  RandomForestRegressor  StandardScaler   650533806520890.38
# 5      1  RandomForestRegressor    MinMaxScaler   654897239906213.62
#
#               test_mse   train_rmse    test_rmse  train_r2  test_r2  \
# 0 51160628699032872.00 213575811.65 226187154.14      0.44     0.42
# 1 48082457330073416.00 210436241.78 219277124.50      0.46     0.45
# 2 48082450750108952.00 210436238.21 219277109.50      0.46     0.45
# 3  5229041647559962.00  25575993.80  72312112.73      0.99     0.94
# 4  5208305591550180.00  25505564.23  72168591.45      0.99     0.94
# 5  5238950723507328.00  25590960.12  72380596.32      0.99     0.94
#
#      train_mae     test_mae  train_mae_ratio  test_mae_ratio
# 0 113861396.08 116022886.92            53.61           53.94
# 1 113785064.60 115847323.00            53.58           53.86
# 2 113785123.35 115847374.75            53.58           53.86
# 3  11363633.23  30549311.02             5.35           14.20
# 4  11362050.95  30550991.16             5.35           14.20
# 5  11366011.53  30564714.04             5.35           14.21

# %%
df_results.to_csv("all_category_shift1.csv", index= False)

# %%
raise KeyboardInterrupt("실행을 중단합니다.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 raise KeyboardInterrupt("실행을 중단합니다.")
#
# KeyboardInterrupt: 실행을 중단합니다.

# %% [markdown]
# <h1>업종별카테고리 선형회귀 모델</h1>
# Polynomial Features & Standard Scaler 사용 안함<br>
# 9개 카테고리를 개별로해서 데이터프레임 형태로 저장

# %%
LRN_result = my_def.category_model_evaluation(df, model_index=0, shift_value=shift)
LRN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   84472616.72  74679550.39      0.94     0.94 47053152.22 44362135.28
# 식음료     36142021.96  37578753.12      0.94     0.95 23592437.41 24654943.73
# 소매_편의   83702264.71 102792732.49      0.96     0.94 45507672.93 49362675.38
# 미용_패션   37095749.23  33011705.05      0.94     0.93 15148725.99 13775775.02
# 생활서비스   61426639.91  54148324.74      0.84     0.91 27903098.92 26807125.74
# 교육_학원   12887852.88  15018535.91      0.91     0.89  6913540.71  7370917.20
# 취미_레저   96803081.20  89477373.50      0.87     0.89 31361570.79 30272672.57
# 부동산_숙박   7992679.93   6670231.56      0.92     0.94  3698028.65  3574945.24
# 가구_전자기기 74910619.85  74176184.20      0.86     0.84 34597400.67 34447372.86
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강               9.42            8.95      1               33.58
# 식음료                 9.86           10.15      1               33.58
# 소매_편의              10.20           10.60      1               33.58
# 미용_패션              17.12           16.47      1               33.58
# 생활서비스              18.90           17.69      1               33.58
# 교육_학원              17.90           18.62      1               33.58
# 취미_레저              25.59           25.54      1               33.58
# 부동산_숙박             33.25           29.67      1               33.58
# 가구_전자기기            32.26           33.58      1               33.58
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                  8.95                19.03
# 식음료                    8.95                19.03
# 소매_편의                  8.95                19.03
# 미용_패션                  8.95                19.03
# 생활서비스                  8.95                19.03
# 교육_학원                  8.95                19.03
# 취미_레저                  8.95                19.03
# 부동산_숙박                 8.95                19.03
# 가구_전자기기                8.95                19.03

# %% [markdown]
# <h1>선형회귀 - Standard Scaler 적용</h1>

# %%
LRS_result = my_def.category_model_evaluation(df, model_index=0, scaler_type="standard", shift_value=shift)
LRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   76873225.20  73786254.48      0.95     0.94 43006956.51 43591878.96
# 식음료     31548846.57  35211708.12      0.96     0.95 20944619.75 23245167.37
# 소매_편의   77131864.46  98207701.78      0.96     0.95 43111345.75 49119434.49
# 미용_패션   33534833.73  34535231.18      0.95     0.92 13860453.29 13453803.98
# 생활서비스   51107608.66  52742487.89      0.89     0.92 24969966.10 25729218.43
# 교육_학원   11911669.12  14659171.76      0.92     0.89  6647412.26  7213974.49
# 취미_레저   77980941.84  81636546.52      0.91     0.91 29337269.93 31013415.40
# 부동산_숙박   6353025.22   7342375.20      0.95     0.93  3007749.79  3806608.30
# 가구_전자기기 65237728.80 166699381.59      0.89     0.20 30315642.87 34094860.99
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강               8.61            8.79      1               33.23
# 식음료                 8.75            9.57      1               33.23
# 소매_편의               9.66           10.55      1               33.23
# 미용_패션              15.67           16.09      1               33.23
# 생활서비스              16.92           16.98      1               33.23
# 교육_학원              17.21           18.23      1               33.23
# 취미_레저              23.94           26.17      1               33.23
# 부동산_숙박             27.05           31.60      1               33.23
# 가구_전자기기            28.27           33.23      1               33.23
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                  8.79                19.02
# 식음료                    8.79                19.02
# 소매_편의                  8.79                19.02
# 미용_패션                  8.79                19.02
# 생활서비스                  8.79                19.02
# 교육_학원                  8.79                19.02
# 취미_레저                  8.79                19.02
# 부동산_숙박                 8.79                19.02
# 가구_전자기기                8.79                19.02

# %% [markdown]
# <h1>선형회귀 - Min-Max Scaler 적용</h1>

# %%
LRM_result = my_def.category_model_evaluation(df, model_index=0, scaler_type="minmax", shift_value=shift)
LRM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse      test_rmse  train_r2   test_r2   train_mae  \
# 의료_건강   76873228.48    73786214.70      0.95      0.94 43006987.88
# 식음료     31548853.94    35211765.79      0.96      0.95 20944645.25
# 소매_편의   77131861.54    98207462.18      0.96      0.95 43111400.21
# 미용_패션   33534831.31    34535239.65      0.95      0.92 13860450.43
# 생활서비스   51107604.85    52742490.52      0.89      0.92 24969945.94
# 교육_학원   11911667.48    14659173.10      0.92      0.89  6647410.62
# 취미_레저   77980935.85    81636596.26      0.91      0.91 29337318.54
# 부동산_숙박   6353023.15     7342374.61      0.95      0.93  3007759.56
# 가구_전자기기 65237739.28 32683525222.69      0.89 -30781.31 30314800.10
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강    43591872.81             8.61            8.79      1
# 식음료      23245245.04             8.75            9.57      1
# 소매_편의    49119391.98             9.66           10.55      1
# 미용_패션    13453769.46            15.67           16.09      1
# 생활서비스    25729196.73            16.92           16.98      1
# 교육_학원     7213980.20            17.21           18.23      1
# 취미_레저    31013492.63            23.94           26.17      1
# 부동산_숙박    3806604.94            27.05           31.60      1
# 가구_전자기기 869574446.84            28.26          847.59      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                847.59                8.79               109.51
# 식음료                  847.59                8.79               109.51
# 소매_편의                847.59                8.79               109.51
# 미용_패션                847.59                8.79               109.51
# 생활서비스                847.59                8.79               109.51
# 교육_학원                847.59                8.79               109.51
# 취미_레저                847.59                8.79               109.51
# 부동산_숙박               847.59                8.79               109.51
# 가구_전자기기              847.59                8.79               109.51

# %% [markdown]
# <h1>업종별카테고리 랜덤포레스트 모델</h1>
# Polynomial Features & Standard Scaler 사용 안함<br>
# 9개 카테고리를 개별로해서 데이터프레임 형태로 저장

# %%
RFN_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift)
RFN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     11846651.32 32342384.12      0.99     0.96  7630768.77 21372596.25
# 의료_건강   32077422.73 75987650.09      0.99     0.94 17475614.74 44823634.70
# 소매_편의   31685534.19 94897135.72      0.99     0.95 17042540.63 49819792.83
# 미용_패션   13703546.19 33332344.42      0.99     0.93  5251680.47 12781797.78
# 생활서비스   21700197.59 65749403.32      0.98     0.87  9928789.97 27829634.49
# 교육_학원    4839894.73 15633743.46      0.99     0.88  2621889.43  7535246.65
# 취미_레저   35985710.96 77043000.83      0.98     0.92 11280359.95 28818182.12
# 가구_전자기기 27587264.76 69460023.44      0.98     0.86 12153490.77 32002119.58
# 부동산_숙박   2877461.05  7241271.51      0.99     0.93  1232301.73  3785892.54
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.19            8.79      1               31.43
# 의료_건강               3.50            9.04      1               31.43
# 소매_편의               3.82           10.70      1               31.43
# 미용_패션               5.94           15.28      1               31.43
# 생활서비스               6.73           18.36      1               31.43
# 교육_학원               6.79           19.04      1               31.43
# 취미_레저               9.20           24.31      1               31.43
# 가구_전자기기            11.33           31.19      1               31.43
# 부동산_숙박             11.08           31.43      1               31.43
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.79                18.68
# 의료_건강                  8.79                18.68
# 소매_편의                  8.79                18.68
# 미용_패션                  8.79                18.68
# 생활서비스                  8.79                18.68
# 교육_학원                  8.79                18.68
# 취미_레저                  8.79                18.68
# 가구_전자기기                8.79                18.68
# 부동산_숙박                 8.79                18.68

# %% [markdown]
# <h1>랜덤포레스트 모델 - Standard scaler</h1>

# %%
RFS_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift, scaler_type="standard")
RFS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     12009687.14 32144851.33      0.99     0.96  7633880.16 21130219.74
# 의료_건강   32154975.48 75823370.32      0.99     0.94 17511630.69 44571726.35
# 소매_편의   31638074.36 93139234.35      0.99     0.95 17006221.20 49235445.69
# 미용_패션   13714374.83 33743052.80      0.99     0.93  5196449.10 12735312.63
# 생활서비스   21506836.43 64720644.03      0.98     0.88 10013858.01 27846983.07
# 교육_학원    4785160.37 15590153.26      0.99     0.88  2612491.26  7509521.46
# 취미_레저   35398726.41 73473371.44      0.98     0.93 11333565.21 28569645.07
# 가구_전자기기 27185426.39 68006451.94      0.98     0.87 12113548.24 31981851.62
# 부동산_숙박   2773396.36  7403603.51      0.99     0.92  1208692.31  3812898.90
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.19            8.70      1               31.65
# 의료_건강               3.50            8.99      1               31.65
# 소매_편의               3.81           10.58      1               31.65
# 미용_패션               5.87           15.23      1               31.65
# 생활서비스               6.78           18.37      1               31.65
# 교육_학원               6.76           18.98      1               31.65
# 취미_레저               9.25           24.10      1               31.65
# 가구_전자기기            11.29           31.17      1               31.65
# 부동산_숙박             10.87           31.65      1               31.65
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.70                18.64
# 의료_건강                  8.70                18.64
# 소매_편의                  8.70                18.64
# 미용_패션                  8.70                18.64
# 생활서비스                  8.70                18.64
# 교육_학원                  8.70                18.64
# 취미_레저                  8.70                18.64
# 가구_전자기기                8.70                18.64
# 부동산_숙박                 8.70                18.64

# %% [markdown]
# <h1>랜덤포레스트 모델 - Min-Max scaler</h1>

# %%
RFM_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift, scaler_type="minmax")
RFM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     12033690.29 32528816.60      0.99     0.96  7707735.18 21315937.91
# 의료_건강   32193443.61 75625232.57      0.99     0.94 17437365.17 44170649.23
# 소매_편의   31881135.83 94911272.90      0.99     0.95 17085483.53 49438782.15
# 미용_패션   13800826.92 33777163.91      0.99     0.93  5244507.06 12698218.66
# 생활서비스   21798567.80 64009896.78      0.98     0.88  9979330.65 27694507.47
# 교육_학원    4818017.54 15704245.93      0.99     0.88  2615670.00  7520104.98
# 취미_레저   35050518.40 72347203.71      0.98     0.93 11302277.84 28298546.45
# 부동산_숙박   2884978.05  7252105.66      0.99     0.93  1231144.79  3776616.28
# 가구_전자기기 27515115.15 70079964.57      0.98     0.86 12151544.82 32211094.96
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.22            8.77      1               31.40
# 의료_건강               3.49            8.91      1               31.40
# 소매_편의               3.83           10.62      1               31.40
# 미용_패션               5.93           15.18      1               31.40
# 생활서비스               6.76           18.27      1               31.40
# 교육_학원               6.77           19.00      1               31.40
# 취미_레저               9.22           23.87      1               31.40
# 부동산_숙박             11.07           31.35      1               31.40
# 가구_전자기기            11.33           31.40      1               31.40
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.77                18.60
# 의료_건강                  8.77                18.60
# 소매_편의                  8.77                18.60
# 미용_패션                  8.77                18.60
# 생활서비스                  8.77                18.60
# 교육_학원                  8.77                18.60
# 취미_레저                  8.77                18.60
# 부동산_숙박                 8.77                18.60
# 가구_전자기기                8.77                18.60

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : None <h1>

# %%
GBN_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift)
GBN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     25432506.33 30748648.83      0.97     0.96 16810236.29 19007624.16
# 의료_건강   67106739.69 77185276.82      0.96     0.94 42005643.48 44439137.77
# 소매_편의   66860150.53 95355051.54      0.97     0.95 40597417.51 47763318.82
# 미용_패션   24906273.33 34538925.51      0.97     0.92 12330638.14 13295167.66
# 교육_학원    9908678.63 15075680.54      0.95     0.89  6068360.87  7203497.88
# 생활서비스   41849039.98 65374026.77      0.92     0.87 23918574.91 27599791.42
# 취미_레저   49697020.54 75297819.63      0.97     0.92 25021419.61 28486339.86
# 가구_전자기기 55785307.75 70622228.75      0.92     0.86 29867571.09 33486149.61
# 부동산_숙박   2742706.43  8521711.97      0.99     0.90  1613214.74  4100743.06
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.03            7.82      1               34.04
# 의료_건강               8.41            8.97      1               34.04
# 소매_편의               9.10           10.26      1               34.04
# 미용_패션              13.94           15.90      1               34.04
# 교육_학원              15.71           18.20      1               34.04
# 생활서비스              16.20           18.21      1               34.04
# 취미_레저              20.42           24.03      1               34.04
# 가구_전자기기            27.85           32.64      1               34.04
# 부동산_숙박             14.51           34.04      1               34.04
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    7.82                18.90
# 의료_건강                  7.82                18.90
# 소매_편의                  7.82                18.90
# 미용_패션                  7.82                18.90
# 교육_학원                  7.82                18.90
# 생활서비스                  7.82                18.90
# 취미_레저                  7.82                18.90
# 가구_전자기기                7.82                18.90
# 부동산_숙박                 7.82                18.90

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : Standard <h1>

# %%
GBS_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift, scaler_type="standard")
GBS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     25432506.33 30759624.80      0.97     0.96 16810236.29 19008523.40
# 의료_건강   67106739.69 78005886.48      0.96     0.94 42005643.48 44526403.05
# 소매_편의   66860150.53 94135020.68      0.97     0.95 40597417.51 47577189.71
# 미용_패션   24906273.33 34466292.14      0.97     0.92 12330638.14 13314480.08
# 생활서비스   41849039.98 64908902.00      0.92     0.87 23918574.91 27603469.75
# 교육_학원    9908678.63 15087201.28      0.95     0.89  6068360.87  7216774.49
# 취미_레저   49697020.54 73446785.25      0.97     0.93 25021419.61 28628253.94
# 가구_전자기기 55785307.75 70177809.13      0.92     0.86 29867571.09 33434434.97
# 부동산_숙박   2742706.43  8226858.78      0.99     0.91  1613214.74  4014047.44
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.03            7.82      1               33.32
# 의료_건강               8.41            8.98      1               33.32
# 소매_편의               9.10           10.22      1               33.32
# 미용_패션              13.94           15.92      1               33.32
# 생활서비스              16.20           18.21      1               33.32
# 교육_학원              15.71           18.24      1               33.32
# 취미_레저              20.42           24.15      1               33.32
# 가구_전자기기            27.85           32.59      1               33.32
# 부동산_숙박             14.51           33.32      1               33.32
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    7.82                18.83
# 의료_건강                  7.82                18.83
# 소매_편의                  7.82                18.83
# 미용_패션                  7.82                18.83
# 생활서비스                  7.82                18.83
# 교육_학원                  7.82                18.83
# 취미_레저                  7.82                18.83
# 가구_전자기기                7.82                18.83
# 부동산_숙박                 7.82                18.83

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : MinMax <h1>

# %%
GBM_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift, scaler_type="minmax")
GBM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     25432506.33 30752990.32      0.97     0.96 16810236.29 19002055.67
# 의료_건강   67106739.69 77920363.33      0.96     0.94 42005643.48 44501090.71
# 소매_편의   66860150.53 94122323.44      0.97     0.95 40597417.51 47579578.55
# 미용_패션   24906273.33 34366126.21      0.97     0.92 12330638.14 13275067.45
# 교육_학원    9908678.63 15079227.14      0.95     0.89  6068360.87  7205472.49
# 생활서비스   41849039.98 65365827.78      0.92     0.87 23918574.91 27636533.26
# 취미_레저   49697020.54 74108004.86      0.97     0.92 25021419.61 28478013.93
# 가구_전자기기 55785307.75 70113093.35      0.92     0.86 29867571.09 33431306.85
# 부동산_숙박   2742706.43  8452503.32      0.99     0.90  1613214.74  4111553.88
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.03            7.82      1               34.13
# 의료_건강               8.41            8.98      1               34.13
# 소매_편의               9.10           10.22      1               34.13
# 미용_패션              13.94           15.87      1               34.13
# 교육_학원              15.71           18.21      1               34.13
# 생활서비스              16.20           18.23      1               34.13
# 취미_레저              20.42           24.03      1               34.13
# 가구_전자기기            27.85           32.59      1               34.13
# 부동산_숙박             14.51           34.13      1               34.13
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    7.82                18.90
# 의료_건강                  7.82                18.90
# 소매_편의                  7.82                18.90
# 미용_패션                  7.82                18.90
# 교육_학원                  7.82                18.90
# 생활서비스                  7.82                18.90
# 취미_레저                  7.82                18.90
# 가구_전자기기                7.82                18.90
# 부동산_숙박                 7.82                18.90

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : None <h1>

# %%
LGN_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift)
LGN_result.iloc[:,4:]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000333 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2226
# [LightGBM] [Info] Number of data points in the train set: 6993, number of used features: 42
# [LightGBM] [Info] Start training from score 147611169.452738
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000352 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2234
# [LightGBM] [Info] Number of data points in the train set: 7085, number of used features: 46
# [LightGBM] [Info] Start training from score 446080185.757516
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000384 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2215
# [LightGBM] [Info] Number of data points in the train set: 7106, number of used features: 37
# [LightGBM] [Info] Start training from score 239273688.051365
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000337 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2210
# [LightGBM] [Info] Number of data points in the train set: 6981, number of used features: 34
# [LightGBM] [Info] Start training from score 499741576.040682
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000432 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2198
# [LightGBM] [Info] Number of data points in the train set: 6062, number of used features: 29
# [LightGBM] [Info] Start training from score 107254588.218905
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000274 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2209
# [LightGBM] [Info] Number of data points in the train set: 6699, number of used features: 34
# [LightGBM] [Info] Start training from score 38629093.518436
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000224 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2217
# [LightGBM] [Info] Number of data points in the train set: 7076, number of used features: 37
# [LightGBM] [Info] Start training from score 88478205.785189
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000377 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2225
# [LightGBM] [Info] Number of data points in the train set: 6637, number of used features: 41
# [LightGBM] [Info] Start training from score 122559315.006479
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000189 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1451
# [LightGBM] [Info] Number of data points in the train set: 558, number of used features: 12
# [LightGBM] [Info] Start training from score 11121217.571685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     20541811.87  28346295.80      0.98     0.97 13145935.60 16689240.34
# 의료_건강   63950157.92  81318640.69      0.96     0.93 36877019.42 45752670.89
# 소매_편의   73300936.79 106895169.17      0.97     0.94 36751920.52 48664207.35
# 미용_패션   28454566.23  35156491.85      0.97     0.92 10453961.11 12772813.72
# 생활서비스   39233474.79  61139475.71      0.93     0.89 20239174.41 26481799.61
# 교육_학원    8496973.47  15840126.93      0.96     0.87  5031121.38  7195241.14
# 취미_레저   67809885.18  81970568.31      0.94     0.91 24332423.14 31648989.42
# 가구_전자기기 45619338.42  68656396.01      0.95     0.86 23918948.15 33198984.27
# 부동산_숙박   5358436.74   7569434.25      0.96     0.92  2012741.90  4248280.60
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 5.49            6.87      1               35.26
# 의료_건강               7.38            9.23      1               35.26
# 소매_편의               8.24           10.45      1               35.26
# 미용_패션              11.82           15.27      1               35.26
# 생활서비스              13.71           17.47      1               35.26
# 교육_학원              13.02           18.18      1               35.26
# 취미_레저              19.85           26.70      1               35.26
# 가구_전자기기            22.30           32.36      1               35.26
# 부동산_숙박             18.10           35.26      1               35.26
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    6.87                19.09
# 의료_건강                  6.87                19.09
# 소매_편의                  6.87                19.09
# 미용_패션                  6.87                19.09
# 생활서비스                  6.87                19.09
# 교육_학원                  6.87                19.09
# 취미_레저                  6.87                19.09
# 가구_전자기기                6.87                19.09
# 부동산_숙박                 6.87                19.09

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : Standard <h1>

# %%
LGS_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift, scaler_type="standard")
LGS_result.iloc[:,4:]
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001613 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2257
# [LightGBM] [Info] Number of data points in the train set: 6993, number of used features: 42
# [LightGBM] [Info] Start training from score 147611169.452738
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001423 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2269
# [LightGBM] [Info] Number of data points in the train set: 7085, number of used features: 46
# [LightGBM] [Info] Start training from score 446080185.757516
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001401 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2241
# [LightGBM] [Info] Number of data points in the train set: 7106, number of used features: 37
# [LightGBM] [Info] Start training from score 239273688.051365
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001085 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2233
# [LightGBM] [Info] Number of data points in the train set: 6981, number of used features: 34
# [LightGBM] [Info] Start training from score 499741576.040682
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001062 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2216
# [LightGBM] [Info] Number of data points in the train set: 6062, number of used features: 29
# [LightGBM] [Info] Start training from score 107254588.218905
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001171 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2232
# [LightGBM] [Info] Number of data points in the train set: 6699, number of used features: 34
# [LightGBM] [Info] Start training from score 38629093.518436
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001378 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2243
# [LightGBM] [Info] Number of data points in the train set: 7076, number of used features: 37
# [LightGBM] [Info] Start training from score 88478205.785189
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001125 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2255
# [LightGBM] [Info] Number of data points in the train set: 6637, number of used features: 41
# [LightGBM] [Info] Start training from score 122559315.006479
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000199 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1455
# [LightGBM] [Info] Number of data points in the train set: 558, number of used features: 12
# [LightGBM] [Info] Start training from score 11121217.571685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     20723925.21  28442369.45      0.98     0.97 13249770.29 16703757.54
# 의료_건강   65432611.73  82060485.24      0.96     0.93 37070564.73 45958674.00
# 소매_편의   72648199.28 106782900.92      0.97     0.94 36603669.22 48408451.66
# 미용_패션   28390633.73  36143668.79      0.97     0.92 10454902.51 12946904.51
# 생활서비스   39025145.43  60961263.68      0.93     0.89 20305120.46 26372677.90
# 교육_학원    8595137.47  15839347.65      0.96     0.87  5072697.66  7162275.80
# 취미_레저   67351470.51  85498099.95      0.94     0.90 24113535.16 32336550.73
# 가구_전자기기 45007591.61  68472162.16      0.95     0.86 23883988.54 33281597.16
# 부동산_숙박   5333397.27   7450507.04      0.96     0.92  1992117.97  4267794.13
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 5.54            6.87      1               35.43
# 의료_건강               7.42            9.27      1               35.43
# 소매_편의               8.21           10.40      1               35.43
# 미용_패션              11.82           15.48      1               35.43
# 생활서비스              13.76           17.40      1               35.43
# 교육_학원              13.13           18.10      1               35.43
# 취미_레저              19.67           27.28      1               35.43
# 가구_전자기기            22.27           32.44      1               35.43
# 부동산_숙박             17.91           35.43      1               35.43
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    6.87                19.19
# 의료_건강                  6.87                19.19
# 소매_편의                  6.87                19.19
# 미용_패션                  6.87                19.19
# 생활서비스                  6.87                19.19
# 교육_학원                  6.87                19.19
# 취미_레저                  6.87                19.19
# 가구_전자기기                6.87                19.19
# 부동산_숙박                 6.87                19.19

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : MinMax <h1>

# %%
LGM_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift, scaler_type="minmax")
LGM_result.iloc[:,4:]
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000344 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2223
# [LightGBM] [Info] Number of data points in the train set: 6993, number of used features: 42
# [LightGBM] [Info] Start training from score 147611169.452738
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000318 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2231
# [LightGBM] [Info] Number of data points in the train set: 7085, number of used features: 46
# [LightGBM] [Info] Start training from score 446080185.757516
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000336 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2212
# [LightGBM] [Info] Number of data points in the train set: 7106, number of used features: 37
# [LightGBM] [Info] Start training from score 239273688.051365
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000300 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2207
# [LightGBM] [Info] Number of data points in the train set: 6981, number of used features: 34
# [LightGBM] [Info] Start training from score 499741576.040682
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000310 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2195
# [LightGBM] [Info] Number of data points in the train set: 6062, number of used features: 29
# [LightGBM] [Info] Start training from score 107254588.218905
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000330 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2206
# [LightGBM] [Info] Number of data points in the train set: 6699, number of used features: 34
# [LightGBM] [Info] Start training from score 38629093.518436
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000309 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2214
# [LightGBM] [Info] Number of data points in the train set: 7076, number of used features: 37
# [LightGBM] [Info] Start training from score 88478205.785189
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000303 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2222
# [LightGBM] [Info] Number of data points in the train set: 6637, number of used features: 41
# [LightGBM] [Info] Start training from score 122559315.006479
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000134 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1443
# [LightGBM] [Info] Number of data points in the train set: 558, number of used features: 12
# [LightGBM] [Info] Start training from score 11121217.571685
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     20691223.40  28544385.19      0.98     0.97 13255429.39 16706072.81
# 의료_건강   63961342.67  80633582.36      0.96     0.93 36573643.25 45625920.05
# 소매_편의   73079798.10 108358992.07      0.97     0.94 36550378.68 48979724.45
# 미용_패션   28306026.39  35934717.88      0.97     0.92 10416058.23 13005274.54
# 생활서비스   39165571.53  61915410.70      0.93     0.89 20323936.98 26752484.77
# 교육_학원    8583381.61  15908199.20      0.96     0.87  5068154.23  7146324.87
# 취미_레저   68617534.96  82666197.49      0.93     0.91 24528257.80 31726701.81
# 가구_전자기기 45795273.49  69402230.51      0.95     0.86 24120089.72 33453858.40
# 부동산_숙박   5387657.07   7664146.09      0.96     0.92  2002962.56  4319064.21
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 5.54            6.87      1               35.85
# 의료_건강               7.32            9.21      1               35.85
# 소매_편의               8.19           10.52      1               35.85
# 미용_패션              11.77           15.55      1               35.85
# 생활서비스              13.77           17.65      1               35.85
# 교육_학원              13.12           18.06      1               35.85
# 취미_레저              20.01           26.77      1               35.85
# 가구_전자기기            22.49           32.61      1               35.85
# 부동산_숙박             18.01           35.85      1               35.85
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    6.87                19.23
# 의료_건강                  6.87                19.23
# 소매_편의                  6.87                19.23
# 미용_패션                  6.87                19.23
# 생활서비스                  6.87                19.23
# 교육_학원                  6.87                19.23
# 취미_레저                  6.87                19.23
# 가구_전자기기                6.87                19.23
# 부동산_숙박                 6.87                19.23

# %% [markdown]
# <h1>SVR - Scaler : None <h1>

# %%
SVRN_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift)
SVRN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   339188038.40 315122807.86     -0.03    -0.03 208935115.95
# 식음료     156724467.06 165970488.48     -0.05    -0.06 108734958.84
# 소매_편의   401866638.12 442974546.74     -0.03    -0.05 219568693.94
# 생활서비스   155780386.76 187108461.31     -0.05    -0.04  91251781.89
# 교육_학원    44675067.97  46795255.06     -0.10    -0.10  26680549.21
# 미용_패션   160294311.63 130392931.43     -0.08    -0.10  66433063.37
# 취미_레저   273016715.09 275952964.91     -0.05    -0.04  94536121.64
# 가구_전자기기 211686914.32 197952092.58     -0.13    -0.13  94073888.75
# 부동산_숙박   29036527.41  28802754.70     -0.11    -0.14  10554584.53
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   200902756.14            41.81           40.53      1
# 식음료     109211151.51            45.44           44.94      1
# 소매_편의   234328722.52            49.22           50.34      1
# 생활서비스    99267180.76            61.82           65.50      1
# 교육_학원    27293838.28            69.07           68.97      1
# 미용_패션    61522885.98            75.08           73.57      1
# 취미_레저    90698040.28            77.13           76.52      1
# 가구_전자기기  90965591.66            87.71           88.67      1
# 부동산_숙박   11474215.72            94.90           95.24      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 95.24               40.53                67.14
# 식음료                   95.24               40.53                67.14
# 소매_편의                 95.24               40.53                67.14
# 생활서비스                 95.24               40.53                67.14
# 교육_학원                 95.24               40.53                67.14
# 미용_패션                 95.24               40.53                67.14
# 취미_레저                 95.24               40.53                67.14
# 가구_전자기기               95.24               40.53                67.14
# 부동산_숙박                95.24               40.53                67.14

# %% [markdown]
# <h1>SVR - Scaler : Standard <h1>

# %%
SVRS_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift, scaler_type="standard")
SVRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   339188650.39 315123454.00     -0.03    -0.03 208935786.22
# 식음료     156725363.78 165971323.59     -0.05    -0.06 108735823.59
# 소매_편의   401867164.74 442975053.92     -0.03    -0.05 219569391.74
# 생활서비스   155781078.43 187109052.66     -0.05    -0.04  91252595.33
# 교육_학원    44675842.73  46796014.63     -0.10    -0.10  26681355.77
# 미용_패션   160294676.51 130393359.12     -0.08    -0.10  66433503.16
# 취미_레저   273016981.10 275953216.57     -0.05    -0.04  94536495.51
# 가구_전자기기 211687305.85 197952494.79     -0.13    -0.13  94074265.46
# 부동산_숙박   29036550.52  28802781.73     -0.11    -0.14  10554602.62
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   200903437.11            41.81           40.53      1
# 식음료     109211981.88            45.44           44.94      1
# 소매_편의   234329435.00            49.22           50.34      1
# 생활서비스    99267995.81            61.82           65.50      1
# 교육_학원    27294635.16            69.07           68.97      1
# 미용_패션    61523332.48            75.08           73.57      1
# 취미_레저    90698415.46            77.14           76.52      1
# 가구_전자기기  90965964.03            87.71           88.67      1
# 부동산_숙박   11474238.85            94.91           95.24      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 95.24               40.53                67.14
# 식음료                   95.24               40.53                67.14
# 소매_편의                 95.24               40.53                67.14
# 생활서비스                 95.24               40.53                67.14
# 교육_학원                 95.24               40.53                67.14
# 미용_패션                 95.24               40.53                67.14
# 취미_레저                 95.24               40.53                67.14
# 가구_전자기기               95.24               40.53                67.14
# 부동산_숙박                95.24               40.53                67.14

# %% [markdown]
# <h1>SVR - Scaler : MinMax <h1>

# %%
SVRM_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift, scaler_type="minmax")
SVRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   339188650.39 315123454.00     -0.03    -0.03 208935786.22
# 식음료     156725363.78 165971323.59     -0.05    -0.06 108735823.59
# 소매_편의   401867164.74 442975053.92     -0.03    -0.05 219569391.74
# 생활서비스   155781078.43 187109052.66     -0.05    -0.04  91252595.33
# 교육_학원    44675842.73  46796014.63     -0.10    -0.10  26681355.77
# 미용_패션   160294676.51 130393359.12     -0.08    -0.10  66433503.16
# 취미_레저   273016981.10 275953216.57     -0.05    -0.04  94536495.51
# 가구_전자기기 211687305.85 197952494.79     -0.13    -0.13  94074265.46
# 부동산_숙박   29036550.52  28802781.73     -0.11    -0.14  10554602.62
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   200903437.11            41.81           40.53      1
# 식음료     109211981.88            45.44           44.94      1
# 소매_편의   234329435.00            49.22           50.34      1
# 생활서비스    99267995.81            61.82           65.50      1
# 교육_학원    27294635.16            69.07           68.97      1
# 미용_패션    61523332.48            75.08           73.57      1
# 취미_레저    90698415.46            77.14           76.52      1
# 가구_전자기기  90965964.03            87.71           88.67      1
# 부동산_숙박   11474238.85            94.91           95.24      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 95.24               40.53                67.14
# 식음료                   95.24               40.53                67.14
# 소매_편의                 95.24               40.53                67.14
# 생활서비스                 95.24               40.53                67.14
# 교육_학원                 95.24               40.53                67.14
# 미용_패션                 95.24               40.53                67.14
# 취미_레저                 95.24               40.53                67.14
# 가구_전자기기               95.24               40.53                67.14
# 부동산_숙박                95.24               40.53                67.14

# %% [markdown]
# <h1>MLPR - Scaler : None <h1>

# %%
MLPN_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift)
MLPN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   85164769.15  74938433.85      0.94     0.94 47087457.11 44703269.82
# 식음료     36492008.64  37423200.25      0.94     0.95 23667527.40 24753916.00
# 소매_편의   83888422.50 102524966.57      0.95     0.94 45515698.48 49311998.65
# 미용_패션   37231294.06  32946389.06      0.94     0.93 14849878.88 13503132.81
# 생활서비스   62012470.71  54349102.84      0.83     0.91 27445865.19 26297350.04
# 교육_학원   12909205.85  15020874.36      0.91     0.89  6861227.84  7310453.32
# 취미_레저   97178935.57  89810014.11      0.87     0.89 30782907.54 29256690.86
# 부동산_숙박   8076363.49   6598465.94      0.91     0.94  3496205.40  3357604.67
# 가구_전자기기 75133756.46  75182775.57      0.86     0.84 33115024.43 32990514.49
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강               9.42            9.02      1               32.16
# 식음료                 9.89           10.19      1               32.16
# 소매_편의              10.20           10.59      1               32.16
# 미용_패션              16.78           16.15      1               32.16
# 생활서비스              18.59           17.35      1               32.16
# 교육_학원              17.76           18.47      1               32.16
# 취미_레저              25.12           24.68      1               32.16
# 부동산_숙박             31.44           27.87      1               32.16
# 가구_전자기기            30.88           32.16      1               32.16
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                  9.02                18.50
# 식음료                    9.02                18.50
# 소매_편의                  9.02                18.50
# 미용_패션                  9.02                18.50
# 생활서비스                  9.02                18.50
# 교육_학원                  9.02                18.50
# 취미_레저                  9.02                18.50
# 부동산_숙박                 9.02                18.50
# 가구_전자기기                9.02                18.50

# %% [markdown]
# <h1>MLPR - Scaler : Standard <h1>

# %%
MLPS_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift, scaler_type="standard")
MLPS_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 교육_학원    57521691.35  59588365.56     -0.82    -0.78  38586247.64
# 미용_패션   177493710.34 149634081.33     -0.33    -0.45  88435583.62
# 생활서비스   211798141.47 237684957.75     -0.94    -0.68 147560586.15
# 가구_전자기기 226204756.47 212631429.54     -0.29    -0.30 107223496.93
# 취미_레저   292987914.67 294884164.58     -0.21    -0.19 122526019.19
# 식음료     283878671.38 291718199.30     -2.45    -2.26 239224364.21
# 의료_건강   601386421.64 585060973.24     -2.23    -2.54 499694018.05
# 소매_편의   595842528.96 635776673.92     -1.27    -1.15 446033435.36
# 부동산_숙박   29687895.97  29518305.62     -0.16    -0.20  11121003.61
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 교육_학원    39533131.87            99.89           99.89      1
# 미용_패션    83585108.18            99.95           99.95      1
# 생활서비스   151512953.88            99.97           99.97      1
# 가구_전자기기 102565711.27            99.97           99.97      1
# 취미_레저   118496875.01            99.97           99.97      1
# 식음료     242960779.88            99.98           99.98      1
# 의료_건강   495614293.05            99.99           99.99      1
# 소매_편의   465433923.02            99.99           99.99      1
# 부동산_숙박   12046871.36           100.00          100.00      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 교육_학원                100.00               99.89                99.97
# 미용_패션                100.00               99.89                99.97
# 생활서비스                100.00               99.89                99.97
# 가구_전자기기              100.00               99.89                99.97
# 취미_레저                100.00               99.89                99.97
# 식음료                  100.00               99.89                99.97
# 의료_건강                100.00               99.89                99.97
# 소매_편의                100.00               99.89                99.97
# 부동산_숙박               100.00               99.89                99.97

# %% [markdown]
# <h1>MLPR - Scaler : MinMax <h1>

# %%
MLPM_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift, scaler_type="minmax")
MLPM_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 교육_학원    57554515.17  59620303.43     -0.82    -0.79  38608501.38
# 취미_레저   293009146.98 294904798.51     -0.21    -0.19 122539726.47
# 가구_전자기기 226235599.13 212659877.74     -0.29    -0.30 107238930.15
# 미용_패션   177532143.27 149671010.07     -0.33    -0.45  88458648.64
# 식음료     283915831.40 291755044.28     -2.45    -2.26 239252441.75
# 생활서비스   211838935.37 237723691.61     -0.94    -0.68 147593838.51
# 의료_건강   601418284.79 585089938.42     -2.23    -2.54 499721264.74
# 소매_편의   595873698.09 635806668.79     -1.27    -1.15 446061286.34
# 부동산_숙박   29688080.75  29518484.80     -0.16    -0.20  11120947.93
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 교육_학원    39554986.29            99.95           99.95      1
# 취미_레저   118509443.99            99.98           99.98      1
# 가구_전자기기 102578257.15            99.99           99.98      1
# 미용_패션    83606070.31            99.98           99.98      1
# 식음료     242988141.65            99.99           99.99      1
# 생활서비스   151542505.52            99.99           99.99      1
# 의료_건강   495639211.55           100.00          100.00      1
# 소매_편의   465460679.36           100.00          100.00      1
# 부동산_숙박   12046833.08           100.00          100.00      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 교육_학원                100.00               99.95                99.99
# 취미_레저                100.00               99.95                99.99
# 가구_전자기기              100.00               99.95                99.99
# 미용_패션                100.00               99.95                99.99
# 식음료                  100.00               99.95                99.99
# 생활서비스                100.00               99.95                99.99
# 의료_건강                100.00               99.95                99.99
# 소매_편의                100.00               99.95                99.99
# 부동산_숙박               100.00               99.95                99.99

# %% [markdown]
# <h1>ESM - Scaler : None <h1>

# %%
ESN_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift)
ESN_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.311e+19, tolerance: 1.615e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.460e+19, tolerance: 1.106e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.142e+18, tolerance: 1.660e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.449e+19, tolerance: 7.818e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.696e+19, tolerance: 2.406e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.428e+17, tolerance: 1.221e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.801e+18, tolerance: 1.677e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.106e+19, tolerance: 4.702e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.775e+16, tolerance: 4.228e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   83729687.91  73917787.52      0.94     0.94 46380389.92 43643743.15
# 식음료     34059089.12  35562932.22      0.95     0.95 21887216.83 22736172.18
# 소매_편의   83314315.41 102625345.02      0.96     0.94 45276872.62 48929940.53
# 미용_패션   36823760.42  32694106.76      0.94     0.93 14984153.93 13675916.17
# 생활서비스   61221413.80  54057907.44      0.84     0.91 27709913.70 26703253.39
# 교육_학원   12722034.61  14842935.27      0.91     0.89  6871442.74  7278539.51
# 취미_레저   96736547.01  89564413.72      0.87     0.89 31412300.34 30328736.37
# 부동산_숙박   7959195.61   6676269.86      0.92     0.94  3689746.59  3586794.98
# 가구_전자기기 74788632.25  74314999.21      0.86     0.84 34198616.18 34053604.06
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강               9.28            8.81      1               33.19
# 식음료                 9.15            9.36      1               33.19
# 소매_편의              10.15           10.51      1               33.19
# 미용_패션              16.94           16.35      1               33.19
# 생활서비스              18.77           17.62      1               33.19
# 교육_학원              17.79           18.39      1               33.19
# 취미_레저              25.63           25.59      1               33.19
# 부동산_숙박             33.18           29.77      1               33.19
# 가구_전자기기            31.89           33.19      1               33.19
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                  8.81                18.84
# 식음료                    8.81                18.84
# 소매_편의                  8.81                18.84
# 미용_패션                  8.81                18.84
# 생활서비스                  8.81                18.84
# 교육_학원                  8.81                18.84
# 취미_레저                  8.81                18.84
# 부동산_숙박                 8.81                18.84
# 가구_전자기기                8.81                18.84

# %% [markdown]
# <h1>ESM - Scaler : standard <h1>

# %%
ESS_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift, scaler_type="standard")
ESS_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.338e+19, tolerance: 1.615e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.655e+20, tolerance: 1.106e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.771e+19, tolerance: 1.660e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.932e+19, tolerance: 7.818e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.206e+19, tolerance: 2.406e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.420e+17, tolerance: 1.221e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.711e+19, tolerance: 1.677e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.597e+19, tolerance: 4.702e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.340e+16, tolerance: 4.228e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   102746076.36  99476562.90      0.91     0.90 62503639.75 61829308.77
# 식음료      45432180.36  52703170.83      0.91     0.89 31924771.40 35303865.60
# 소매_편의   145416983.08 180430837.97      0.86     0.83 62398826.46 70591568.63
# 생활서비스    60305236.43  67660294.95      0.84     0.86 32115398.48 34499001.41
# 미용_패션    45416439.37  41478483.31      0.91     0.89 20336157.91 19847647.07
# 교육_학원    15302128.82  16930895.80      0.87     0.86  9300883.53  9554819.92
# 취미_레저    94817065.20  95845811.39      0.87     0.87 36898729.54 37419257.11
# 부동산_숙박    8381373.08   8790834.25      0.91     0.89  4115173.17  4589074.41
# 가구_전자기기  75501046.32  72792897.44      0.86     0.85 39377698.68 39142779.10
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              12.51           12.47      1               38.15
# 식음료                13.34           14.53      1               38.15
# 소매_편의              13.99           15.17      1               38.15
# 생활서비스              21.76           22.76      1               38.15
# 미용_패션              22.98           23.73      1               38.15
# 교육_학원              24.08           24.14      1               38.15
# 취미_레저              30.11           31.57      1               38.15
# 부동산_숙박             37.00           38.09      1               38.15
# 가구_전자기기            36.71           38.15      1               38.15
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 12.47                24.51
# 식음료                   12.47                24.51
# 소매_편의                 12.47                24.51
# 생활서비스                 12.47                24.51
# 미용_패션                 12.47                24.51
# 교육_학원                 12.47                24.51
# 취미_레저                 12.47                24.51
# 부동산_숙박                12.47                24.51
# 가구_전자기기               12.47                24.51

# %% [markdown]
# <h1>ESM - Scaler : MinMax <h1>

# %%
ESM_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift, scaler_type="minmax")
ESM_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.413e+19, tolerance: 1.615e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.201e+20, tolerance: 1.106e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.561e+19, tolerance: 1.660e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.757e+20, tolerance: 7.818e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.779e+19, tolerance: 2.406e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.103e+16, tolerance: 1.221e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.073e+19, tolerance: 1.677e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.405e+20, tolerance: 4.702e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.328e+16, tolerance: 4.228e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   327993003.28 304891500.18      0.04     0.04 209359926.82
# 식음료     146661673.73 155293384.21      0.08     0.08 107354551.67
# 소매_편의   389884088.84 428529959.70      0.03     0.02 224814494.21
# 생활서비스   149487032.84 180367204.79      0.03     0.03  93708434.72
# 교육_학원    41691635.77  43607919.20      0.05     0.04  28006022.56
# 미용_패션   151554953.74 122179004.16      0.03     0.03  77441058.98
# 취미_레저   262727259.48 266735585.31      0.03     0.02 107872374.18
# 부동산_숙박   25241679.37  24762740.08      0.16     0.16  12992084.25
# 가구_전자기기 195622322.73 182949306.74      0.04     0.04 112446943.02
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   199607417.46            41.89           40.27      1
# 식음료     107938371.40            44.87           44.42      1
# 소매_편의   235836887.08            50.40           50.67      1
# 생활서비스   102239946.29            63.48           67.46      1
# 교육_학원    28667438.38            72.50           72.44      1
# 미용_패션    71905996.24            87.53           85.99      1
# 취미_레저   105233254.99            88.02           88.78      1
# 부동산_숙박   12832550.39           116.82          106.52      1
# 가구_전자기기 111367415.42           104.84          108.55      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                108.55               40.27                73.90
# 식음료                  108.55               40.27                73.90
# 소매_편의                108.55               40.27                73.90
# 생활서비스                108.55               40.27                73.90
# 교육_학원                108.55               40.27                73.90
# 미용_패션                108.55               40.27                73.90
# 취미_레저                108.55               40.27                73.90
# 부동산_숙박               108.55               40.27                73.90
# 가구_전자기기              108.55               40.27                73.90

# %%
ESM_result.iloc[:,:]
# Out:
#               Model Scaler             train_mse              test_mse  \
# 의료_건강    ElasticNet   None 107579410202611952.00  92958826881528928.00
# 식음료      ElasticNet   None  21509646540074724.00  24116035178153328.00
# 소매_편의    ElasticNet   None 152009602734382016.00 183637926361024800.00
# 생활서비스    ElasticNet   None  22346372985960400.00  32532328563337692.00
# 교육_학원    ElasticNet   None   1738192492890830.50   1901650616660888.75
# 미용_패션    ElasticNet   None  22968904003925864.00  14927709056696366.00
# 취미_레저    ElasticNet   None  69025612875136328.00  71147872473121816.00
# 부동산_숙박   ElasticNet   None    637142377525212.12    613193296133878.38
# 가구_전자기기  ElasticNet   None  38268093151098736.00  33470448835804172.00
#
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   327993003.28 304891500.18      0.04     0.04 209359926.82
# 식음료     146661673.73 155293384.21      0.08     0.08 107354551.67
# 소매_편의   389884088.84 428529959.70      0.03     0.02 224814494.21
# 생활서비스   149487032.84 180367204.79      0.03     0.03  93708434.72
# 교육_학원    41691635.77  43607919.20      0.05     0.04  28006022.56
# 미용_패션   151554953.74 122179004.16      0.03     0.03  77441058.98
# 취미_레저   262727259.48 266735585.31      0.03     0.02 107872374.18
# 부동산_숙박   25241679.37  24762740.08      0.16     0.16  12992084.25
# 가구_전자기기 195622322.73 182949306.74      0.04     0.04 112446943.02
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   199607417.46            41.89           40.27      1
# 식음료     107938371.40            44.87           44.42      1
# 소매_편의   235836887.08            50.40           50.67      1
# 생활서비스   102239946.29            63.48           67.46      1
# 교육_학원    28667438.38            72.50           72.44      1
# 미용_패션    71905996.24            87.53           85.99      1
# 취미_레저   105233254.99            88.02           88.78      1
# 부동산_숙박   12832550.39           116.82          106.52      1
# 가구_전자기기 111367415.42           104.84          108.55      1
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                108.55               40.27                73.90
# 식음료                  108.55               40.27                73.90
# 소매_편의                108.55               40.27                73.90
# 생활서비스                108.55               40.27                73.90
# 교육_학원                108.55               40.27                73.90
# 미용_패션                108.55               40.27                73.90
# 취미_레저                108.55               40.27                73.90
# 부동산_숙박               108.55               40.27                73.90
# 가구_전자기기              108.55               40.27                73.90

# %%
# 각 데이터프레임의 인덱스를 리셋한 후 새로운 변수로 저장합니다.
ESM_result2 = ESM_result.reset_index()
ESS_result2 = ESS_result.reset_index()
ESN_result2 = ESN_result.reset_index()
MLPM_result2 = MLPM_result.reset_index()
MLPS_result2 = MLPS_result.reset_index()
MLPN_result2 = MLPN_result.reset_index()
SVRS_result2 = SVRS_result.reset_index()
SVRM_result2 = SVRM_result.reset_index()
SVRN_result2 = SVRN_result.reset_index()
LGM_result2 = LGM_result.reset_index()
LGS_result2 = LGS_result.reset_index()
LGN_result2 = LGN_result.reset_index()
GBM_result2 = GBM_result.reset_index()
GBS_result2 = GBS_result.reset_index()
GBN_result2 = GBN_result.reset_index()
RFM_result2 = RFM_result.reset_index()
RFS_result2 = RFS_result.reset_index()
RFN_result2 = RFN_result.reset_index()
LRM_result2 = LRM_result.reset_index()
LRS_result2 = LRS_result.reset_index()
LRN_result2 = LRN_result.reset_index()

# %%
import pandas as pd

# 데이터프레임 목록 생성
df_list = [
    ESM_result2, ESS_result2, ESN_result2,
    MLPM_result2, MLPS_result2, MLPN_result2,
    SVRS_result2, SVRM_result2, SVRN_result2,
    LGM_result2, LGS_result2, LGN_result2,
    GBM_result2, GBS_result2, GBN_result2,
    RFM_result2, RFS_result2, RFN_result2,
    LRM_result2, LRS_result2, LRN_result2
]

# 데이터프레임 이름 목록 생성
df_names = [
    'ESM', 'ESS', 'ESN',
    'MLPM', 'MLPS', 'MLPN',
    'SVRS', 'SVRM', 'SVRN',
    'LGM', 'LGS', 'LGN',
    'GBM', 'GBS', 'GBN',
    'RFM', 'RFS', 'RFN',
    'LRM', 'LRS', 'LRN'
]

# 각 데이터프레임에 대해 Scaler 값을 업데이트
for df, name in zip(df_list, df_names):
    suffix = name[-1]  # 이름에서 마지막 문자를 추출
    if suffix == 'S':
        scaler_value = 'Standard'
    elif suffix == 'M':
        scaler_value = 'MinMax'
    elif suffix == 'N':
        scaler_value = 'Default'
    else:
        continue  # 해당하지 않으면 건너뜀
    
    # Scaler 컬럼 값을 업데이트
    if 'Scaler' in df.columns:
        df['Scaler'] = scaler_value
    else:
        print(f"DataFrame {name} does not have a 'Scaler' column.")

# %%
all_results = [
    ESM_result2, ESS_result2, ESN_result2,
    MLPM_result2, MLPS_result2, MLPN_result2,
    SVRS_result2, SVRM_result2, SVRN_result2,
    LGM_result2, LGS_result2, LGN_result2,
    GBM_result2, GBS_result2, GBN_result2,
    RFM_result2, RFS_result2, RFN_result2,
    LRM_result2, LRS_result2, LRN_result2
]

# 모든 데이터프레임을 행 방향으로 병합
df_combined = pd.concat(all_results, ignore_index=True)

# %%
col = ['Shift', 'Model', 'Scaler', 'index', 'train_r2', 'test_r2', 'train_mse', 'test_mse','train_mae_ratio', 'test_mae_ratio', 'test_mae_ratio_max','test_mae_ratio_min', 'test_mae_ratio_mean', 'train_mae', 'test_mae', 'train_rmse', 'test_rmse']
df_combined = df_combined[col]

# %%
df_combined.to_csv("single_category_shift1.csv", index=False)

# %%
data = pd.read_csv("single_category_shift1.csv")
data.groupby(["Model", "Scaler"])["index"].count()
# Out:
# Model                      Scaler
# ElasticNet                 Default     9
#                            MinMax      9
#                            Standard    9
# GradientBoostingRegressor  Default     9
#                            MinMax      9
#                            Standard    9
# LGBMRegressor              Default     9
#                            MinMax      9
#                            Standard    9
# LinearRegression           Default     9
#                            MinMax      9
#                            Standard    9
# MLPRegressor               Default     9
#                            MinMax      9
#                            Standard    9
# RandomForestRegressor      Default     9
#                            MinMax      9
#                            Standard    9
# SVR                        Default     9
#                            MinMax      9
#                            Standard    9
# Name: index, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shift                189 non-null    int64
#  1   Model                189 non-null    object
#  2   Scaler               189 non-null    object
#  3   index                189 non-null    object
#  4   train_r2             189 non-null    float64
#  5   test_r2              189 non-null    float64
#  6   train_mse            189 non-null    float64
#  7   test_mse             189 non-null    float64
#  8   train_mae_ratio      189 non-null    float64
#  9   test_mae_ratio       189 non-null    float64
#  10  test_mae_ratio_max   189 non-null    float64
#  11  test_mae_ratio_min   189 non-null    float64
#  12  test_mae_ratio_mean  189 non-null    float64
#  13  train_mae            189 non-null    float64
#  14  test_mae             189 non-null    float64
#  15  train_rmse           189 non-null    float64
#  16  test_rmse            189 non-null    float64
# dtypes: float64(13), int64(1), object(3)
# memory usage: 25.2+ KB
