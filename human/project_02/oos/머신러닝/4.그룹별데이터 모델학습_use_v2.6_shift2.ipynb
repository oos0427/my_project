# %%
import pandas as pd
import numpy as np
import my_def

# %% [markdown]
# <h1>데이터확인 및 가공</h1>
# 업종명 분류 -> 9개의 중분류로 구분

# %%
df = pd.read_csv('Merged_Sales_data_v2.6(shift2).csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65647 entries, 0 to 65646
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년분기         65647 non-null  int64
#  1   행정동         65647 non-null  object
#  2   업종별카테고리     65647 non-null  object
#  3   월매출(점포)     65647 non-null  int64
#  4   인구수         65647 non-null  float64
#  5   지역생활인구      65647 non-null  float64
#  6   장기외국인       65647 non-null  float64
#  7   단기외국인       65647 non-null  float64
#  8   주차장면적(면)    65647 non-null  float64
#  9   주차장개수(개소)   65647 non-null  float64
#  10  학교수         65647 non-null  float64
#  11  학생수         65647 non-null  float64
#  12  버스정류장수      65647 non-null  float64
#  13  년분기_미룸      65647 non-null  float64
#  14  월매출_shift2  65647 non-null  float64
# dtypes: float64(11), int64(2), object(2)
# memory usage: 7.5+ MB

# %%
df = my_def.reduce_memory_usage(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65647 entries, 0 to 65646
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   년분기         65647 non-null  int16
#  1   행정동         65647 non-null  object
#  2   업종별카테고리     65647 non-null  object
#  3   월매출(점포)     65647 non-null  int64
#  4   인구수         65647 non-null  float16
#  5   지역생활인구      65647 non-null  float32
#  6   장기외국인       65647 non-null  float32
#  7   단기외국인       65647 non-null  float32
#  8   주차장면적(면)    65647 non-null  float32
#  9   주차장개수(개소)   65647 non-null  float16
#  10  학교수         65647 non-null  float16
#  11  학생수         65647 non-null  float16
#  12  버스정류장수      65647 non-null  float16
#  13  년분기_미룸      65647 non-null  float16
#  14  월매출_shift2  65647 non-null  float32
# dtypes: float16(6), float32(5), int16(1), int64(1), object(2)
# memory usage: 3.6+ MB
# None

# %%
df[df["업종별카테고리"] == "기타"]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\pandas\io\formats\format.py:1458: RuntimeWarning: overflow encountered in cast
#   has_large_values = (abs_vals > 1e6).any()
# Empty DataFrame
# Columns: [년분기, 행정동, 업종별카테고리, 월매출(점포), 인구수, 지역생활인구, 장기외국인, 단기외국인, 주차장면적(면), 주차장개수(개소), 학교수, 학생수, 버스정류장수, 년분기_미룸, 월매출_shift2]
# Index: []

# %% [markdown]
# <h1>전체업종 선형회귀 분석</h1>

# %%
shift = 2

# %%
result_lr_00 = my_def.linear_regression_model(df, scaler_option= 0, shift_value=shift)
result_lr_00
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'None',
#  'train_mse': np.float64(4.726719676828874e+16),
#  'test_mse': np.float64(4.6091074559614744e+16),
#  'train_rmse': np.float64(217410203.92),
#  'test_rmse': np.float64(214688319.57),
#  'train_r2': 0.43,
#  'test_r2': 0.44,
#  'train_mae': np.float64(114708267.36),
#  'test_mae': np.float64(114405085.26),
#  'train_mae_ratio': np.float64(54.06),
#  'test_mae_ratio': np.float64(53.74),
#  'Shift': 2}

# %%
result_lr_01 = my_def.linear_regression_model(df, scaler_option= 1, shift_value=shift)
result_lr_01
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'StandardScaler',
#  'train_mse': np.float64(4.4284663716886024e+16),
#  'test_mse': np.float64(4.7032288789869304e+16),
#  'train_rmse': np.float64(210439216.2),
#  'test_rmse': np.float64(216869289.64),
#  'train_r2': 0.47,
#  'test_r2': 0.43,
#  'train_mae': np.float64(113393246.28),
#  'test_mae': np.float64(114446898.39),
#  'train_mae_ratio': np.float64(53.44),
#  'test_mae_ratio': np.float64(53.76),
#  'Shift': 2}

# %%
result_lr_02 = my_def.linear_regression_model(df, scaler_option= 2, shift_value=shift)
result_lr_02
# Out:
# {'Model': 'LinearRegression',
#  'Scaler': 'MinMaxScaler',
#  'train_mse': np.float64(4.428466239563687e+16),
#  'test_mse': np.float64(4.703227525272587e+16),
#  'train_rmse': np.float64(210439213.07),
#  'test_rmse': np.float64(216869258.43),
#  'train_r2': 0.47,
#  'test_r2': 0.43,
#  'train_mae': np.float64(113393860.56),
#  'test_mae': np.float64(114447520.79),
#  'train_mae_ratio': np.float64(53.44),
#  'test_mae_ratio': np.float64(53.76),
#  'Shift': 2}

# %%
#raise KeyboardInterrupt("실행을 중단합니다.")

# %%
result_rf_00 = my_def.random_forest_model(df, scaler_option= 0, shift_value=shift)
result_rf_00
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'None',
#  'train_mse': np.float64(674518765023128.9),
#  'test_mse': np.float64(4702229122973504.0),
#  'train_rmse': np.float64(25971499.09),
#  'test_rmse': np.float64(68572801.63),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11414672.54),
#  'test_mae': np.float64(30227100.93),
#  'train_mae_ratio': np.float64(5.38),
#  'test_mae_ratio': np.float64(14.2),
#  'Shift': 2}

# %%
result_rf_01 = my_def.random_forest_model(df, scaler_option= 1, shift_value=shift)
result_rf_01
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'StandardScaler',
#  'train_mse': np.float64(675627895557844.0),
#  'test_mse': np.float64(4694311016433731.0),
#  'train_rmse': np.float64(25992843.16),
#  'test_rmse': np.float64(68515042.26),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11413484.44),
#  'test_mae': np.float64(30249791.15),
#  'train_mae_ratio': np.float64(5.38),
#  'test_mae_ratio': np.float64(14.21),
#  'Shift': 2}

# %%
result_rf_02 = my_def.random_forest_model(df, scaler_option= 2, shift_value=shift)
result_rf_02
# Out:
# {'Model': 'RandomForestRegressor',
#  'Scaler': 'MinMaxScaler',
#  'train_mse': np.float64(674247126682085.5),
#  'test_mse': np.float64(4709563226831936.0),
#  'train_rmse': np.float64(25966269.02),
#  'test_rmse': np.float64(68626257.56),
#  'train_r2': 0.99,
#  'test_r2': 0.94,
#  'train_mae': np.float64(11415308.71),
#  'test_mae': np.float64(30224892.47),
#  'train_mae_ratio': np.float64(5.38),
#  'test_mae_ratio': np.float64(14.2),
#  'Shift': 2}

# %%
# 결과 딕셔너리들을 리스트에 모읍니다.
results = [result_lr_00, result_lr_01, result_lr_02, result_rf_00, result_rf_01, result_rf_02]

# 리스트를 데이터프레임으로 변환합니다.
df_results = pd.DataFrame(results)

# %%
col = ['Shift', 'Model', 'Scaler', 'train_mse', 'test_mse', 'train_rmse', 'test_rmse',
       'train_r2', 'test_r2', 'train_mae', 'test_mae', 'train_mae_ratio',
       'test_mae_ratio']
df_results = df_results[col]

# %%
df_results
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      2       LinearRegression            None  4.726720e+16  4.609107e+16
# 1      2       LinearRegression  StandardScaler  4.428466e+16  4.703229e+16
# 2      2       LinearRegression    MinMaxScaler  4.428466e+16  4.703228e+16
# 3      2  RandomForestRegressor            None  6.745188e+14  4.702229e+15
# 4      2  RandomForestRegressor  StandardScaler  6.756279e+14  4.694311e+15
# 5      2  RandomForestRegressor    MinMaxScaler  6.742471e+14  4.709563e+15
#
#      train_rmse     test_rmse  train_r2  test_r2     train_mae      test_mae  \
# 0  2.174102e+08  2.146883e+08      0.43     0.44  1.147083e+08  1.144051e+08
# 1  2.104392e+08  2.168693e+08      0.47     0.43  1.133932e+08  1.144469e+08
# 2  2.104392e+08  2.168693e+08      0.47     0.43  1.133939e+08  1.144475e+08
# 3  2.597150e+07  6.857280e+07      0.99     0.94  1.141467e+07  3.022710e+07
# 4  2.599284e+07  6.851504e+07      0.99     0.94  1.141348e+07  3.024979e+07
# 5  2.596627e+07  6.862626e+07      0.99     0.94  1.141531e+07  3.022489e+07
#
#    train_mae_ratio  test_mae_ratio
# 0            54.06           53.74
# 1            53.44           53.76
# 2            53.44           53.76
# 3             5.38           14.20
# 4             5.38           14.21
# 5             5.38           14.20

# %%
df_results.to_csv("all_category_shift2.csv", index= False)

# %%
#raise KeyboardInterrupt("실행을 중단합니다.")

# %% [markdown]
# <h1>업종별카테고리 선형회귀 모델</h1>
# Polynomial Features & Standard Scaler 사용 안함<br>
# 9개 카테고리를 개별로해서 데이터프레임 형태로 저장

# %%
shift = 2

# %%
LRN_result = my_def.category_model_evaluation(df, model_index=0, shift_value=shift)
LRN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강    93814083.36  95638403.94      0.92     0.91 52418074.71 54191182.43
# 식음료      40267255.16  41095430.07      0.93     0.92 26203828.82 26585137.29
# 소매_편의   104092404.71 114487587.27      0.93     0.93 56199943.24 59559257.23
# 미용_패션    39869237.15  49352656.86      0.93     0.89 15072852.22 15530177.07
# 생활서비스    69205004.96  72096588.40      0.80     0.81 31268468.78 32098693.78
# 교육_학원    16074533.43  18783222.13      0.86     0.83  8872117.60  9115297.87
# 취미_레저   106185790.20  88634105.78      0.84     0.90 36669097.20 34018772.75
# 가구_전자기기  76659644.49  90245947.65      0.85     0.78 36573911.44 40208864.26
# 부동산_숙박    8520403.29  10405075.54      0.91     0.85  4252415.42  4989331.02
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              10.57           10.88      2               45.18
# 식음료                10.95           11.25      2               45.18
# 소매_편의              12.60           13.02      2               45.18
# 미용_패션              17.16           18.00      2               45.18
# 생활서비스              21.18           21.52      2               45.18
# 교육_학원              23.02           23.67      2               45.18
# 취미_레저              29.97           28.38      2               45.18
# 가구_전자기기            34.27           37.26      2               45.18
# 부동산_숙박             37.27           45.18      2               45.18
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.88                23.24
# 식음료                   10.88                23.24
# 소매_편의                 10.88                23.24
# 미용_패션                 10.88                23.24
# 생활서비스                 10.88                23.24
# 교육_학원                 10.88                23.24
# 취미_레저                 10.88                23.24
# 가구_전자기기               10.88                23.24
# 부동산_숙박                10.88                23.24

# %% [markdown]
# <h1>선형회귀 - Standard Scaler 적용</h1>

# %%
LRS_result = my_def.category_model_evaluation(df, model_index=0, scaler_type="standard", shift_value=shift)
LRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   83306976.32  82087792.32      0.93     0.94 46678867.34 49920526.70
# 식음료     35212148.41  39592549.96      0.95     0.93 24187375.70 25915137.71
# 소매_편의   92202108.79 101350778.67      0.95     0.94 50956328.99 55132426.97
# 미용_패션   35329796.26  45761518.89      0.94     0.91 13576899.01 14331566.49
# 생활서비스   53413195.52  55871076.88      0.88     0.89 26508501.58 28313521.12
# 교육_학원   14090665.98  17237879.70      0.89     0.86  8037950.21  8846928.16
# 취미_레저   80639420.36  73187796.10      0.91     0.93 31837054.84 32012124.96
# 부동산_숙박   6811301.38   9582054.18      0.94     0.88  3263107.88  4632612.35
# 가구_전자기기 63823843.74 282630634.46      0.90    -1.13 30348535.51 45570462.51
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강               9.42           10.02      2               42.22
# 식음료                10.11           10.97      2               42.22
# 소매_편의              11.43           12.05      2               42.22
# 미용_패션              15.46           16.61      2               42.22
# 생활서비스              17.95           18.98      2               42.22
# 교육_학원              20.85           22.98      2               42.22
# 취미_레저              26.02           26.71      2               42.22
# 부동산_숙박             28.60           41.95      2               42.22
# 가구_전자기기            28.44           42.22      2               42.22
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.02                22.50
# 식음료                   10.02                22.50
# 소매_편의                 10.02                22.50
# 미용_패션                 10.02                22.50
# 생활서비스                 10.02                22.50
# 교육_학원                 10.02                22.50
# 취미_레저                 10.02                22.50
# 부동산_숙박                10.02                22.50
# 가구_전자기기               10.02                22.50

# %% [markdown]
# <h1>선형회귀 - Min-Max Scaler 적용</h1>

# %%
LRM_result = my_def.category_model_evaluation(df, model_index=0, scaler_type="minmax", shift_value=shift)
LRM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   83306962.49  82087835.18      0.93     0.94 46678841.93 49920528.82
# 식음료     35212185.63  39592566.00      0.95     0.93 24187419.13 25915156.82
# 소매_편의   92202101.49 101350689.42      0.95     0.94 50956579.12 55132056.83
# 미용_패션   35329795.95  45761508.72      0.94     0.91 13576915.94 14331587.38
# 생활서비스   53413190.38  55871058.03      0.88     0.89 26508475.56 28313522.86
# 교육_학원   14090652.02  17237868.49      0.89     0.86  8037951.92  8846928.65
# 취미_레저   80639417.02  73187810.39      0.91     0.93 31837088.37 32012168.69
# 가구_전자기기 63823839.93  78576381.67      0.90     0.84 30348667.43 35499366.18
# 부동산_숙박   6811300.34   8422618.94      0.94     0.90  3263103.42  4358388.02
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강               9.42           10.02      2               39.46
# 식음료                10.11           10.97      2               39.46
# 소매_편의              11.43           12.05      2               39.46
# 미용_패션              15.46           16.61      2               39.46
# 생활서비스              17.95           18.98      2               39.46
# 교육_학원              20.85           22.98      2               39.46
# 취미_레저              26.02           26.71      2               39.46
# 가구_전자기기            28.44           32.89      2               39.46
# 부동산_숙박             28.60           39.46      2               39.46
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.02                21.19
# 식음료                   10.02                21.19
# 소매_편의                 10.02                21.19
# 미용_패션                 10.02                21.19
# 생활서비스                 10.02                21.19
# 교육_학원                 10.02                21.19
# 취미_레저                 10.02                21.19
# 가구_전자기기               10.02                21.19
# 부동산_숙박                10.02                21.19

# %% [markdown]
# <h1>업종별카테고리 랜덤포레스트 모델</h1>
# Polynomial Features & Standard Scaler 사용 안함<br>
# 9개 카테고리를 개별로해서 데이터프레임 형태로 저장

# %%
RFN_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift)
RFN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     11735772.02 32907840.38      0.99     0.95  7467544.59 20742688.82
# 의료_건강   35193546.24 92021553.35      0.99     0.92 18796169.19 51381522.51
# 소매_편의   34178270.98 99560007.79      0.99     0.95 18858156.85 52099210.26
# 미용_패션   14616819.23 36929006.02      0.99     0.94  5328707.27 13233680.66
# 생활서비스   21478492.32 58161294.35      0.98     0.88 10209722.97 28373161.44
# 교육_학원    5643082.17 17222181.75      0.98     0.86  3009066.88  8230382.60
# 취미_레저   36878208.47 62571537.52      0.98     0.95 11765911.77 26521398.22
# 가구_전자기기 25949154.09 88645855.36      0.98     0.79 12176237.51 37161482.58
# 부동산_숙박   2901623.67  8763309.77      0.99     0.90  1258700.62  4151514.46
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.12            8.78      2               37.59
# 의료_건강               3.79           10.32      2               37.59
# 소매_편의               4.23           11.39      2               37.59
# 미용_패션               6.07           15.34      2               37.59
# 생활서비스               6.92           19.02      2               37.59
# 교육_학원               7.81           21.37      2               37.59
# 취미_레저               9.62           22.12      2               37.59
# 가구_전자기기            11.41           34.43      2               37.59
# 부동산_숙박             11.03           37.59      2               37.59
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.78                20.04
# 의료_건강                  8.78                20.04
# 소매_편의                  8.78                20.04
# 미용_패션                  8.78                20.04
# 생활서비스                  8.78                20.04
# 교육_학원                  8.78                20.04
# 취미_레저                  8.78                20.04
# 가구_전자기기                8.78                20.04
# 부동산_숙박                 8.78                20.04

# %% [markdown]
# <h1>랜덤포레스트 모델 - Standard scaler</h1>

# %%
RFS_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift, scaler_type="standard")
RFS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     11637470.71 33033566.39      0.99     0.95  7431809.56 20684445.90
# 의료_건강   35805624.59 92762506.45      0.99     0.92 18825509.55 51148018.52
# 소매_편의   33781095.42 99187434.40      0.99     0.95 18849817.22 52177033.44
# 미용_패션   14701329.90 40052829.80      0.99     0.93  5317172.65 13566068.47
# 생활서비스   21843362.04 59087707.37      0.98     0.87 10239180.59 28591212.90
# 교육_학원    5521097.97 17361474.32      0.98     0.86  2988557.75  8224046.96
# 취미_레저   35897352.00 62227953.42      0.98     0.95 11638570.71 26605270.79
# 가구_전자기기 26319830.16 87916413.85      0.98     0.79 12182443.44 36840180.03
# 부동산_숙박   2860266.22  8747032.26      0.99     0.90  1229497.16  4223524.36
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.11            8.75      2               38.24
# 의료_건강               3.80           10.27      2               38.24
# 소매_편의               4.23           11.40      2               38.24
# 미용_패션               6.05           15.72      2               38.24
# 생활서비스               6.94           19.17      2               38.24
# 교육_학원               7.75           21.36      2               38.24
# 취미_레저               9.51           22.19      2               38.24
# 가구_전자기기            11.41           34.13      2               38.24
# 부동산_숙박             10.78           38.24      2               38.24
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.75                20.14
# 의료_건강                  8.75                20.14
# 소매_편의                  8.75                20.14
# 미용_패션                  8.75                20.14
# 생활서비스                  8.75                20.14
# 교육_학원                  8.75                20.14
# 취미_레저                  8.75                20.14
# 가구_전자기기                8.75                20.14
# 부동산_숙박                 8.75                20.14

# %% [markdown]
# <h1>랜덤포레스트 모델 - Min-Max scaler</h1>

# %%
RFM_result = my_def.category_model_evaluation(df, model_index=1, shift_value=shift, scaler_type="minmax")
RFM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse   test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     11849897.71 33067697.33      0.99     0.95  7498439.61 20758040.15
# 의료_건강   35961411.13 90658052.41      0.99     0.92 18798025.62 51130699.21
# 소매_편의   34312746.78 99204983.42      0.99     0.95 18938105.49 52030150.32
# 미용_패션   14472452.97 38405341.42      0.99     0.93  5337088.07 13541596.98
# 생활서비스   21960557.98 58602089.53      0.98     0.88 10213771.02 28457012.27
# 교육_학원    5466339.12 17223941.35      0.98     0.86  2986808.93  8211259.90
# 취미_레저   36939991.71 63528384.85      0.98     0.95 11751586.09 26665242.08
# 가구_전자기기 26158500.72 88401879.82      0.98     0.79 12261785.26 36783814.53
# 부동산_숙박   2863924.84  8543940.77      0.99     0.90  1250825.71  4138823.07
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 3.13            8.78      2               37.48
# 의료_건강               3.79           10.27      2               37.48
# 소매_편의               4.25           11.37      2               37.48
# 미용_패션               6.08           15.70      2               37.48
# 생활서비스               6.92           19.08      2               37.48
# 교육_학원               7.75           21.32      2               37.48
# 취미_레저               9.61           22.24      2               37.48
# 가구_전자기기            11.49           34.08      2               37.48
# 부동산_숙박             10.96           37.48      2               37.48
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.78                20.04
# 의료_건강                  8.78                20.04
# 소매_편의                  8.78                20.04
# 미용_패션                  8.78                20.04
# 생활서비스                  8.78                20.04
# 교육_학원                  8.78                20.04
# 취미_레저                  8.78                20.04
# 가구_전자기기                8.78                20.04
# 부동산_숙박                 8.78                20.04

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : None <h1>

# %%
GBN_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift)
GBN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     27957598.44  33580406.27      0.97     0.95 19087134.56 20988725.41
# 의료_건강   73116793.38  90321068.86      0.95     0.92 46095302.42 51770197.34
# 소매_편의   77448394.58 104980007.69      0.96     0.94 48307575.91 56161637.59
# 미용_패션   26511661.68  36711228.82      0.97     0.94 12633195.47 14143929.13
# 생활서비스   44749803.54  55248202.13      0.92     0.89 26089779.25 29319278.68
# 교육_학원   12164338.04  17520027.49      0.92     0.85  7526115.01  8685805.73
# 취미_레저   54280217.25  81848056.10      0.96     0.92 28183845.02 31483496.13
# 가구_전자기기 56991075.30  86961232.23      0.92     0.80 31516732.21 39369867.93
# 부동산_숙박   2736599.95   8596337.29      0.99     0.90  1719399.30  4298338.13
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.98            8.88      2               38.92
# 의료_건강               9.30           10.39      2               38.92
# 소매_편의              10.83           12.27      2               38.92
# 미용_패션              14.39           16.39      2               38.92
# 생활서비스              17.67           19.65      2               38.92
# 교육_학원              19.53           22.56      2               38.92
# 취미_레저              23.04           26.26      2               38.92
# 가구_전자기기            29.53           36.48      2               38.92
# 부동산_숙박             15.07           38.92      2               38.92
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.88                21.31
# 의료_건강                  8.88                21.31
# 소매_편의                  8.88                21.31
# 미용_패션                  8.88                21.31
# 생활서비스                  8.88                21.31
# 교육_학원                  8.88                21.31
# 취미_레저                  8.88                21.31
# 가구_전자기기                8.88                21.31
# 부동산_숙박                 8.88                21.31

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : Standard <h1>

# %%
GBS_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift, scaler_type="standard")
GBS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     27957598.44  33583562.50      0.97     0.95 19087134.56 20995116.70
# 의료_건강   73116793.38  90228535.30      0.95     0.92 46095302.42 51868390.21
# 소매_편의   77448394.58 104776367.70      0.96     0.94 48307575.91 56046317.33
# 미용_패션   26511661.68  37886283.08      0.97     0.94 12633195.47 14269806.97
# 생활서비스   44749803.54  55284000.26      0.92     0.89 26089779.25 29376548.07
# 교육_학원   12164338.04  17533631.73      0.92     0.85  7526115.01  8696616.54
# 취미_레저   54280217.25  82371863.66      0.96     0.92 28183845.02 31538923.54
# 가구_전자기기 56991075.30  86993074.75      0.92     0.80 31516732.21 39390326.48
# 부동산_숙박   2736599.95   8671256.32      0.99     0.90  1719399.30  4345551.62
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.98            8.88      2               39.35
# 의료_건강               9.30           10.41      2               39.35
# 소매_편의              10.83           12.25      2               39.35
# 미용_패션              14.39           16.54      2               39.35
# 생활서비스              17.67           19.69      2               39.35
# 교육_학원              19.53           22.59      2               39.35
# 취미_레저              23.04           26.31      2               39.35
# 가구_전자기기            29.53           36.50      2               39.35
# 부동산_숙박             15.07           39.35      2               39.35
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.88                21.39
# 의료_건강                  8.88                21.39
# 소매_편의                  8.88                21.39
# 미용_패션                  8.88                21.39
# 생활서비스                  8.88                21.39
# 교육_학원                  8.88                21.39
# 취미_레저                  8.88                21.39
# 가구_전자기기                8.88                21.39
# 부동산_숙박                 8.88                21.39

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : MinMax <h1>

# %%
GBM_result = my_def.category_model_evaluation(df, model_index=2, shift_value=shift, scaler_type="minmax")
GBM_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     27957598.44  33570717.84      0.97     0.95 19087134.56 20992011.95
# 의료_건강   72600060.40  90963536.39      0.95     0.92 46058185.77 51910193.34
# 소매_편의   76733092.91 104413853.01      0.96     0.94 48191839.33 56093471.96
# 미용_패션   26511661.68  36623269.33      0.97     0.94 12633195.47 14145313.02
# 생활서비스   44749803.54  55277205.50      0.92     0.89 26089779.25 29403744.90
# 교육_학원   12164292.40  17595103.56      0.92     0.85  7526087.92  8702856.34
# 취미_레저   54280415.05  81775466.77      0.96     0.92 28183530.72 31556982.39
# 가구_전자기기 57051550.16  86816158.43      0.92     0.80 31484834.90 39185893.27
# 부동산_숙박   2736599.95   8670472.36      0.99     0.90  1719399.30  4287028.43
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 7.98            8.88      2               38.82
# 의료_건강               9.29           10.42      2               38.82
# 소매_편의              10.81           12.26      2               38.82
# 미용_패션              14.39           16.39      2               38.82
# 생활서비스              17.67           19.71      2               38.82
# 교육_학원              19.53           22.60      2               38.82
# 취미_레저              23.04           26.33      2               38.82
# 가구_전자기기            29.50           36.31      2               38.82
# 부동산_숙박             15.07           38.82      2               38.82
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.88                21.30
# 의료_건강                  8.88                21.30
# 소매_편의                  8.88                21.30
# 미용_패션                  8.88                21.30
# 생활서비스                  8.88                21.30
# 교육_학원                  8.88                21.30
# 취미_레저                  8.88                21.30
# 가구_전자기기                8.88                21.30
# 부동산_숙박                 8.88                21.30

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : None <h1>

# %%
LGN_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift)
LGN_result.iloc[:,4:]
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000308 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2167
# [LightGBM] [Info] Number of data points in the train set: 6658, number of used features: 13
# [LightGBM] [Info] Start training from score 147643807.707420
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000261 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2172
# [LightGBM] [Info] Number of data points in the train set: 6748, number of used features: 15
# [LightGBM] [Info] Start training from score 445864150.336544
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000212 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2175
# [LightGBM] [Info] Number of data points in the train set: 6768, number of used features: 17
# [LightGBM] [Info] Start training from score 239302887.390810
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000264 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2177
# [LightGBM] [Info] Number of data points in the train set: 6648, number of used features: 18
# [LightGBM] [Info] Start training from score 495698978.151625
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2166
# [LightGBM] [Info] Number of data points in the train set: 5760, number of used features: 14
# [LightGBM] [Info] Start training from score 106724326.291840
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000266 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 6371, number of used features: 12
# [LightGBM] [Info] Start training from score 38542702.262596
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000260 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2178
# [LightGBM] [Info] Number of data points in the train set: 6738, number of used features: 18
# [LightGBM] [Info] Start training from score 87816763.181508
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000246 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2168
# [LightGBM] [Info] Number of data points in the train set: 6316, number of used features: 13
# [LightGBM] [Info] Start training from score 122347848.364946
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000145 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1324
# [LightGBM] [Info] Number of data points in the train set: 508, number of used features: 12
# [LightGBM] [Info] Start training from score 11409327.704724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     22678274.08  33070629.01      0.98     0.95 15346727.86 19950466.45
# 의료_건강   69422046.07  92131518.82      0.95     0.92 39619578.10 51897726.05
# 소매_편의   76366814.50 113619297.71      0.96     0.93 41247359.77 54539334.94
# 미용_패션   30409885.36  42223918.36      0.96     0.92 11199130.04 14637628.20
# 생활서비스   37969244.26  51641712.17      0.94     0.90 21122071.33 28323666.38
# 교육_학원    9600305.85  16912322.53      0.95     0.86  5914995.13  8233833.08
# 취미_레저   73283217.42  78362055.64      0.92     0.92 26575558.09 32446992.52
# 가구_전자기기 44253241.59  87158228.83      0.95     0.80 24299123.05 38312098.42
# 부동산_숙박   5845910.26  12913376.92      0.96     0.78  2339143.61  5792572.40
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 6.41            8.44      2               52.45
# 의료_건강               7.99           10.42      2               52.45
# 소매_편의               9.25           11.92      2               52.45
# 미용_패션              12.75           16.97      2               52.45
# 생활서비스              14.31           18.99      2               52.45
# 교육_학원              15.35           21.38      2               52.45
# 취미_레저              21.72           27.07      2               52.45
# 가구_전자기기            22.77           35.50      2               52.45
# 부동산_숙박             20.50           52.45      2               52.45
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.44                22.57
# 의료_건강                  8.44                22.57
# 소매_편의                  8.44                22.57
# 미용_패션                  8.44                22.57
# 생활서비스                  8.44                22.57
# 교육_학원                  8.44                22.57
# 취미_레저                  8.44                22.57
# 가구_전자기기                8.44                22.57
# 부동산_숙박                 8.44                22.57

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : Standard <h1>

# %%
LGS_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift, scaler_type="standard")
LGS_result.iloc[:,4:]
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000415 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2169
# [LightGBM] [Info] Number of data points in the train set: 6658, number of used features: 13
# [LightGBM] [Info] Start training from score 147643807.707420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000528 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2176
# [LightGBM] [Info] Number of data points in the train set: 6748, number of used features: 15
# [LightGBM] [Info] Start training from score 445864150.336544
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2181
# [LightGBM] [Info] Number of data points in the train set: 6768, number of used features: 17
# [LightGBM] [Info] Start training from score 239302887.390810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000759 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2184
# [LightGBM] [Info] Number of data points in the train set: 6648, number of used features: 18
# [LightGBM] [Info] Start training from score 495698978.151625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000577 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2169
# [LightGBM] [Info] Number of data points in the train set: 5760, number of used features: 14
# [LightGBM] [Info] Start training from score 106724326.291840
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000270 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2166
# [LightGBM] [Info] Number of data points in the train set: 6371, number of used features: 12
# [LightGBM] [Info] Start training from score 38542702.262596
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001103 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2185
# [LightGBM] [Info] Number of data points in the train set: 6738, number of used features: 18
# [LightGBM] [Info] Start training from score 87816763.181508
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000331 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2170
# [LightGBM] [Info] Number of data points in the train set: 6316, number of used features: 13
# [LightGBM] [Info] Start training from score 122347848.364946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000102 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1329
# [LightGBM] [Info] Number of data points in the train set: 508, number of used features: 12
# [LightGBM] [Info] Start training from score 11409327.704724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     22721286.80  33278046.81      0.98     0.95 15353811.79 20064037.85
# 의료_건강   69272117.96  95525113.76      0.96     0.91 39643046.90 52860090.81
# 소매_편의   75280239.25 108892556.13      0.96     0.94 40956859.18 53962669.08
# 미용_패션   30579652.77  42353837.53      0.96     0.92 11212728.97 14578142.77
# 생활서비스   37890307.85  51511037.30      0.94     0.90 21065817.99 28303436.06
# 교육_학원    9564869.58  16686481.09      0.95     0.87  5906529.69  8194300.42
# 취미_레저   73557843.23  78459913.81      0.92     0.92 26749679.00 32587712.52
# 가구_전자기기 44058893.16  87309281.74      0.95     0.80 24278096.00 38664546.25
# 부동산_숙박   5776574.23  12637549.62      0.96     0.79  2335784.01  5622476.79
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 6.42            8.49      2               50.91
# 의료_건강               8.00           10.61      2               50.91
# 소매_편의               9.19           11.79      2               50.91
# 미용_패션              12.77           16.90      2               50.91
# 생활서비스              14.27           18.97      2               50.91
# 교육_학원              15.32           21.28      2               50.91
# 취미_레저              21.86           27.19      2               50.91
# 가구_전자기기            22.75           35.83      2               50.91
# 부동산_숙박             20.47           50.91      2               50.91
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.49                22.44
# 의료_건강                  8.49                22.44
# 소매_편의                  8.49                22.44
# 미용_패션                  8.49                22.44
# 생활서비스                  8.49                22.44
# 교육_학원                  8.49                22.44
# 취미_레저                  8.49                22.44
# 가구_전자기기                8.49                22.44
# 부동산_숙박                 8.49                22.44

# %% [markdown]
# <h1>그래디언트 부스팅 - Scaler : MinMax <h1>

# %%
LGM_result = my_def.category_model_evaluation(df, model_index=3, shift_value=shift, scaler_type="minmax")
LGM_result.iloc[:,4:]
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000214 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2164
# [LightGBM] [Info] Number of data points in the train set: 6658, number of used features: 13
# [LightGBM] [Info] Start training from score 147643807.707420
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000345 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2169
# [LightGBM] [Info] Number of data points in the train set: 6748, number of used features: 15
# [LightGBM] [Info] Start training from score 445864150.336544
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000235 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2172
# [LightGBM] [Info] Number of data points in the train set: 6768, number of used features: 17
# [LightGBM] [Info] Start training from score 239302887.390810
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000283 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2174
# [LightGBM] [Info] Number of data points in the train set: 6648, number of used features: 18
# [LightGBM] [Info] Start training from score 495698978.151625
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000250 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2163
# [LightGBM] [Info] Number of data points in the train set: 5760, number of used features: 14
# [LightGBM] [Info] Start training from score 106724326.291840
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000216 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2162
# [LightGBM] [Info] Number of data points in the train set: 6371, number of used features: 12
# [LightGBM] [Info] Start training from score 38542702.262596
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000451 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2175
# [LightGBM] [Info] Number of data points in the train set: 6738, number of used features: 18
# [LightGBM] [Info] Start training from score 87816763.181508
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000296 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2165
# [LightGBM] [Info] Number of data points in the train set: 6316, number of used features: 13
# [LightGBM] [Info] Start training from score 122347848.364946
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000106 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1321
# [LightGBM] [Info] Number of data points in the train set: 508, number of used features: 12
# [LightGBM] [Info] Start training from score 11409327.704724
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#          train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 식음료     22646748.85  32949328.76      0.98     0.95 15318542.69 19805488.60
# 의료_건강   68996913.56  91777061.87      0.96     0.92 39431292.35 51846316.67
# 소매_편의   77391040.88 113730387.45      0.96     0.93 41444771.98 54813140.88
# 미용_패션   30610035.43  42003333.19      0.96     0.92 11257839.52 14525825.03
# 생활서비스   37836559.26  50954798.96      0.94     0.91 21062589.40 28215551.56
# 교육_학원    9624173.31  16912761.07      0.95     0.86  5934215.88  8221422.08
# 취미_레저   72629065.97  82036004.05      0.93     0.92 26575276.35 32576444.45
# 가구_전자기기 44260415.55  86802313.81      0.95     0.80 24328506.14 38585890.23
# 부동산_숙박   5766634.24  12906515.19      0.96     0.78  2330120.14  5710917.68
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 식음료                 6.40            8.38      2               51.71
# 의료_건강               7.95           10.41      2               51.71
# 소매_편의               9.30           11.98      2               51.71
# 미용_패션              12.82           16.84      2               51.71
# 생활서비스              14.27           18.91      2               51.71
# 교육_학원              15.40           21.35      2               51.71
# 취미_레저              21.72           27.18      2               51.71
# 가구_전자기기            22.80           35.75      2               51.71
# 부동산_숙박             20.42           51.71      2               51.71
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 식음료                    8.38                22.50
# 의료_건강                  8.38                22.50
# 소매_편의                  8.38                22.50
# 미용_패션                  8.38                22.50
# 생활서비스                  8.38                22.50
# 교육_학원                  8.38                22.50
# 취미_레저                  8.38                22.50
# 가구_전자기기                8.38                22.50
# 부동산_숙박                 8.38                22.50

# %% [markdown]
# <h1>SVR - Scaler : None <h1>

# %%
SVRN_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift)
SVRN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   330306471.37 331642866.82     -0.02    -0.02 205101017.74
# 식음료     158988508.47 152592973.45     -0.05    -0.04 108859283.61
# 소매_편의   400680920.66 439252466.95     -0.04    -0.04 220867201.61
# 생활서비스   157926030.83 170564181.23     -0.05    -0.05  91369534.71
# 교육_학원    44482696.38  47684747.84     -0.10    -0.08  26611283.66
# 미용_패션   154300270.98 154792612.20     -0.09    -0.08  65903376.07
# 취미_레저   273458818.35 290302155.59     -0.05    -0.04  94251926.69
# 가구_전자기기 210100805.77 206570386.08     -0.13    -0.14  93827009.09
# 부동산_숙박   29651493.05  28753985.02     -0.11    -0.11  10841140.04
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   208774744.09            41.38           41.92      2
# 식음료     105536307.21            45.49           44.66      2
# 소매_편의   223188720.82            49.54           48.78      2
# 생활서비스    96449344.85            61.89           64.65      2
# 교육_학원    27104211.97            69.04           70.39      2
# 미용_패션    63476939.86            75.05           73.57      2
# 취미_레저    93823769.67            77.04           78.27      2
# 가구_전자기기  94010618.87            87.92           87.11      2
# 부동산_숙박   10320735.97            95.02           93.45      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 93.45               41.92                66.98
# 식음료                   93.45               41.92                66.98
# 소매_편의                 93.45               41.92                66.98
# 생활서비스                 93.45               41.92                66.98
# 교육_학원                 93.45               41.92                66.98
# 미용_패션                 93.45               41.92                66.98
# 취미_레저                 93.45               41.92                66.98
# 가구_전자기기               93.45               41.92                66.98
# 부동산_숙박                93.45               41.92                66.98

# %% [markdown]
# <h1>SVR - Scaler : Standard <h1>

# %%
SVRS_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift, scaler_type="standard")
SVRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   330306987.60 331643404.78     -0.02    -0.02 205101646.58
# 식음료     158989361.61 152593828.75     -0.05    -0.04 108860081.75
# 소매_편의   400681436.51 439252931.63     -0.04    -0.04 220867844.59
# 생활서비스   157926610.33 170564726.24     -0.05    -0.05  91370286.05
# 교육_학원    44483534.58  47685532.58     -0.10    -0.08  26612000.10
# 미용_패션   154300607.79 154792936.27     -0.09    -0.08  65903803.90
# 취미_레저   273459060.79 290302378.33     -0.05    -0.04  94252283.86
# 가구_전자기기 210101204.82 206570783.24     -0.13    -0.14  93827352.99
# 부동산_숙박   29651510.01  28753999.87     -0.11    -0.11  10841156.44
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   208775372.28            41.38           41.92      2
# 식음료     105537085.56            45.49           44.66      2
# 소매_편의   223189361.24            49.54           48.78      2
# 생활서비스    96450094.38            61.89           64.65      2
# 교육_학원    27104917.81            69.05           70.39      2
# 미용_패션    63477359.63            75.05           73.57      2
# 취미_레저    93824125.56            77.04           78.27      2
# 가구_전자기기  94010962.89            87.92           87.11      2
# 부동산_숙박   10320751.76            95.02           93.45      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 93.45               41.92                66.98
# 식음료                   93.45               41.92                66.98
# 소매_편의                 93.45               41.92                66.98
# 생활서비스                 93.45               41.92                66.98
# 교육_학원                 93.45               41.92                66.98
# 미용_패션                 93.45               41.92                66.98
# 취미_레저                 93.45               41.92                66.98
# 가구_전자기기               93.45               41.92                66.98
# 부동산_숙박                93.45               41.92                66.98

# %% [markdown]
# <h1>SVR - Scaler : MinMax <h1>

# %%
SVRM_result = my_def.category_model_evaluation(df, model_index=4, shift_value=shift, scaler_type="minmax")
SVRS_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   330306987.60 331643404.78     -0.02    -0.02 205101646.58
# 식음료     158989361.61 152593828.75     -0.05    -0.04 108860081.75
# 소매_편의   400681436.51 439252931.63     -0.04    -0.04 220867844.59
# 생활서비스   157926610.33 170564726.24     -0.05    -0.05  91370286.05
# 교육_학원    44483534.58  47685532.58     -0.10    -0.08  26612000.10
# 미용_패션   154300607.79 154792936.27     -0.09    -0.08  65903803.90
# 취미_레저   273459060.79 290302378.33     -0.05    -0.04  94252283.86
# 가구_전자기기 210101204.82 206570783.24     -0.13    -0.14  93827352.99
# 부동산_숙박   29651510.01  28753999.87     -0.11    -0.11  10841156.44
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   208775372.28            41.38           41.92      2
# 식음료     105537085.56            45.49           44.66      2
# 소매_편의   223189361.24            49.54           48.78      2
# 생활서비스    96450094.38            61.89           64.65      2
# 교육_학원    27104917.81            69.05           70.39      2
# 미용_패션    63477359.63            75.05           73.57      2
# 취미_레저    93824125.56            77.04           78.27      2
# 가구_전자기기  94010962.89            87.92           87.11      2
# 부동산_숙박   10320751.76            95.02           93.45      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 93.45               41.92                66.98
# 식음료                   93.45               41.92                66.98
# 소매_편의                 93.45               41.92                66.98
# 생활서비스                 93.45               41.92                66.98
# 교육_학원                 93.45               41.92                66.98
# 미용_패션                 93.45               41.92                66.98
# 취미_레저                 93.45               41.92                66.98
# 가구_전자기기               93.45               41.92                66.98
# 부동산_숙박                93.45               41.92                66.98

# %% [markdown]
# <h1>MLPR - Scaler : None <h1>

# %%
MLPN_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift)
MLPN_result.iloc[:,4:]
# Out:
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강    95124228.83  95167036.08      0.92     0.92 52003382.61 53661363.94
# 식음료      40752632.19  41590498.40      0.93     0.92 26546600.27 26991753.10
# 소매_편의   104952405.68 114995639.39      0.93     0.93 57024303.99 60534885.21
# 미용_패션    40205618.13  49360731.46      0.93     0.89 14830051.63 15164637.17
# 생활서비스    69966981.88  73805823.75      0.79     0.80 30377716.30 31027292.21
# 교육_학원    16122568.77  18831312.86      0.86     0.83  8785288.36  9076814.70
# 취미_레저   106287919.03  89133959.26      0.84     0.90 35785530.03 32941610.92
# 가구_전자기기  76952211.94  90500891.48      0.85     0.78 35474587.47 39063227.79
# 부동산_숙박    8575360.37  10467708.53      0.91     0.85  4017954.10  4710317.83
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              10.49           10.77      2               42.65
# 식음료                11.09           11.42      2               42.65
# 소매_편의              12.79           13.23      2               42.65
# 미용_패션              16.89           17.58      2               42.65
# 생활서비스              20.58           20.80      2               42.65
# 교육_학원              22.79           23.57      2               42.65
# 취미_레저              29.25           27.48      2               42.65
# 가구_전자기기            33.24           36.19      2               42.65
# 부동산_숙박             35.22           42.65      2               42.65
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.77                22.63
# 식음료                   10.77                22.63
# 소매_편의                 10.77                22.63
# 미용_패션                 10.77                22.63
# 생활서비스                 10.77                22.63
# 교육_학원                 10.77                22.63
# 취미_레저                 10.77                22.63
# 가구_전자기기               10.77                22.63
# 부동산_숙박                10.77                22.63

# %% [markdown]
# <h1>MLPR - Scaler : Standard <h1>

# %%
MLPS_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift, scaler_type="standard")
MLPS_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 교육_학원    57293257.83  59797798.57     -0.82    -0.70  38502265.99
# 미용_패션   171916271.88 171972781.27     -0.35    -0.34  87778500.46
# 생활서비스   213286413.16 223580603.26     -0.92    -0.80 147602897.79
# 취미_레저   293258941.29 308533382.06     -0.21    -0.18 122312868.38
# 식음료     285168261.55 279485227.84     -2.38    -2.51 239262004.63
# 가구_전자기기 224604198.74 221499611.56     -0.29    -0.31 106696709.02
# 의료_건강   593575124.21 596084167.61     -2.30    -2.31 495653048.61
# 소매_편의   594578039.53 628157639.67     -1.28    -1.13 445826968.32
# 부동산_숙박   30324044.02  29423069.58     -0.16    -0.16  11409110.69
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 교육_학원    38466589.06            99.90           99.90      2
# 미용_패션    86242808.80            99.96           99.96      2
# 생활서비스   149141350.56            99.97           99.97      2
# 취미_레저   119839090.50            99.97           99.97      2
# 식음료     236289034.76            99.98           99.98      2
# 가구_전자기기 107899337.02            99.97           99.98      2
# 의료_건강   498004575.58            99.99           99.99      2
# 소매_편의   457536785.33            99.99           99.99      2
# 부동산_숙박   11043665.79           100.00          100.00      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 교육_학원                100.00               99.90                99.97
# 미용_패션                100.00               99.90                99.97
# 생활서비스                100.00               99.90                99.97
# 취미_레저                100.00               99.90                99.97
# 식음료                  100.00               99.90                99.97
# 가구_전자기기              100.00               99.90                99.97
# 의료_건강                100.00               99.90                99.97
# 소매_편의                100.00               99.90                99.97
# 부동산_숙박               100.00               99.90                99.97

# %% [markdown]
# <h1>MLPR - Scaler : MinMax <h1>

# %%
MLPM_result = my_def.category_model_evaluation(df, model_index=5, shift_value=shift, scaler_type="minmax")
MLPM_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 교육_학원    57326812.31  59829811.37     -0.82    -0.71  38526265.66
# 미용_패션   171951970.65 172004123.16     -0.35    -0.34  87800951.84
# 생활서비스   213315852.37 223608882.30     -0.92    -0.80 147625038.27
# 식음료     285194651.13 279509307.41     -2.38    -2.51 239280489.97
# 가구_전자기기 224630732.98 221524866.56     -0.29    -0.31 106709298.24
# 취미_레저   293283453.15 308557046.77     -0.21    -0.18 122332266.78
# 의료_건강   593603521.10 596109735.03     -2.30    -2.31 495677039.41
# 소매_편의   594599375.81 628177666.57     -1.28    -1.13 445844599.45
# 부동산_숙박   30324230.30  29423252.12     -0.16    -0.16  11409083.65
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 교육_학원    38489209.96            99.96           99.96      2
# 미용_패션    86262555.39            99.98           99.98      2
# 생활서비스   149161007.16            99.99           99.99      2
# 식음료     236305721.14            99.99           99.99      2
# 가구_전자기기 107910326.07            99.99           99.99      2
# 취미_레저   119856440.88            99.99           99.99      2
# 의료_건강   498025918.06           100.00          100.00      2
# 소매_편의   457553398.87           100.00          100.00      2
# 부동산_숙박   11043649.83           100.00          100.00      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 교육_학원                100.00               99.96                99.99
# 미용_패션                100.00               99.96                99.99
# 생활서비스                100.00               99.96                99.99
# 식음료                  100.00               99.96                99.99
# 가구_전자기기              100.00               99.96                99.99
# 취미_레저                100.00               99.96                99.99
# 의료_건강                100.00               99.96                99.99
# 소매_편의                100.00               99.96                99.99
# 부동산_숙박               100.00               99.96                99.99

# %% [markdown]
# <h1>ESM - Scaler : None <h1>

# %%
ESN_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift)
ESN_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.589e+19, tolerance: 1.579e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.577e+19, tolerance: 1.044e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.273e+18, tolerance: 1.630e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.890e+19, tolerance: 7.091e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.689e+19, tolerance: 2.251e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.971e+17, tolerance: 1.148e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.326e+18, tolerance: 1.473e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.552e+19, tolerance: 4.488e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.837e+16, tolerance: 4.010e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강    93220974.37  95597953.51      0.92     0.91 52154204.88 54112405.22
# 식음료      39437760.76  40403818.81      0.94     0.93 25765855.48 26099114.75
# 소매_편의   102937250.09 113747651.04      0.93     0.93 54817665.47 58363683.93
# 미용_패션    39746160.10  49303231.73      0.93     0.89 15125576.90 15552648.99
# 생활서비스    69078386.89  71956256.63      0.80     0.81 31304810.42 32198876.78
# 교육_학원    15804566.10  18665975.99      0.86     0.83  8710107.98  9068285.08
# 취미_레저   106042795.66  88796009.80      0.84     0.90 36641498.08 34072442.96
# 가구_전자기기  76563463.77  90372362.11      0.85     0.78 36677973.82 40461036.38
# 부동산_숙박    8490110.25  10381755.51      0.91     0.86  4231163.00  4980452.23
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              10.52           10.86      2               45.10
# 식음료                10.77           11.04      2               45.10
# 소매_편의              12.29           12.76      2               45.10
# 미용_패션              17.22           18.03      2               45.10
# 생활서비스              21.20           21.58      2               45.10
# 교육_학원              22.60           23.55      2               45.10
# 취미_레저              29.95           28.42      2               45.10
# 가구_전자기기            34.37           37.49      2               45.10
# 부동산_숙박             37.09           45.10      2               45.10
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 10.86                23.20
# 식음료                   10.86                23.20
# 소매_편의                 10.86                23.20
# 미용_패션                 10.86                23.20
# 생활서비스                 10.86                23.20
# 교육_학원                 10.86                23.20
# 취미_레저                 10.86                23.20
# 가구_전자기기               10.86                23.20
# 부동산_숙박                10.86                23.20

# %% [markdown]
# <h1>ESM - Scaler : standard <h1>

# %%
ESS_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift, scaler_type="standard")
ESS_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.202e+19, tolerance: 1.579e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.603e+20, tolerance: 1.044e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.522e+19, tolerance: 1.630e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.664e+19, tolerance: 7.091e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.695e+19, tolerance: 2.251e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.195e+17, tolerance: 1.148e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.452e+19, tolerance: 1.473e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.249e+19, tolerance: 4.488e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.259e+16, tolerance: 4.010e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2   train_mae    test_mae  \
# 의료_건강   106155334.84 106669353.84      0.89     0.89 63730492.89 66753732.69
# 식음료      47041925.94  48854512.56      0.91     0.89 32887633.85 33930589.66
# 소매_편의   153079223.13 196196101.18      0.85     0.79 66647708.30 72735778.19
# 생활서비스    63618014.65  64784039.50      0.83     0.85 33446627.50 36598097.98
# 미용_패션    46105763.49  55882315.13      0.90     0.86 20396963.54 21359939.52
# 교육_학원    16601030.40  19504994.07      0.85     0.82 10066496.88 10729647.34
# 취미_레저   100016662.42  87104341.20      0.86     0.91 39268187.67 38278561.84
# 가구_전자기기  74213205.23  86443170.43      0.86     0.80 39413323.54 43681431.72
# 부동산_숙박    8813730.40   9188687.32      0.90     0.89  4435737.76  4902365.53
#
#          train_mae_ratio  test_mae_ratio  Shift  test_mae_ratio_max  \
# 의료_건강              12.86           13.40      2               44.39
# 식음료                13.74           14.36      2               44.39
# 소매_편의              14.95           15.90      2               44.39
# 생활서비스              22.65           24.53      2               44.39
# 미용_패션              23.23           24.76      2               44.39
# 교육_학원              26.12           27.87      2               44.39
# 취미_레저              32.10           31.93      2               44.39
# 가구_전자기기            36.93           40.47      2               44.39
# 부동산_숙박             38.88           44.39      2               44.39
#
#          test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                 13.40                26.40
# 식음료                   13.40                26.40
# 소매_편의                 13.40                26.40
# 생활서비스                 13.40                26.40
# 미용_패션                 13.40                26.40
# 교육_학원                 13.40                26.40
# 취미_레저                 13.40                26.40
# 가구_전자기기               13.40                26.40
# 부동산_숙박                13.40                26.40

# %% [markdown]
# <h1>ESM - Scaler : MinMax <h1>

# %%
ESM_result = my_def.category_model_evaluation(df, model_index=6, shift_value=shift, scaler_type="minmax")
ESM_result.iloc[:,4:]
# Out:
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.564e+19, tolerance: 1.579e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.591e+20, tolerance: 1.044e+17
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.906e+19, tolerance: 1.630e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.419e+20, tolerance: 7.091e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.707e+19, tolerance: 2.251e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.613e+17, tolerance: 1.148e+15
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.790e+19, tolerance: 1.473e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.444e+20, tolerance: 4.488e+16
#   model = cd_fast.enet_coordinate_descent(
# c:\Dev\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.093e+16, tolerance: 4.010e+13
#   model = cd_fast.enet_coordinate_descent(
# c:\Work\Project\teamproject_02\oos\머신러닝\my_def.py:983: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   results_df = results_df.apply(pd.to_numeric, errors='ignore')
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   320180877.08 321539171.25      0.04     0.04 204852867.94
# 식음료     148676852.91 143115321.64      0.08     0.08 107412664.64
# 소매_편의   388015378.64 425537487.08      0.03     0.02 226153265.26
# 생활서비스   151395326.60 163945009.63      0.03     0.03  93887559.15
# 교육_학원    41484251.50  44782408.13      0.05     0.04  28022219.60
# 미용_패션   145568732.72 146854248.67      0.03     0.03  76413033.44
# 취미_레저   263295878.67 280739413.43      0.02     0.03 107734867.20
# 가구_전자기기 194079056.06 190230695.28      0.04     0.03 112100370.17
# 부동산_숙박   25605057.19  24815449.94      0.17     0.17  13071029.21
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   208912135.52            41.33           41.95      2
# 식음료     104947435.81            44.89           44.41      2
# 소매_편의   224294329.71            50.72           49.02      2
# 생활서비스    99223350.94            63.59           66.51      2
# 교육_학원    28632092.65            72.70           74.36      2
# 미용_패션    74472840.88            87.01           86.32      2
# 취미_레저   108712196.64            88.06           90.69      2
# 가구_전자기기 111385383.92           105.04          103.21      2
# 부동산_숙박   12609149.11           114.56          114.17      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                114.17               41.95                74.52
# 식음료                  114.17               41.95                74.52
# 소매_편의                114.17               41.95                74.52
# 생활서비스                114.17               41.95                74.52
# 교육_학원                114.17               41.95                74.52
# 미용_패션                114.17               41.95                74.52
# 취미_레저                114.17               41.95                74.52
# 가구_전자기기              114.17               41.95                74.52
# 부동산_숙박               114.17               41.95                74.52

# %%
ESM_result.iloc[:,:]
# Out:
#               Model Scaler             train_mse              test_mse  \
# 의료_건강    ElasticNet   None 102515794049206544.00 103387438648641856.00
# 식음료      ElasticNet   None  22104806591444000.00  20481995289092840.00
# 소매_편의    ElasticNet   None 150555934064717984.00 181082152909575520.00
# 생활서비스    ElasticNet   None  22920544916292540.00  26877966183526560.00
# 교육_학원    ElasticNet   None   1720943122531563.00   2005464077959997.75
# 미용_패션    ElasticNet   None  21190255946515608.00  21566170351156712.00
# 취미_레저    ElasticNet   None  69324719725078592.00  78814618254588176.00
# 가구_전자기기  ElasticNet   None  37666679999402448.00  36187717425218816.00
# 부동산_숙박   ElasticNet   None    655618953731435.62    615806555664168.25
#
#           train_rmse    test_rmse  train_r2  test_r2    train_mae  \
# 의료_건강   320180877.08 321539171.25      0.04     0.04 204852867.94
# 식음료     148676852.91 143115321.64      0.08     0.08 107412664.64
# 소매_편의   388015378.64 425537487.08      0.03     0.02 226153265.26
# 생활서비스   151395326.60 163945009.63      0.03     0.03  93887559.15
# 교육_학원    41484251.50  44782408.13      0.05     0.04  28022219.60
# 미용_패션   145568732.72 146854248.67      0.03     0.03  76413033.44
# 취미_레저   263295878.67 280739413.43      0.02     0.03 107734867.20
# 가구_전자기기 194079056.06 190230695.28      0.04     0.03 112100370.17
# 부동산_숙박   25605057.19  24815449.94      0.17     0.17  13071029.21
#
#             test_mae  train_mae_ratio  test_mae_ratio  Shift  \
# 의료_건강   208912135.52            41.33           41.95      2
# 식음료     104947435.81            44.89           44.41      2
# 소매_편의   224294329.71            50.72           49.02      2
# 생활서비스    99223350.94            63.59           66.51      2
# 교육_학원    28632092.65            72.70           74.36      2
# 미용_패션    74472840.88            87.01           86.32      2
# 취미_레저   108712196.64            88.06           90.69      2
# 가구_전자기기 111385383.92           105.04          103.21      2
# 부동산_숙박   12609149.11           114.56          114.17      2
#
#          test_mae_ratio_max  test_mae_ratio_min  test_mae_ratio_mean
# 의료_건강                114.17               41.95                74.52
# 식음료                  114.17               41.95                74.52
# 소매_편의                114.17               41.95                74.52
# 생활서비스                114.17               41.95                74.52
# 교육_학원                114.17               41.95                74.52
# 미용_패션                114.17               41.95                74.52
# 취미_레저                114.17               41.95                74.52
# 가구_전자기기              114.17               41.95                74.52
# 부동산_숙박               114.17               41.95                74.52

# %%
ESM_result["Scaler"].unique()
# Out:
# array(['None'], dtype=object)

# %%
# 각 데이터프레임의 인덱스를 리셋한 후 새로운 변수로 저장합니다.
ESM_result2 = ESM_result.reset_index()
ESS_result2 = ESS_result.reset_index()
ESN_result2 = ESN_result.reset_index()
MLPM_result2 = MLPM_result.reset_index()
MLPS_result2 = MLPS_result.reset_index()
MLPN_result2 = MLPN_result.reset_index()
SVRS_result2 = SVRS_result.reset_index()
SVRM_result2 = SVRM_result.reset_index()
SVRN_result2 = SVRN_result.reset_index()
LGM_result2 = LGM_result.reset_index()
LGS_result2 = LGS_result.reset_index()
LGN_result2 = LGN_result.reset_index()
GBM_result2 = GBM_result.reset_index()
GBS_result2 = GBS_result.reset_index()
GBN_result2 = GBN_result.reset_index()
RFM_result2 = RFM_result.reset_index()
RFS_result2 = RFS_result.reset_index()
RFN_result2 = RFN_result.reset_index()
LRM_result2 = LRM_result.reset_index()
LRS_result2 = LRS_result.reset_index()
LRN_result2 = LRN_result.reset_index()

# %%
import pandas as pd

# 데이터프레임 목록 생성
df_list = [
    ESM_result2, ESS_result2, ESN_result2,
    MLPM_result2, MLPS_result2, MLPN_result2,
    SVRS_result2, SVRM_result2, SVRN_result2,
    LGM_result2, LGS_result2, LGN_result2,
    GBM_result2, GBS_result2, GBN_result2,
    RFM_result2, RFS_result2, RFN_result2,
    LRM_result2, LRS_result2, LRN_result2
]

# 데이터프레임 이름 목록 생성
df_names = [
    'ESM', 'ESS', 'ESN',
    'MLPM', 'MLPS', 'MLPN',
    'SVRS', 'SVRM', 'SVRN',
    'LGM', 'LGS', 'LGN',
    'GBM', 'GBS', 'GBN',
    'RFM', 'RFS', 'RFN',
    'LRM', 'LRS', 'LRN'
]

# 각 데이터프레임에 대해 Scaler 값을 업데이트
for df, name in zip(df_list, df_names):
    suffix = name[-1]  # 이름에서 마지막 문자를 추출
    if suffix == 'S':
        scaler_value = 'Standard'
    elif suffix == 'M':
        scaler_value = 'MinMax'
    elif suffix == 'N':
        scaler_value = 'Default'
    else:
        continue  # 해당하지 않으면 건너뜀
    
    # Scaler 컬럼 값을 업데이트
    if 'Scaler' in df.columns:
        df['Scaler'] = scaler_value
    else:
        print(f"DataFrame {name} does not have a 'Scaler' column.")

# %%
all_results = [
    ESM_result2, ESS_result2, ESN_result2,
    MLPM_result2, MLPS_result2, MLPN_result2,
    SVRS_result2, SVRM_result2, SVRN_result2,
    LGM_result2, LGS_result2, LGN_result2,
    GBM_result2, GBS_result2, GBN_result2,
    RFM_result2, RFS_result2, RFN_result2,
    LRM_result2, LRS_result2, LRN_result2
]

# 모든 데이터프레임을 행 방향으로 병합
df_combined = pd.concat(all_results, ignore_index=True)

# %%
col = ['Shift', 'Model', 'Scaler', 'index', 'train_r2', 'test_r2', 'train_mse', 'test_mse','train_mae_ratio', 'test_mae_ratio', 'test_mae_ratio_max','test_mae_ratio_min', 'test_mae_ratio_mean', 'train_mae', 'test_mae', 'train_rmse', 'test_rmse']
df_combined = df_combined[col]

# %%
df_combined.to_csv("single_category_shift2.csv", index=False)

# %%
data = pd.read_csv("single_category_shift2.csv")
data.groupby(["Model", "Scaler"])["index"].count()
# Out:
# Model                      Scaler
# ElasticNet                 Default     9
#                            MinMax      9
#                            Standard    9
# GradientBoostingRegressor  Default     9
#                            MinMax      9
#                            Standard    9
# LGBMRegressor              Default     9
#                            MinMax      9
#                            Standard    9
# LinearRegression           Default     9
#                            MinMax      9
#                            Standard    9
# MLPRegressor               Default     9
#                            MinMax      9
#                            Standard    9
# RandomForestRegressor      Default     9
#                            MinMax      9
#                            Standard    9
# SVR                        Default     9
#                            MinMax      9
#                            Standard    9
# Name: index, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shift                189 non-null    int64
#  1   Model                189 non-null    object
#  2   Scaler               189 non-null    object
#  3   index                189 non-null    object
#  4   train_r2             189 non-null    float64
#  5   test_r2              189 non-null    float64
#  6   train_mse            189 non-null    float64
#  7   test_mse             189 non-null    float64
#  8   train_mae_ratio      189 non-null    float64
#  9   test_mae_ratio       189 non-null    float64
#  10  test_mae_ratio_max   189 non-null    float64
#  11  test_mae_ratio_min   189 non-null    float64
#  12  test_mae_ratio_mean  189 non-null    float64
#  13  train_mae            189 non-null    float64
#  14  test_mae             189 non-null    float64
#  15  train_rmse           189 non-null    float64
#  16  test_rmse            189 non-null    float64
# dtypes: float64(13), int64(1), object(3)
# memory usage: 25.2+ KB

# %%
data.head()
# Out:
#    Shift       Model  Scaler  index  train_r2  test_r2             train_mse  \
# 0      2  ElasticNet  MinMax  의료_건강      0.04     0.04 102515794049206544.00
# 1      2  ElasticNet  MinMax    식음료      0.08     0.08  22104806591444000.00
# 2      2  ElasticNet  MinMax  소매_편의      0.03     0.02 150555934064717984.00
# 3      2  ElasticNet  MinMax  생활서비스      0.03     0.03  22920544916292540.00
# 4      2  ElasticNet  MinMax  교육_학원      0.05     0.04   1720943122531563.00
#
#                test_mse  train_mae_ratio  test_mae_ratio  test_mae_ratio_max  \
# 0 103387438648641856.00            41.33           41.95              114.17
# 1  20481995289092840.00            44.89           44.41              114.17
# 2 181082152909575520.00            50.72           49.02              114.17
# 3  26877966183526560.00            63.59           66.51              114.17
# 4   2005464077959997.50            72.70           74.36              114.17
#
#    test_mae_ratio_min  test_mae_ratio_mean    train_mae     test_mae  \
# 0               41.95                74.52 204852867.94 208912135.52
# 1               41.95                74.52 107412664.64 104947435.81
# 2               41.95                74.52 226153265.26 224294329.71
# 3               41.95                74.52  93887559.15  99223350.94
# 4               41.95                74.52  28022219.60  28632092.65
#
#     train_rmse    test_rmse
# 0 320180877.08 321539171.25
# 1 148676852.91 143115321.64
# 2 388015378.64 425537487.08
# 3 151395326.60 163945009.63
# 4  41484251.50  44782408.13
