# %%
import pandas as pd

# %%
all0 = pd.read_csv("all_category_shift0.csv")
all1 = pd.read_csv("all_category_shift1.csv")
all2 = pd.read_csv("all_category_shift2.csv")
all3 = pd.read_csv("all_category_shift3.csv")
all4 = pd.read_csv("all_category_shift4.csv")

# %%
all0
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      0       LinearRegression             NaN  4.894665e+16  3.937581e+16
# 1      0       LinearRegression  StandardScaler  4.675692e+16  3.900029e+16
# 2      0       LinearRegression    MinMaxScaler  4.675692e+16  3.900037e+16
# 3      0  RandomForestRegressor             NaN  6.807108e+14  3.912119e+15
# 4      0  RandomForestRegressor  StandardScaler  6.804776e+14  3.923931e+15
# 5      0  RandomForestRegressor    MinMaxScaler  6.797919e+14  3.940530e+15
#
#      train_rmse     test_rmse  train_r2  test_r2     train_mae      test_mae  \
# 0  2.212389e+08  1.984334e+08      0.43     0.46  1.155356e+08  1.142812e+08
# 1  2.162335e+08  1.974849e+08      0.46     0.47  1.152066e+08  1.140063e+08
# 2  2.162335e+08  1.974851e+08      0.46     0.47  1.152083e+08  1.140080e+08
# 3  2.609044e+07  6.254694e+07      0.99     0.95  1.129284e+07  2.901945e+07
# ...

# %%
all2
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      2       LinearRegression             NaN  4.726720e+16  4.609107e+16
# 1      2       LinearRegression  StandardScaler  4.428466e+16  4.703229e+16
# 2      2       LinearRegression    MinMaxScaler  4.428466e+16  4.703228e+16
# 3      2  RandomForestRegressor             NaN  6.745188e+14  4.702229e+15
# 4      2  RandomForestRegressor  StandardScaler  6.756279e+14  4.694311e+15
# 5      2  RandomForestRegressor    MinMaxScaler  6.742471e+14  4.709563e+15
#
#      train_rmse     test_rmse  train_r2  test_r2     train_mae      test_mae  \
# 0  2.174102e+08  2.146883e+08      0.43     0.44  1.147083e+08  1.144051e+08
# 1  2.104392e+08  2.168693e+08      0.47     0.43  1.133932e+08  1.144469e+08
# 2  2.104392e+08  2.168693e+08      0.47     0.43  1.133939e+08  1.144475e+08
# 3  2.597150e+07  6.857280e+07      0.99     0.94  1.141467e+07  3.022710e+07
# ...

# %%
all3
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      3       LinearRegression             NaN  4.506266e+16  4.967637e+16
# 1      3       LinearRegression  StandardScaler  4.348441e+16  4.682330e+16
# 2      3       LinearRegression    MinMaxScaler  4.348441e+16  4.682333e+16
# 3      3  RandomForestRegressor             NaN  6.967058e+14  5.458950e+15
# 4      3  RandomForestRegressor  StandardScaler  6.968916e+14  5.449624e+15
# 5      3  RandomForestRegressor    MinMaxScaler  6.969026e+14  5.471243e+15
#
#      train_rmse     test_rmse  train_r2  test_r2     train_mae      test_mae  \
# 0  2.122797e+08  2.228820e+08      0.44     0.42  1.123064e+08  1.134869e+08
# 1  2.085292e+08  2.163869e+08      0.46     0.45  1.124983e+08  1.135622e+08
# 2  2.085292e+08  2.163870e+08      0.46     0.45  1.124973e+08  1.135612e+08
# 3  2.639519e+07  7.388471e+07      0.99     0.94  1.142135e+07  3.182963e+07
# ...

# %%
all4
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      4       LinearRegression             NaN  4.385309e+16  5.065745e+16
# 1      4       LinearRegression  StandardScaler  4.230390e+16  4.804541e+16
# 2      4       LinearRegression    MinMaxScaler  4.230390e+16  4.804530e+16
# 3      4  RandomForestRegressor             NaN  8.207429e+14  6.128535e+15
# 4      4  RandomForestRegressor  StandardScaler  8.200774e+14  6.075590e+15
# 5      4  RandomForestRegressor    MinMaxScaler  8.196979e+14  6.125437e+15
#
#      train_rmse     test_rmse  train_r2  test_r2     train_mae      test_mae  \
# 0  2.094113e+08  2.250721e+08      0.44     0.41  1.115738e+08  1.142079e+08
# 1  2.056791e+08  2.191926e+08      0.46     0.44  1.114328e+08  1.139289e+08
# 2  2.056791e+08  2.191924e+08      0.46     0.44  1.114346e+08  1.139303e+08
# 3  2.864861e+07  7.828496e+07      0.99     0.93  1.189751e+07  3.145971e+07
# ...

# %%
result_all = pd.concat([all0, all1, all2, all3, all4], axis=0)

# %%
result_all = result_all.sort_values("test_mae_ratio")
result_all
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 3      0  RandomForestRegressor             NaN  6.807108e+14  3.912119e+15
# 4      0  RandomForestRegressor  StandardScaler  6.804776e+14  3.923931e+15
# 5      0  RandomForestRegressor    MinMaxScaler  6.797919e+14  3.940530e+15
# 3      1  RandomForestRegressor             NaN  6.541315e+14  5.229042e+15
# 4      1  RandomForestRegressor  StandardScaler  6.505338e+14  5.208306e+15
# 3      2  RandomForestRegressor             NaN  6.745188e+14  4.702229e+15
# 5      2  RandomForestRegressor    MinMaxScaler  6.742471e+14  4.709563e+15
# 5      1  RandomForestRegressor    MinMaxScaler  6.548972e+14  5.238951e+15
# 4      2  RandomForestRegressor  StandardScaler  6.756279e+14  4.694311e+15
# 4      3  RandomForestRegressor  StandardScaler  6.968916e+14  5.449624e+15
# 3      3  RandomForestRegressor             NaN  6.967058e+14  5.458950e+15
# ...

# %%
result_all.to_csv("all_category_merged_shift0_to_shift4.csv", index=False)

# %%
result_all = pd.read_csv("all_category_merged_shift0_to_shift4.csv")

# %%
result_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Shift            30 non-null     int64
#  1   Model            30 non-null     object
#  2   Scaler           20 non-null     object
#  3   train_mse        30 non-null     float64
#  4   test_mse         30 non-null     float64
#  5   train_rmse       30 non-null     float64
#  6   test_rmse        30 non-null     float64
#  7   train_r2         30 non-null     float64
#  8   test_r2          30 non-null     float64
#  9   train_mae        30 non-null     float64
#  10  test_mae         30 non-null     float64
#  11  train_mae_ratio  30 non-null     float64
#  12  test_mae_ratio   30 non-null     float64
# dtypes: float64(10), int64(1), object(2)
# memory usage: 3.2+ KB

# %%
result_all.head(5)
# Out:
#    Shift                  Model          Scaler     train_mse      test_mse  \
# 0      0  RandomForestRegressor             NaN  6.807108e+14  3.912119e+15
# 1      0  RandomForestRegressor  StandardScaler  6.804776e+14  3.923931e+15
# 2      0  RandomForestRegressor    MinMaxScaler  6.797919e+14  3.940530e+15
# 3      1  RandomForestRegressor             NaN  6.541315e+14  5.229042e+15
# 4      1  RandomForestRegressor  StandardScaler  6.505338e+14  5.208306e+15
#
#     train_rmse    test_rmse  train_r2  test_r2    train_mae     test_mae  \
# 0  26090435.92  62546938.10      0.99     0.95  11292838.94  29019445.18
# 1  26085965.03  62641285.74      0.99     0.95  11292730.95  29016936.00
# 2  26072819.00  62773643.62      0.99     0.95  11291422.82  29053142.23
# 3  25575993.80  72312112.73      0.99     0.94  11363633.23  30549311.02
# 4  25505564.23  72168591.45      0.99     0.94  11362050.95  30550991.16
#
#    train_mae_ratio  test_mae_ratio
# ...

# %%
single0 = pd.read_csv("single_category_shift0.csv")
single1 = pd.read_csv("single_category_shift1.csv")
single2 = pd.read_csv("single_category_shift2.csv")
single3 = pd.read_csv("single_category_shift3.csv")
single4 = pd.read_csv("single_category_shift4.csv")

# %%
single4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shift                189 non-null    int64
#  1   Model                189 non-null    object
#  2   Scaler               189 non-null    object
#  3   index                189 non-null    object
#  4   train_r2             189 non-null    float64
#  5   test_r2              189 non-null    float64
#  6   train_mse            189 non-null    float64
#  7   test_mse             189 non-null    float64
#  8   train_mae_ratio      189 non-null    float64
#  9   test_mae_ratio       189 non-null    float64
#  10  test_mae_ratio_max   189 non-null    float64
#  11  test_mae_ratio_min   189 non-null    float64
#  12  test_mae_ratio_mean  189 non-null    float64
#  13  train_mae            189 non-null    float64
#  14  test_mae             189 non-null    float64
# ...

# %%
result_single = pd.concat([single0, single1, single2, single3, single4], axis=0)

# %%
189 * 5
# Out:
# 945

# %%
result_single.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 945 entries, 0 to 188
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shift                945 non-null    int64
#  1   Model                945 non-null    object
#  2   Scaler               945 non-null    object
#  3   index                945 non-null    object
#  4   train_r2             945 non-null    float64
#  5   test_r2              945 non-null    float64
#  6   train_mse            945 non-null    float64
#  7   test_mse             945 non-null    float64
#  8   train_mae_ratio      945 non-null    float64
#  9   test_mae_ratio       945 non-null    float64
#  10  test_mae_ratio_max   945 non-null    float64
#  11  test_mae_ratio_min   945 non-null    float64
#  12  test_mae_ratio_mean  945 non-null    float64
#  13  train_mae            945 non-null    float64
#  14  test_mae             945 non-null    float64
# ...

# %%
result_single.iloc[:,:10]
# Out:
#      Shift             Model   Scaler    index  train_r2  test_r2  \
# 0        0        ElasticNet   MinMax    의료_건강      0.02     0.01
# 1        0        ElasticNet   MinMax      식음료      0.04     0.04
# 2        0        ElasticNet   MinMax    소매_편의      0.01     0.01
# 3        0        ElasticNet   MinMax    생활서비스      0.02     0.02
# 4        0        ElasticNet   MinMax    교육_학원      0.02     0.02
# ..     ...               ...      ...      ...       ...      ...
# 184      4  LinearRegression  Default    미용_패션      0.88     0.88
# 185      4  LinearRegression  Default    취미_레저      0.86     0.92
# 186      4  LinearRegression  Default    교육_학원      0.77     0.78
# 187      4  LinearRegression  Default  가구_전자기기      0.81     0.74
# 188      4  LinearRegression  Default   부동산_숙박      0.88     0.87
#
#         train_mse      test_mse  train_mae_ratio  test_mae_ratio
# 0    1.127143e+17  9.248058e+16            42.36           42.19
# ...

# %%
result_single.groupby(["Model", "Scaler"])["index"].count()
# Out:
# Model                      Scaler
# ElasticNet                 Default     45
#                            MinMax      45
#                            Standard    45
# GradientBoostingRegressor  Default     45
#                            MinMax      45
#                            Standard    45
# LGBMRegressor              Default     45
#                            MinMax      45
#                            Standard    45
# LinearRegression           Default     45
#                            MinMax      45
#                            Standard    45
# MLPRegressor               Default     45
#                            MinMax      45
#                            Standard    45
# RandomForestRegressor      Default     45
#                            MinMax      45
#                            Standard    45
# SVR                        Default     45
#                            MinMax      45
#                            Standard    45
# Name: index, dtype: int64

# %%
result_single.to_csv("single_category_merged_shift0_to_shift4.csv", index=False)

# %%
result_single = pd.read_csv("single_category_merged_shift0_to_shift4.csv")

# %%
result_single.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Shift                945 non-null    int64
#  1   Model                945 non-null    object
#  2   Scaler               945 non-null    object
#  3   index                945 non-null    object
#  4   train_r2             945 non-null    float64
#  5   test_r2              945 non-null    float64
#  6   train_mse            945 non-null    float64
#  7   test_mse             945 non-null    float64
#  8   train_mae_ratio      945 non-null    float64
#  9   test_mae_ratio       945 non-null    float64
#  10  test_mae_ratio_max   945 non-null    float64
#  11  test_mae_ratio_min   945 non-null    float64
#  12  test_mae_ratio_mean  945 non-null    float64
#  13  train_mae            945 non-null    float64
#  14  test_mae             945 non-null    float64
# ...
