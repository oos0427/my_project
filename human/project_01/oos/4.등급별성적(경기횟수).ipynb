# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr, spearmanr, kendalltau

# %%
df = pd.read_csv('source/no_open.csv')

# %%
winner = df[df['ORD']  == 1]

# %%
winner_c = winner.groupby('RANK')['ORD'].count().reset_index(name= 'Count 1st')

# %%
winner_c.head()
# Out:
#    RANK  Count 1st
# 0  국1등급        120
# 1  국2등급        157
# 2  국3등급        171
# 3  국4등급        315
# 4  국5등급        691

# %%
filtered_data = filtered_data[filtered_data['RANK'] != '한4등급']

# %%
winner_c

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'    

plt.figure(figsize=(10, 6))
plt.bar(filtered_data['RANK'], filtered_data['Count 1st'], color='skyblue')
plt.xlabel('등급')  # x축 라벨
plt.ylabel('경기 횟수')  # y축 라벨
plt.title('등급별 경기 횟수')  # 제목
plt.xticks(rotation=45)  # x축 라벨 회전
plt.tight_layout()  # 레이아웃 조정
plt.show()

# %%
winner.head(1)
# Out:
#   MEET   RC_DATE  RC_NO  RC_DIST  RANK WEATHER TR_CON  TR_WC  ORD  CHUL_NO  \
# 0   제주  20230701      1      800  제6등급      흐림     포화     18    1        9
#
#    ... BU_2F-G_TIME  BU_3F-G_TIME BU_1F-G_TIME BU_S1F_ACC_TIME  \
# 0  ...          0.0           0.0          0.0             0.0
#
#    BU_G8F_ACC_TIME BU_G6F_ACC_TIME  BU_G4F_ACC_TIME  BU_G3F_ACC_TIME  \
# 0              0.0             0.0              0.0              0.0
#
#    BU_G2F_ACC_TIME  BU_G1F_ACC_TIME
# 0              0.0              0.0
#
# [1 rows x 92 columns]

# %%
winner['RANK'].unique()
# Out:
# array(['제6등급', '제5등급', '제4등급', '제2등급', '제3등급', '제1등급', '한2등급', '한1등급',
#        '한3등급', '한4등급', '국6등급', '국5등급', '국4등급', '국3등급', '국2등급', '국1등급'],
#       dtype=object)

# %%
rank_info = ['국1등급', '국2등급', '국3등급', '국4등급', '국5등급', '국6등급',
 '제1등급', '제2등급', '제3등급', '제4등급', '제5등급', '제6등급',
 '한1등급', '한2등급', '한3등급', '한4등급']

# %%
plt.rcParams['font.family'] = 'Malgun Gothic'

for rank in rank_info:
    winner_rank = winner[winner['RANK'] == rank]
    winner_rank = winner_rank.groupby(['HR_NAME'])['ORD'].count().sort_values(ascending=False).reset_index(name='Count 1st')
    winner_rank = winner_rank.head(10)

    plt.figure(figsize=(10, 6))
    plt.bar(winner_rank['HR_NAME'], winner_rank['Count 1st'], color='skyblue')
    plt.xlabel('HR_NAME')  # x축 라벨
    plt.ylabel('Count 1st')  # y축 라벨
    plt.title(f'{rank} : Top 10 Horse Names by 1st Count')  # 제목
    plt.xticks(rotation=45)  # x축 라벨 회전
    plt.tight_layout()  # 레이아웃 조정
    plt.show()
