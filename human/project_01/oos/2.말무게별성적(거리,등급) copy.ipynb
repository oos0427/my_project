# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
#df = pd.read_csv('source/rawdata_v1.2.csv')
#df = pd.read_csv('winner.csv')
df = pd.read_csv('source/raw_vol2.0.csv')

# %%
winner = df[df['ORD'] == 1]

# %%
winner['ORD'].unique()
# Out:
# array([1])

# %%
#winner.to_csv('winner.csv', index=False, encoding='utf-8-sig')

# %%
winner.head(1)
# Out:
#   MEET   RC_DATE  RC_NO  RC_DIST  RANK WEATHER TR_CON  TR_WC  ORD  CHUL_NO  \
# 0   제주  20230701      1      800  제6등급      흐림     포화     18    1        9
#
#    ... BU_2F-G_TIME  BU_3F-G_TIME BU_1F-G_TIME BU_S1F_ACC_TIME  \
# 0  ...          0.0           0.0          0.0             0.0
#
#    BU_G8F_ACC_TIME BU_G6F_ACC_TIME  BU_G4F_ACC_TIME  BU_G3F_ACC_TIME  \
# 0              0.0             0.0              0.0              0.0
#
#    BU_G2F_ACC_TIME  BU_G1F_ACC_TIME
# 0              0.0              0.0
#
# [1 rows x 92 columns]

# %%
df.columns
# Out:
# Index(['MEET', 'RC_DATE', 'RC_NO', 'RC_DIST', 'RANK', 'WEATHER', 'TR_CON',
#        'TR_WC', 'ORD', 'CHUL_NO', 'HR_NAME', 'HR_NO', 'NAME', 'PRD_NAME',
#        'AGE', 'SEX', 'horse_weight', 'weight_gain', 'RC_TIME', 'ORD1_CNT_T',
#        'ORD2_CNT_T', 'RC_CNT_T', 'ORD1_CNT_Y', 'ORD2_CNT_Y', 'RC_CNT_Y',
#        'WG_BUDAM', 'JK_NAME', 'JK_NO', 'JK_AGE', 'JK_CAREER', 'JK_ORD1_CNT_T',
#        'JK_ORD2_CNT_T', 'JK_RC_CNT_T', 'JK_ORD1_CNT_Y', 'JK_ORD2_CNT_Y',
#        'JK_RC_CNT_Y', 'TR_NAME', 'TR_NO', 'TR_AGE', 'TR_CAREER',
#        'TR_ORD1_CNT_T', 'TR_ORD2_CNT_T', 'TR_RC_CNT_T', 'TR_ORD1_CNT_Y',
#        'TR_ORD2_CNT_Y', 'TR_RC_CNT_Y', 'HR_ORD1_CNT_T', 'HR_ORD2_CNT_T',
#        'HR_RC_CNT_T', 'SJ_S1F_ORD', 'SJ_1C_ORD', 'SJ_2C_ORD', 'SJ_3C_ORD',
#        'SJ_G3F_ORD', 'SJ_4C_ORD', 'SJ_G1F_ORD', 'SE_S1F_ACC_TIME',
#        'SE_1C_ACC_TIME', 'SE_2C_ACC_TIME', 'SE_3C_ACC_TIME', 'SE_G3F_ACC_TIME',
#        'SE_4C_ACC_TIME', 'SE_G1F_ACC_TIME', 'JE_S1F_TIME', 'JE_1C_TIME',
# ...

# %%
# 말의 무게에 따른 1등 횟수를 히스토그램으로 시각화
plt.figure(figsize=(10, 6))
plt.hist(winner['horse_weight'].dropna(), bins=20)  # NaN 값을 제거하고 bin 크기 설정
plt.xlabel('Horse Weight')
plt.ylabel('Frequency of Wins')
plt.title('Histogram of Wins by Horse Weight')
plt.show()

# %%
print(winner['horse_weight'].max())
print(winner['horse_weight'].min())
print(winner['horse_weight'].mean())
# Out:
# 570.0
# 214.0
# 380.30738255033555

# %%
winner['RC_DIST'].unique()
# Out:
# array([ 800,  900, 1000, 1110, 1200, 1400, 1700, 1610, 1300, 1600, 1800,
#        2000, 2200, 1900])

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['font.size'] = 14

# 'RC_DIST' 별로 반복
for distance in [800, 900, 1000, 1110, 1200, 1400, 1700, 1800, 1610, 1300, 1600, 2000, 2200, 1900]:
    # 'ORD' 값이 1인 경우만 필터링하고 특정 'RC_DIST' 경기 거리로 필터링
    df_filtered = winner[(winner['ORD'] == 1) & (winner['RC_DIST'] == distance)]
    
    # 히스토그램 그리기
    plt.figure(figsize=(10, 6))
    plt.hist(df_filtered['horse_weight'], bins=20, edgecolor='black')
    plt.xlabel('말 무게')
    plt.ylabel('1등 횟수')
    plt.title(f'{distance}M 경기 무게별 1등 횟수')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # 그래프 출력
    plt.show()

# %%
df['RANK'].unique()
# Out:
# array(['제6등급', '제5등급', '제4등급', '제2등급', '제3등급', '제1등급', '한2등급', '한1등급',
#        '한3등급', '한4등급', '국6등급', '국5등급', '국4등급', '국3등급', '국2등급', '국1등급'],
#       dtype=object)

# %%
import matplotlib.pyplot as plt

# 폰트 설정
plt.rcParams['font.family'] = 'Malgun Gothic'

# 'RC_DIST' 별로 반복
for rank in [
    '제1등급', '제2등급', '제3등급', '제4등급', '제5등급', '제6등급',
    '한1등급', '한2등급', '한3등급', '한4등급',
    '국1등급', '국2등급', '국3등급', '국4등급', '국5등급', '국6등급'
]:
    
    # 'ORD' 값이 1인 경우만 필터링하고 특정 'RC_DIST' 경기 거리로 필터링
    df_filtered = df[(df['ORD'] == 1) & (df['RANK'] == rank)]
    
    # 히스토그램 그리기
    plt.figure(figsize=(10, 6))
    plt.hist(df_filtered['horse_weight'], bins=20, edgecolor='black')
    plt.xlabel('말 무게')
    plt.ylabel('1등 횟수')
    plt.title(f'{rank} 경기 무게별 1등 횟수')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    
    # 그래프 출력
    plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

file_path = 'source/raw_vol2.0.csv'
df = pd.read_csv(file_path)

# %%
df['horse_weight'].max()
# Out:
# np.float64(587.0)

# %%
#df2 = df[df['horse_weight'] <= 400]
df2 = df[df['horse_weight'] >= 400]

# %%
print(filtered_df['horse_weight'].describe())  # 데이터 분포 확인
print(filtered_df['horse_weight_bins'].value_counts())  # 구간별 빈도 확인
# Out:
# count    26462.000000
# mean       287.867433
# std         20.320075
# min        250.000000
# 25%        273.000000
# 50%        286.000000
# 75%        302.000000
# max        350.000000
# Name: horse_weight, dtype: float64
# horse_weight_bins
# [400, 410)    0
# [410, 420)    0
# [420, 430)    0
# [430, 440)    0
# [440, 450)    0
# [450, 460)    0
# [460, 470)    0
# [470, 480)    0
# [480, 490)    0
# [490, 500)    0
# [500, 510)    0
# [510, 520)    0
# [520, 530)    0
# [530, 540)    0
# [540, 550)    0
# Name: count, dtype: int64

# %%
# horse_weight을 10 단위로 구간화 (bins 설정)
df2['horse_weight_bins'] = pd.cut(df2['horse_weight'], bins=range(400, 551, 10), right=False)

# 카이제곱 검정을 위한 교차표 생성 (구간화된 horse_weight 사용)
contingency_table = pd.crosstab(df2['ORD'], df2['horse_weight_bins'])

# 카이제곱 검정 수행
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print("Chi-square test statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:", expected)
# Out:
# Chi-square test statistic: 431.8480889265022
# p-value: 2.356848304914838e-22
# Degrees of freedom: 182
# Expected frequencies: [[  7.88439306  21.32369942  48.56069364  88.87861272 135.55780347
#   220.94219653 295.57514451 342.07514451 354.26011561 280.07514451
#   226.85549133 155.         102.94508671  52.68208092  23.38439306]
#  [  7.90781868  21.38705507  48.70497414  89.1426833  135.96056434
#   221.59864618 296.45333891 343.09149681 355.31267113 280.90728628
#   227.52951019 155.46052632 103.25095071  52.83860663  23.45387131]
#  [  7.90112565  21.36895345  48.66375114  89.06723456 135.84548981
#   221.41108914 296.20242622 342.80111044 355.01194098 280.66953149
#   227.33693337 155.32894737 103.163561    52.793885    23.43402038]
#  [  7.93459081  21.45946152  48.86986614  89.44447825 136.42086249
#   222.34887435 297.45698966 344.25304229 356.51559172 281.85830545
#   228.29981746 155.98684211 103.60050958  53.01749315  23.53327502]
# ...

# %%
# horse_weight을 10 단위로 구간화 (bins 설정)
filtered_df['horse_weight_bins'] = pd.cut(filtered_df['horse_weight'], bins=range(250, 361, 10), right=False)

# 카이제곱 검정을 위한 교차표 생성 (구간화된 horse_weight 사용)
contingency_table = pd.crosstab(filtered_df['ORD'], filtered_df['horse_weight_bins'])

# 카이제곱 검정 수행
chi2, p, dof, expected = stats.chi2_contingency(contingency_table)

print("Chi-square test statistic:", chi2)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected frequencies:", expected)

# %%
contingency_table
# Out:
# horse_weight_bins  [400, 410)  [410, 420)  [420, 430)  [430, 440)  [440, 450)  \
# ORD
# 1                           1          12          23          51          77
# 2                           0           7          28          67         106
# 3                           4          17          42          64         150
# 4                           8          19          46          89         139
# 5                           7          22          54         109         130
# 6                           9          20          59          96         137
# 7                          10          23          53         108         153
# 8                           9          17          56         101         142
# 9                          12          29          58          95         137
# 10                         12          36          46          80         120
# 11                          7          19          45          66         117
# ...
